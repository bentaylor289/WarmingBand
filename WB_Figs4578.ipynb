# %% [markdown]
# ## Code for Figures 4,5, 7 and 8
#
# Calculating the along-front means for several models.
#
# Dependencies: time-averages of many models.

# %%
import numpy as np
import matplotlib.pylab as plt
import xarray as xr
import cartopy.crs as ccrs
import cartopy
import gsw

foldern = 'Jan22means/'

# %%
# Calculate the ARC-SAF contour from observations
# will use this for MITgcm ECCO-derived solution

alim=157
tlim = 55
pts = 4

orsi1 = xr.open_dataset('Orsi_Fronts.nc')
orsiSAFx = orsi1.xsaf
orsiSAFy = orsi1.ysaf
#plt.plot(orsiSAFx,orsiSAFy)
orsiSTFx = orsi1.xstf
orsiSTFy = orsi1.ystf

plt.plot(orsiSTFx[0:tlim],orsiSTFy[0:tlim])

y1 = orsiSTFy[tlim-1].values
y2 = orsiSAFy[alim+1].values
x1 = orsiSTFx[tlim].values
x2 = orsiSAFx[alim].values
fill = np.arange(pts)/4
fillx = x1+ fill*(x2-x1)
filly = y1+ fill*(y2-y1)
plt.plot(fillx,filly, 'green')
plt.plot(orsiSAFx[alim:380], orsiSAFy[alim:380], color = 'yellow')

SJFx = np.concatenate((orsiSTFx[0:tlim], fillx, orsiSAFx[alim:380]))
SJFy = np.concatenate((orsiSTFy[0:tlim], filly, orsiSAFy[alim:380]))

# %%
## First doing all the figures that use MITgcm data with along-front averages (4,5, 8). 

# Loading MITgcm data

import scipy.io as sio
# this is old! 
Natl=sio.loadmat('/nfs/data/OGCM/globalwarmingssssstnorthatlanticexplast40years.mat')

#Indp=sio.loadmat('/nfs/data/OGCM/globalwarmingssssstindpacexplast40years.mat') # compare otherocean
#OthO =sio.loadmat('/nfs/data/OGCM/globalwarmingssssstotheroceanexplast40years.mat') # compare otherocean
#S55T =sio.loadmat('/nfs/data/OGCM/globalwarmingssssstexplast40years.mat') # do ssssst instead!
#dSSS =sio.loadmat('/nfs/data/OGCM/globalwarmingsssexplast40years.mat') # do ssssst instead!

#import mat73
#SOBen =mat73.loadmat('/nfs/data/OGCM/globalwarmingssssstSOBenexplast40yearsinterp.mat')

depq = np.squeeze(Natl['depth'])
latq = np.squeeze(Natl['latinterp'])
lonq = np.squeeze(Natl['loninterp'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/scipy/io/matlab/mio.py in _open_file(file_like, appendmat, mode)
#      38     try:
# ---> 39         return open(file_like, mode), True
#      40     except IOError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/nfs/data/OGCM/globalwarmingssssstnorthatlanticexplast40years.mat'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-eaa88db42e52> in <module>
#       5
#       6 import scipy.io as sio
# ----> 7 Natl=sio.loadmat('/nfs/data/OGCM/globalwarmingssssstnorthatlanticexplast40years.mat')
#       8
#       9 #Indp=sio.loadmat('/nfs/data/OGCM/globalwarmingssssstindpacexplast40years.mat') # compare otherocean
#
# ...

# %%
# Code to process the variable we want (annual means of the needed variables)
# Once saved, I just load them. 

#climU_natl = Natl['u4dmeaninterp']
#expU_natl = Natl['u4dmeanwarminginterp']
#expU_indp = Indp['u4dmeanwarminginterp']
#climT_natl = Indp['temp4dmeaninterp']
#expT_natl = Natl['temp4dmeanwarminginterp']
#expT_indp = Indp['temp4dmeanwarminginterp']
#expT_SSTexp = SSTexp['temp4dmeanwarminginterp']
#expU_SSTexp = SSTexp['u4dmeanwarminginterp']

#expSSH_SST  = SSTexp['sealevelmeanwarminginterp']
#expSSH_indp = Indp['sealevelmeanwarminginterp']
#expSSH_natl = Natl['sealevelmeanwarminginterp']
#climSSH_SST = SSTexp['sealevelmeaninterp']

#expT_S55T = S55T['temp4dmeanwarminginterp']
#expT_OthO = OthO['temp4dmeanwarminginterp']
#expU_S55T = S55T['u4dmeanwarminginterp']
#expU_OthO = OthO['u4dmeanwarminginterp']

#expS_dSSS = dSSS['salt4dmeanwarminginterp']
#climS = dSSS['salt4dmeaninterp']
#expT_SST4k = SST4k['temp4dmeanwarminginterp']
#expU_SST4k = SST4k['u4dmeanwarminginterp']

# Southern Ocean run
#expU_SOB = SOBen['u4dmeanwarminginterp'] 
#expT_SOB = SOBen['temp4dmeanwarminginterp']

# %%
#climaU_natl = np.mean(climU_natl,3)
#expaU_natl = np.mean(expU_natl,3)
#expaU_indp = np.mean(expU_indp,3)
#climaT_natl = np.mean(climT_natl,3)


#expaT_S55T =  np.mean(expT_S55T ,3)
#expaT_OthO =  np.mean(expT_OthO,3)
#expaU_S55T = np.mean(expU_S55T,3)
#expaU_OthO = np.mean(expU_OthO,3)
#
#expaSSH_SST  =np.mean(expSSH_SST , 2)
#expaSSH_indp =np.mean(expSSH_indp, 2)
#expaSSH_natl =np.mean(expSSH_natl, 2)
#climaSSH_SST =np.mean(climSSH_SST, 2)

#expaT_SST4k =  np.mean(expT_SST4k, 3)
#expaU_SST4k =  np.mean(expU_SST4k, 3)

#expaS_dSSS =  np.mean(expS_dSSS, 3)
#climaS =  np.mean(climS, 3)

#expaT_SOB = np.mean(expT_SOB,3)
#expaU_SOB = np.mean(expU_SOB,3)

# %%
#np.save( 'MITgcm_qmeans/climaU_natl', climaU_natl)
#np.save( 'MITgcm_qmeans/expaU_natl', expaU_natl)
#np.save( 'MITgcm_qmeans/expaU_indp', expaU_indp)
#np.save( 'MITgcm_qmeans/climaT_natl', climaT_natl)

#np.save( 'MITgcm_qmeans/expaT_SSSSST', expaT_S55T)
#np.save( 'MITgcm_qmeans/expaT_OtherO', expaT_OthO)
#np.save( 'MITgcm_qmeans/expaU_SSSSST', expaU_S55T)
#np.save( 'MITgcm_qmeans/expaU_OtherO', expaU_OthO)
#
#np.save( 'MITgcm_qmeans/expaSSH_SST', expaSSH_SST )
#np.save( 'MITgcm_qmeans/expaSSH_indp',expaSSH_indp)
#np.save( 'MITgcm_qmeans/expaSSH_natl', expaSSH_natl)
#np.save( 'MITgcm_qmeans/climaSSH_SST', climaSSH_SST)

#np.save('MITgcm_qmeans/expaT_dWind', expaT_dWind)
#np.save('MITgcm_qmeans/expaU_dWind', expaU_dWind)
#np.save('MITgcm_qmeans/expaT_SST4k', expaT_SST4k)
#np.save('MITgcm_qmeans/expaU_SST4k', expaU_SST4k)
#np.save('MITgcm_qmeans/expaS_dSSS', expaS_dSSS)

#np.save( 'MITgcm_qmeans/expaT_SOBen', expaT_SOB)
#np.save( 'MITgcm_qmeans/expaU_SOBen', expaU_SOB)

# %%
# Loading the saved variables. 

climaU_natl = np.load( 'MITgcm_qmeans/climaU_natl.npy')
expaU_natl = np.load( 'MITgcm_qmeans/expaU_natl.npy')
expaU_indp = np.load( 'MITgcm_qmeans/expaU_indp.npy')
climaT_natl = np.load( 'MITgcm_qmeans/climaT_natl.npy')
expaT_natl = np.load( 'MITgcm_qmeans/expaT_natl.npy')
expaT_indp = np.load( 'MITgcm_qmeans/expaT_indp.npy')
expaT_SST = np.load( 'MITgcm_qmeans/expaT_SST.npy')
expaU_SST = np.load( 'MITgcm_qmeans/expaU_SST.npy')

expaSSH_SST = np.load('MITgcm_qmeans/expaSSH_SST.npy')
expaSSH_indp = np.load('MITgcm_qmeans/expaSSH_indp.npy')
expaSSH_natl = np.load('MITgcm_qmeans/expaSSH_natl.npy')
climaSSH_SST = np.load('MITgcm_qmeans/climaSSH_SST.npy')

expaT_S55T = np.load('MITgcm_qmeans/expaT_SSSSST.npy')
expaT_OthO = np.load('MITgcm_qmeans/expaT_OtherO.npy')
expaU_S55T = np.load('MITgcm_qmeans/expaU_SSSSST.npy')
expaU_OthO = np.load('MITgcm_qmeans/expaU_OtherO.npy')

expaT_dWind = np.load( 'MITgcm_qmeans/expaT_dWind.npy')
expaU_dWind = np.load( 'MITgcm_qmeans/expaU_dWind.npy')

expaT_dSSS = np.load( 'MITgcm_qmeans/expaT_dSSS.npy')
expaU_dSSS = np.load( 'MITgcm_qmeans/expaU_dSSS.npy')
expaT_SST4k = np.load( 'MITgcm_qmeans/expaT_SST4k.npy')
expaU_SST4k = np.load( 'MITgcm_qmeans/expaU_SST4k.npy')
expaT_AB = np.load( 'MITgcm_qmeans/expaT_AtlBen.npy')
expaU_AB = np.load( 'MITgcm_qmeans/expaU_AtlBen.npy')
expaT_SOB = np.load( 'MITgcm_qmeans/expaT_SOBen.npy')
expaU_SOB = np.load( 'MITgcm_qmeans/expaU_SOBen.npy')

expapassT_SST4k = np.load( 'MITgcm_qmeans/expapassT_SST4k.npy')
expaactT_SST4k = np.load( 'MITgcm_qmeans/expaactT_SST4k.npy') # changed this not to be temp_active, not tempdiff_active
climaT_SST4k = np.load( 'MITgcm_qmeans/climT_SST4k.npy') 

expaS_dSSS = np.load('MITgcm_qmeans/expaS_dSSS.npy')
climaS = np.load('MITgcm_qmeans/climaS_dSSS.npy')

# %%
# not sure what this was ... 

###expSSH_SOB = np.nanmean(expSSH_SOB
##fig, ax = plt.subplots( figsize=(7,4))
##plt.set_cmap('bwr')
##tst = expaT_AB[:,:,1]
##np.where(tst =0, np.nan, tst)
##plt.contourf(np.transpose(expaT_AB[:,:,0] - climaT_natl[:,:,0]), vmin=0.6, vmax=1.8, levels=10)
##ax.tick_params(labelbottom=False, bottom = False, labelleft=False, left=False)
###plt.colorbar()
##
### would this dipole pattern still occur in the SST+4k run?? I feel like maybe not. Worth testing, it's very easy.

# %%
#Now we're actually calculating the average with respect to the ARC-SAF.


sos = 12
nos = 20

qlon = range(20,150) # really need to check this one because sometimes I change it!!
qlat = range(10,70)
qlev = range(0,40)

# Interpolating the ARC-SAF onto the grid x coordinates. 
SJFyq=np.interp(qlon,SJFx,SJFy) # runs from 0 to len(qlon).

#toPl = -np.nanmean(climaU_natl[qlon,:,:], 0) + np.nanmean(expaU_natl[qlon,:,:],0)
#toPl = toPl[qlat,:]

# calculate density of the control run for isopycnals. 
climaSig0 = gsw.sigma0(climaS, climaT_natl)


climaU_natl_str = np.zeros([len(qlon), sos+nos, len(qlev)])
climaT_natl_str = np.zeros([len(qlon), sos+nos, len(qlev)])
expaU_natl_str  = np.zeros([len(qlon), sos+nos, len(qlev)])
expaU_indp_str  = np.zeros([len(qlon), sos+nos, len(qlev)])
expaT_indp_str  = np.zeros([len(qlon), sos+nos, len(qlev)])
expaT_natl_str  = np.zeros([len(qlon), sos+nos, len(qlev)])
expaU_sst_str  = np.zeros([len(qlon), sos+nos, len(qlev)])
expaT_sst_str  = np.zeros([len(qlon), sos+nos, len(qlev)])

expaU_s55t_str  = np.zeros([len(qlon), sos+nos, len(qlev)])
expaT_s55t_str  = np.zeros([len(qlon), sos+nos, len(qlev)])
expaU_otho_str  = np.zeros([len(qlon), sos+nos, len(qlev)])
expaT_otho_str  = np.zeros([len(qlon), sos+nos, len(qlev)])

expaU_dWind_str  = np.zeros([len(qlon), sos+nos, len(qlev)])
expaT_dWind_str  = np.zeros([len(qlon), sos+nos, len(qlev)])
expaU_dSSS_str  = np.zeros([len(qlon), sos+nos, len(qlev)])
expaT_dSSS_str  = np.zeros([len(qlon), sos+nos, len(qlev)])
expaU_SST4k_str  = np.zeros([len(qlon), sos+nos, len(qlev)])
expaT_SST4k_str  = np.zeros([len(qlon), sos+nos, len(qlev)])
expaU_AB_str  = np.zeros([len(qlon), sos+nos, len(qlev)]) # Atlantic north of 30 S
expaT_AB_str  = np.zeros([len(qlon), sos+nos, len(qlev)])
expaU_SOB_str  = np.zeros([len(qlon), sos+nos, len(qlev)]) # Everywhere south of 30 S
expaT_SOB_str  = np.zeros([len(qlon), sos+nos, len(qlev)])


expapassT_SST4k_str  = np.zeros([len(qlon), sos+nos, len(qlev)])
expaactT_SST4k_str  = np.zeros([len(qlon), sos+nos, len(qlev)])
climaT_4kemail_str = np.zeros([len(qlon), sos+nos, len(qlev)])

expaSSH_sst_str = np.zeros([len(qlon), sos+nos])
expaSSH_natl_str = np.zeros([len(qlon), sos+nos])
expaSSH_indp_str = np.zeros([len(qlon), sos+nos])
climaSSH_sst_str = np.zeros([len(qlon), sos+nos])

expaS_dSSS_str  = np.zeros([len(qlon), sos+nos, len(qlev)])
climaS_str  = np.zeros([len(qlon), sos+nos, len(qlev)])
climaSig0_str  = np.zeros([len(qlon), sos+nos, len(qlev)])

#expaT_NAmid_str  = np.zeros([len(qlon), sos+nos, len(qlev)])


for i in np.arange(0, len(qlon)):
    a = int(SJFyq[i]+80)#MIT_rij[qlon[i]] 
    climaU_natl_str[i,:,:] = np.transpose(climaU_natl[qlon[i], a-sos:a+nos, qlev])
    expaU_natl_str[i,:,:]  = np.transpose(expaU_natl[qlon[i], a-sos:a+nos,  qlev])
    expaU_indp_str[i,:,:]  = np.transpose(expaU_indp[qlon[i], a-sos:a+nos,  qlev])
    climaT_natl_str[i,:,:] = np.transpose(climaT_natl[qlon[i], a-sos:a+nos, qlev])
    expaT_natl_str[i,:,:]  = np.transpose(expaT_natl[qlon[i], a-sos:a+nos,  qlev])
    expaT_indp_str[i,:,:]  = np.transpose(expaT_indp[qlon[i], a-sos:a+nos,  qlev])
    expaT_sst_str[i,:,:]  = np.transpose(expaT_SST[qlon[i], a-sos:a+nos,  qlev])
    expaU_sst_str[i,:,:]  = np.transpose(expaU_SST[qlon[i], a-sos:a+nos,  qlev])
    
    expaT_s55t_str[i,:,:]  = np.transpose(expaT_S55T[qlon[i], a-sos:a+nos,  qlev])
    expaU_s55t_str[i,:,:]  = np.transpose(expaU_S55T[qlon[i], a-sos:a+nos,  qlev])
    expaU_otho_str[i,:,:]  = np.transpose(expaU_OthO[qlon[i], a-sos:a+nos,  qlev])
    expaT_otho_str[i,:,:]  = np.transpose(expaT_OthO[qlon[i], a-sos:a+nos,  qlev])
    expaU_dWind_str[i,:,:]  = np.transpose(expaU_dWind[qlon[i], a-sos:a+nos,  qlev])
    expaT_dWind_str[i,:,:]  = np.transpose(expaT_dWind[qlon[i], a-sos:a+nos,  qlev])
    expaU_dSSS_str[i,:,:]  = np.transpose(expaU_dSSS[qlon[i], a-sos:a+nos,  qlev])
    expaT_dSSS_str[i,:,:]  = np.transpose(expaT_dSSS[qlon[i], a-sos:a+nos,  qlev])
    expaU_SST4k_str[i,:,:]  = np.transpose(expaU_SST4k[qlon[i], a-sos:a+nos,  qlev])
    expaT_SST4k_str[i,:,:]  = np.transpose(expaT_SST4k[qlon[i], a-sos:a+nos,  qlev])
    expaU_AB_str[i,:,:]  = np.transpose(expaU_AB[qlon[i], a-sos:a+nos,  qlev])
    expaT_AB_str[i,:,:]  = np.transpose(expaT_AB[qlon[i], a-sos:a+nos,  qlev])
    expaU_SOB_str[i,:,:]  = np.transpose(expaU_SOB[qlon[i], a-sos:a+nos,  qlev])
    expaT_SOB_str[i,:,:]  = np.transpose(expaT_SOB[qlon[i], a-sos:a+nos,  qlev])
    
    expapassT_SST4k_str[i,:,:]  = np.transpose(expapassT_SST4k[qlon[i], a-sos:a+nos,  qlev])
    expaactT_SST4k_str[i,:,:]  = np.transpose(expaactT_SST4k[qlon[i], a-sos:a+nos,  qlev]) # this is not temp diff
    
    # this one is coming from Qihua's email. 
    climaT_4kemail_str[i,:,:] = np.transpose(climaT_SST4k[qlon[i], a-sos:a+nos,  qlev])
    
    
    
    expaSSH_sst_str[i,:]  = np.transpose(expaSSH_SST[qlon[i], a-sos:a+nos])
    expaSSH_natl_str[i,:]  = np.transpose(expaSSH_natl[qlon[i], a-sos:a+nos])
    expaSSH_indp_str[i,:]  = np.transpose(expaSSH_indp[qlon[i], a-sos:a+nos])
    climaSSH_sst_str[i,:]  = np.transpose(climaSSH_SST[qlon[i], a-sos:a+nos])
    
    expaS_dSSS_str[i,:,:]  = np.transpose(expaS_dSSS[qlon[i], a-sos:a+nos,  qlev])
    climaS_str[i,:,:]  = np.transpose(climaS[qlon[i], a-sos:a+nos,  qlev])
    climaSig0_str[i,:,:]  = np.transpose(climaSig0[qlon[i], a-sos:a+nos,  qlev])
    #expaT_NAmid_str[i,:,:]  = np.transpose(expaT_NAmid[qlev, a-sos:a+nos,  qlon[i]])
                                                   
    #WOA_theta_str[:,:,i] = thed[wocedep, a-sos:a+nos,wocelon[i]]
    #IAP_theta_str[:,:,i] = IAPthed[:, a-sos:a+nos,IAPlon[i]]
    #WOA_sig_str[:,:,i] = sigd[wocedep, a-sos:a+nos,wocelon[i]]
    #WOA_sf_str[:,:,i] = sf[wocedep, a-sos:a+nos, wocelon[i]]
    
#plt.contour(np.arange(nos,sos), - dep_natl[qlev], np.transpose(np.mean(climaU_natl_str[:,:, qlev])), levels=20, colors= 'black')

# %% [markdown]
# Now I'll do a few figures that only include the MITgcm material (Figs 5 and 8).

# %%
# Fig 5

# OK new figure just to look at the +4k uniform forcing pattern! 
# I actually think this is quite clear! 


fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(10,6), sharex=True, constrained_layout=True) 

toPl0 = np.transpose(np.nanmean(climaU_natl_str, 0)) 
toPl_iso = np.transpose(np.nanmean(climaSig0_str, 0)) 


# np.nanmean(expaU_natl_str,0)

Plact =  np.transpose(np.nanmean(expaT_SST4k_str,0) - np.nanmean(climaT_natl_str,0))
Plpass = np.transpose(np.nanmean(expapassT_SST4k_str,0))
toPl6 =  np.transpose(np.nanmean(expaU_SST4k_str,0)) - toPl0


#toPl6 =  toPl5 - toPl4 # wild, the otho bit explains essentially the whole shift itself. 

vmb = 15
vmd = 3

Td = 4 
Tdif = 2



plt.set_cmap('bwr')
A = axs[0,0].contourf(np.arange(-sos,nos), - depq[qlev], Plact, vmin = -Td, vmax = Td, levels=30)


B = axs[1,0].contourf(np.arange(-sos,nos), - depq[qlev], Plpass, vmin = -Td, vmax = Td, levels=30)
plt.set_cmap('PRGn')
C = axs[0,1].contourf(np.arange(-sos,nos), - depq[qlev], 100*toPl6, vmin = -vmd, vmax = vmd, levels=30)
plt.set_cmap('bwr')
D = axs[1,1].contourf(np.arange(-sos,nos), - depq[qlev], Plact-Plpass, vmin = -Tdif, vmax = Tdif, levels=30)

Acb = plt.colorbar(A, ax=axs[0,0])

Bcb = plt.colorbar(B, ax=axs[1,0])
Ccb = plt.colorbar(C, ax=axs[0,1])
Dcb = plt.colorbar(D, ax=axs[1,1])

Acb.set_label("$\Delta$T, $^{\circ}$C",fontsize = 'medium')
Bcb.set_label("Passive T, $^{\circ}$C",fontsize = 'medium')
Ccb.set_label("$\Delta$u, cm/s",fontsize = 'medium')
Dcb.set_label("T, $^{\circ}$C",fontsize = 'medium')

axs[0,0].set_title('T change under SST+4K')
axs[0,1].set_title('U change under SST+4K')
axs[1,0].set_ylabel('z (m)')
axs[0,0].set_ylabel('z (m)')

axs[1,0].set_title('Passive T under pass4K')
axs[1,1].set_title('Difference: Panel (a) minus Panel (c)')
axs[1,0].set_xlabel('Degrees North of ARC-SAF',fontsize = 'medium')
axs[1,1].set_xlabel('Degrees North of ARC-SAF',fontsize = 'medium')


plabels = ['a', 'b','c','d']
for i in np.arange(0,4):#[2,4,6]:
    j = i//2
    k = i%2
    if i==2:
        axs[j,k].contour(np.arange(-sos,nos), - depq[qlev], toPl_iso, levels=15, colors= 'gray')
    else:    
        axs[j,k].contour(np.arange(-sos,nos), - depq[qlev], toPl0, levels=20, colors= 'gray')
    #if (k==1 or i==0):
    #    axs[j,k].contour(np.arange(-sos,nos), - depq[qlev], toPl_iso, levels=12, colors= 'gray')
    axs[j,k].set_ylim(-2000,0) 
    axs[j,k].plot([0,0], [-2000,0], '--')
    #axs[j,k].plot(0*depq[qlev] -3, -depq[qlev], linestyle='dashed', color='black', linewidth = 1.5)
    #axs[j,k].plot(0*depq[qlev] +5, -depq[qlev], linestyle='dashed', color='black', linewidth = 1.5)
    axs[j,k].text(0.02, 0.05, plabels[i], size = 16, transform = axs[j,k].transAxes)

#plt.savefig('SISAZ_figures/MITgcm_SST+4k_2-26.eps', format='eps')

# %%
# And here's Figure 8
# this one is ARC-SAF zonal velocity changes 
# SST 4K, North Atlantic SST+SSS, INDP SST+SSS, and a few more. 

fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(10,6), sharex=True, constrained_layout=True) 

toPl0 = np.transpose(np.nanmean(climaU_natl_str, 0)) 
toPl_iso = np.transpose(np.nanmean(climaSig0_str, 0)) 


# np.nanmean(expaU_natl_str,0)
toPl1 =  np.transpose(np.nanmean(expaU_s55t_str,0)) - toPl0
toPl2 =  np.transpose(np.nanmean(expaU_natl_str,0)) - toPl0
toPl4 =  np.transpose(np.nanmean(expaU_indp_str,0)) - toPl0
toPl6 =  np.transpose(np.nanmean(expaU_SST4k_str,0)) - toPl0
toPl5 =  np.transpose(np.nanmean(expaU_otho_str,0)) - toPl0
toPl7 =  np.transpose(np.nanmean(expaU_SOB_str,0)) - toPl0
#toPl6 =  toPl5 - toPl4 # wild, the otho bit explains essentially the whole shift itself. 


vmb = 15
vmd = 3

plt.set_cmap('PRGn')

A = axs[0,0].contourf(np.arange(-sos,nos), - depq[qlev], 100*toPl1, vmin = -vmd, vmax = vmd, levels=30)
B = axs[1,0].contourf(np.arange(-sos,nos), - depq[qlev], 100*toPl2, vmin = -vmd, vmax = vmd, levels=30)
C = axs[0,1].contourf(np.arange(-sos,nos), - depq[qlev], 100*toPl4, vmin = -vmd, vmax = vmd, levels=30)
D = axs[1,1].contourf(np.arange(-sos,nos), - depq[qlev], 100*toPl7, vmin = -vmd, vmax = vmd, levels=30)

Acb = plt.colorbar(A, ax=axs[0,0])
Bcb = plt.colorbar(B, ax=axs[1,0])
Ccb = plt.colorbar(C, ax=axs[0,1])
Dcb = plt.colorbar(D, ax=axs[1,1])

Dcb.set_label("$\Delta$u, cm/s",fontsize = 'medium')
Bcb.set_label("$\Delta$u, cm/s",fontsize = 'medium')
Ccb.set_label("$\Delta$u, cm/s",fontsize = 'medium')
Acb.set_label("$\Delta$u, cm/s",fontsize = 'medium')

axs[0,0].set_title('U change under dBuoy')
axs[0,1].set_title('U change under Ind-Pac')
axs[1,0].set_title('U change under North-Atl')
axs[1,1].set_title('U change under So-Ocean')

# this piece is challenging - I want to make a new axis. 

tst = expaT_AB[:,:,0]

x = np.where(tst ==0 , np.nan, tst)

x = np.ma.array(x, mask=np.isnan(x))
#plt.contourf(x)
plt.gca().set_facecolor("gray") 


axin00 = axs[0,0].inset_axes([0.65, 0.02, 0.33, 0.22])
plt.set_cmap('bwr')
#x = np.where(expaT_AB[:,:,0], np.nan, tst)
x = np.ma.array(expaT_S55T[:,:,0] - climaT_natl[:,:,0], mask=not(np.nonzero(expaT_SST[:,:,0])))
axin00.contourf(np.transpose(x),vmin=0.6, vmax=1.8, levels=10)
axin00.set_facecolor("gray") 
#.contourf(np.transpose(expaT_S55T[:,:,0] - climaT_natl[:,:,0]), vmin=0.6, vmax=1.8, levels=10)
axin00.tick_params(labelbottom=False, bottom = False, labelleft=False, left=False)

axin01 = axs[0,1].inset_axes([0.65, 0.02, 0.33, 0.22])
plt.set_cmap('bwr')
x = np.ma.array(expaT_indp[:,:,0] - climaT_natl[:,:,0], mask=not(np.nonzero(expaT_SST[:,:,0])))
axin01.contourf(np.transpose(x),vmin=0.6, vmax=1.8, levels=10)
axin01.set_facecolor("gray") 
axin01.tick_params(labelbottom=False, bottom = False, labelleft=False, left=False)

axin10 = axs[1,0].inset_axes([0.65, 0.02, 0.33, 0.22])
plt.set_cmap('bwr')
x = np.ma.array(expaT_natl[:,:,0] - climaT_natl[:,:,0], mask=not(np.nonzero(expaT_SST[:,:,0])))
axin10.contourf(np.transpose(x),vmin=0.6, vmax=1.8, levels=10)
axin10.set_facecolor("gray") 
axin10.tick_params(labelbottom=False, bottom = False, labelleft=False, left=False)

axin11 = axs[1,1].inset_axes([0.65, 0.02, 0.33, 0.22])
plt.set_cmap('bwr')
x = np.ma.array(expaT_SOB[:,:,0] - climaT_natl[:,:,0], mask=not(np.nonzero(expaT_SST[:,:,0])))
axin11.contourf(np.transpose(x),vmin=0.6, vmax=1.8, levels=10)
axin11.set_facecolor("gray") 
axin11.tick_params(labelbottom=False, bottom = False, labelleft=False, left=False)

# I am fine

plabels = ['a', 'b','c','d']
for i in np.arange(0,4):#[2,4,6]:
    j = i//2
    k = i%2 
    
    axs[j,k].contour(np.arange(-sos,nos), - depq[qlev], toPl0, levels=20, colors= 'gray')
    #if (k==1 or i==0):
    #    axs[j,k].contour(np.arange(-sos,nos), - depq[qlev], toPl_iso, levels=12, colors= 'gray')
    axs[j,k].set_ylim(-2000,0)    
    #axs[j,k].plot(0*depq[qlev] -3, -depq[qlev], linestyle='dashed', color='black', linewidth = 1.5)
    #axs[j,k].plot(0*depq[qlev] +5, -depq[qlev], linestyle='dashed', color='black', linewidth = 1.5)
    axs[j,k].text(0.02, 0.05, plabels[i], size = 16, transform = axs[j,k].transAxes)

#plt.savefig('SISAZ_figures/MITgcm_regionalbuoy_7-12_insets2.eps', format='eps')

# %% [markdown]
# Figure 4 includes the O-FAFMIP data.

# %% [markdown]
# There are just a few changes needed:
# Need to make sure there's actually a line for ACCESS wind uo.
# Also for GFDL control velocity!
# Make sure this is integrated to 2000m and confirm that somewhere? I think that's right.

# %%
# what I'm doing here is the few degrees around the ARC-SAF minus 55-40 S. 
# 12 is the ARC-SAF .. 
# 11-16 or 11-15?? makes a difference for salinity ... 

zmSST = np.nanmean(expaT_SST[qlon,:,:] - climaT_natl[qlon,:,:], 0)
ztst = np.nansum(qdepd*(zmSST[qlat,:]),1) / sum(qdepd)
SSTdif = np.mean(tmp3[11:16]) - np.nanmean(ztst[15:30])

zmSSS = np.nanmean(expaT_dSSS[qlon,:,:] - climaT_natl[qlon,:,:], 0)
ztst = np.nansum(qdepd*(zmSSS[qlat,:]),1) / sum(qdepd)
SSSdif = np.mean(tmp5[11:16]) - np.nanmean(ztst[15:30])

zmwind = np.nanmean(expaT_dWind[qlon,:,:] - climaT_natl[qlon,:,:], 0)
ztst = np.nansum(qdepd*(zmwind[qlat,:]),1) / sum(qdepd)
winddif = np.mean(tmp7[11:16]) - np.nanmean(ztst[15:30])

plt.bar([1,2,3],[SSTdif, SSSdif, winddif])

# %%
plt.bar([1,2,3],[SSTdif, SSSdif, winddif])

# %%
plt.plot(tmp3[12:15])

# %%
# And here's Figure .. 8!
# This is straightforward, just adding a few more panels to provide a little more information. 

# I think I'm going to include the South Atlantic, because I can directly assess that from Otho minus IndPac. 
# The only piece that matters is the Atlantic sector of the Southern Ocean. 

fig, axs = plt.subplots(nrows=3, ncols=2, figsize=(11,9), sharex=True, constrained_layout=True) 

toPl0 = np.transpose(np.nanmean(climaU_natl_str, 0)) 
toPl_iso = np.transpose(np.nanmean(climaSig0_str, 0)) 


# np.nanmean(expaU_natl_str,0)
toPl1 =  np.transpose(np.nanmean(expaU_s55t_str,0)) - toPl0
toPl2 =  np.transpose(np.nanmean(expaU_natl_str,0)) - toPl0
toPl4 =  np.transpose(np.nanmean(expaU_indp_str,0)) - toPl0
toPl6 =  np.transpose(np.nanmean(expaU_SST4k_str,0)) - toPl0
toPl5 =  np.transpose(np.nanmean(expaU_otho_str,0)) - toPl0
toPl7 =  np.transpose(np.nanmean(expaU_SOB_str,0)) - toPl0
#toPl6 =  toPl5 - toPl4 # wild, the otho bit explains essentially the whole shift itself. 


vmb = 15
vmd = 3

plt.set_cmap('PRGn')

A = axs[0,0].contourf(np.arange(-sos,nos), - depq[qlev], 100*toPl1, vmin = -vmd, vmax = vmd, levels=30)
B = axs[1,0].contourf(np.arange(-sos,nos), - depq[qlev], 100*toPl2, vmin = -vmd, vmax = vmd, levels=30)
C = axs[0,1].contourf(np.arange(-sos,nos), - depq[qlev], 100*toPl4, vmin = -vmd, vmax = vmd, levels=30)
D = axs[1,1].contourf(np.arange(-sos,nos), - depq[qlev], 100*toPl7, vmin = -vmd, vmax = vmd, levels=30)
E = axs[2,0].contourf(np.arange(-sos,nos), - depq[qlev], 100*(toPl5 - toPl4), vmin = -vmd, vmax = vmd, levels=30)

Acb = plt.colorbar(A, ax=axs[0,0])
Bcb = plt.colorbar(B, ax=axs[1,0])
Ccb = plt.colorbar(C, ax=axs[0,1])
Dcb = plt.colorbar(D, ax=axs[1,1])
Ecb = plt.colorbar(E, ax=axs[2,0])

Ecb.set_label("$\Delta$u, cm/s",fontsize = 'medium')
Dcb.set_label("$\Delta$u, cm/s",fontsize = 'medium')
Bcb.set_label("$\Delta$u, cm/s",fontsize = 'medium')
Ccb.set_label("$\Delta$u, cm/s",fontsize = 'medium')
Acb.set_label("$\Delta$u, cm/s",fontsize = 'medium')

axs[0,0].set_title('U change under dBuoy')
axs[0,1].set_title('U change under IndPac-dBuoy')
axs[1,0].set_title('U change under NAtl-dBuoy')
axs[1,1].set_title('U change under SOce-dBuoy')
axs[2,0].set_title('U change, NotNA-dBuoy minus IndPac-dBuoy')
axs[2,1].set_title('U change, upper 2000m')

# this piece is challenging - I want to make a new axis. 

tst = expaT_AB[:,:,0]

x = np.where(tst ==0 , np.nan, tst)

x = np.ma.array(x, mask=np.isnan(x))
#plt.contourf(x)
#plt.gca().set_facecolor("gray") 


axin00 = axs[0,0].inset_axes([0.65, 0.02, 0.33, 0.22])
plt.set_cmap('bwr')
#x = np.where(expaT_AB[:,:,0], np.nan, tst)
x = np.ma.array(expaT_S55T[:,:,0] - climaT_natl[:,:,0], mask=not(np.nonzero(expaT_SST[:,:,0])))
axin00.contourf(np.transpose(x),vmin=0.6, vmax=1.8, levels=10)
axin00.set_facecolor("gray") 
#.contourf(np.transpose(expaT_S55T[:,:,0] - climaT_natl[:,:,0]), vmin=0.6, vmax=1.8, levels=10)
axin00.tick_params(labelbottom=False, bottom = False, labelleft=False, left=False)

axin01 = axs[0,1].inset_axes([0.65, 0.02, 0.33, 0.22])
plt.set_cmap('bwr')
x = np.ma.array(expaT_indp[:,:,0] - climaT_natl[:,:,0], mask=not(np.nonzero(expaT_SST[:,:,0])))
axin01.contourf(np.transpose(x),vmin=0.6, vmax=1.8, levels=10)
axin01.set_facecolor("gray") 
axin01.tick_params(labelbottom=False, bottom = False, labelleft=False, left=False)

axin10 = axs[1,0].inset_axes([0.65, 0.02, 0.33, 0.22])
plt.set_cmap('bwr')
x = np.ma.array(expaT_natl[:,:,0] - climaT_natl[:,:,0], mask=not(np.nonzero(expaT_SST[:,:,0])))
axin10.contourf(np.transpose(x),vmin=0.6, vmax=1.8, levels=10)
axin10.set_facecolor("gray") 
axin10.tick_params(labelbottom=False, bottom = False, labelleft=False, left=False)

axin11 = axs[1,1].inset_axes([0.65, 0.02, 0.33, 0.22])
plt.set_cmap('bwr')
x = np.ma.array(expaT_SOB[:,:,0] - climaT_natl[:,:,0], mask=not(np.nonzero(expaT_SST[:,:,0])))
axin11.contourf(np.transpose(x),vmin=0.6, vmax=1.8, levels=10)
axin11.set_facecolor("gray") 
axin11.tick_params(labelbottom=False, bottom = False, labelleft=False, left=False)

axin20 = axs[2,0].inset_axes([0.65, 0.02, 0.33, 0.22])
plt.set_cmap('bwr')
x = np.ma.array(expaT_OthO[:,:,0] - expaT_indp[:,:,0], mask=not(np.nonzero(expaT_SST[:,:,0])))
axin20.contourf(np.transpose(x),vmin=1, vmax=1.8, levels=10)
axin20.set_facecolor("gray") 
axin20.tick_params(labelbottom=False, bottom = False, labelleft=False, left=False)


climU = np.nanmean(climaU_natl_str[:,:,0:40], 0)
du_natl = np.sum(qdepd[0:40]*(np.nanmean(expaU_natl_str,0) - climU),1) / sum(qdepd)
du_indp = np.sum(qdepd[0:40]*(np.nanmean(expaU_indp_str,0) - climU),1) / sum(qdepd)
du_SOB = np.sum(qdepd[0:40]*(np.nanmean(expaU_SOB_str,0) - climU),1) / sum(qdepd)
du_otho = np.sum(qdepd[0:40]*(np.nanmean(expaU_otho_str,0) - climU),1) / sum(qdepd)
du_AB = np.sum(qdepd[0:40]*(np.nanmean(expaU_AB_str,0) - climU),1) / sum(qdepd)
du_s55t = np.sum(qdepd[0:40]*(np.nanmean(expaU_s55t_str,0) - climU),1) / sum(qdepd)

axs[2,1].plot(np.arange(-sos,nos), 100*du_s55t, color='black')
axs[2,1].plot(np.arange(-sos,nos), 100*du_indp, color ='orange')
axs[2,1].plot(np.arange(-sos,nos), 100*du_natl, color='red', zorder = 1)
axs[2,1].plot(np.arange(-sos,nos), 100*du_SOB,  zorder = 2)
axs[2,1].plot(np.arange(-sos,nos), 100*du_otho, '--',color='green', zorder =6)
#axs[2,1].plot(np.arange(-sos,nos), 100*du_AB, color='pink', zorder= 5)

axs[2,1].legend(['dBuoy','IndPac-dBuoy', 'NAtl-dBuoy', 'SOce-dBuoy', 'NotNA-dBuoy'],loc = 'lower right', ncol=1)

axs[2,1].grid()
axs[2,1].set_facecolor("white") 
axs[2,1].set_ylabel('Average $\Delta$u, cm/s')
axs[2,0].set_xlabel('Degrees North of ARC-SAF',fontsize = 'medium')
axs[2,1].set_xlabel('Degrees North of ARC-SAF',fontsize = 'medium')
axs[2,0].set_ylabel('z (m)')
axs[1,0].set_ylabel('z (m)')
axs[0,0].set_ylabel('z (m)')


plabels = ['a', 'b','c','d','e','f']
for i in np.arange(0,6):#[2,4,6]:
    j = i//2
    k = i%2 
    if i<5:
        axs[j,k].contour(np.arange(-sos,nos), - depq[qlev], toPl0, levels=20, colors= 'gray')
        axs[j,k].plot([0,0], [-2000,0], '--')
        axs[j,k].set_ylim(-2000,0)    
    #else:
    #    axs[2,1].plot([0,0], [-1.5,1.5], '--')
    #    axs[2,1].set_ylim(-1.5,1.5)
        
    #axs[j,k].plot(0*depq[qlev] -3, -depq[qlev], linestyle='dashed', color='black', linewidth = 1.5)
    #axs[j,k].plot(0*depq[qlev] +5, -depq[qlev], linestyle='dashed', color='black', linewidth = 1.5)
    axs[j,k].text(0.02, 0.05, plabels[i], size = 16, transform = axs[j,k].transAxes)

#plt.savefig('SISAZ_figures/MITgcm_regionalbuoy_7-22_insets.eps', format='eps')

# %%
plt.contourf(np.arange(-sos,nos), - depq[qlev], np.transpose(climU))
plt.colorbar()

# %%
#x = np.ma.array(expaT_S55T[:,:,0] - climaT_natl[:,:,0], mask=not(np.nonzero(expaT_SST[:,:,0])))
#plt.contourf(np.transpose(x))
#plt.colorbar()
#plt.gca().set_facecolor("gray")

# %%
#expaU_sst_str.shape

# %%
qdepd

# %%
climT = np.nanmean(climaT_natl_str, 0)
d_natl = np.sum(qdepd[0:40]*(np.nanmean(expaT_natl_str,0) - climT),1) / sum(qdepd)
d_indp = np.sum(qdepd[0:40]*(np.nanmean(expaT_indp_str,0) - climT),1) / sum(qdepd)
d_SOB = np.sum(qdepd[0:40]*(np.nanmean(expaT_SOB_str,0) - climT),1) / sum(qdepd)
d_pass = np.sum(qdepd[0:40]*(np.nanmean(expapassT_SST4k_str,0)),1) / sum(qdepd)

# %%
# what I'm doing here is the few degrees around the ARC-SAF minus 55-40 S. 
# 12 is the ARC-SAF .. 
# 11-16 or 11-15?? makes a difference for salinity ... 
zmr = np.arange(15,30) # passive depends strongly on the mean we compare it to! 

# lazy coding on the names
zmSST = np.nanmean(expaT_natl[qlon,:,:] - climaT_natl[qlon,:,:], 0) 
ztst = np.nansum(qdepd*(zmSST[qlat,:]),1) / sum(qdepd)
Natldif = np.mean(d_natl[11:16]) - np.nanmean(ztst[zmr])

zmSSS = np.nanmean(expaT_indp[qlon,:,:] - climaT_natl[qlon,:,:], 0)
ztst = np.nansum(qdepd*(zmSSS[qlat,:]),1) / sum(qdepd)
Indpdif = np.mean(d_indp[11:16]) - np.nanmean(ztst[zmr])

zmwind = np.nanmean(expaT_SOB[qlon,:,:] - climaT_natl[qlon,:,:], 0)
ztst = np.nansum(qdepd*(zmwind[qlat,:]),1) / sum(qdepd)
SOBdif = np.mean(d_SOB[11:16]) - np.nanmean(ztst[zmr])

zmwind = np.nanmean(expapassT_SST4k[qlon,:,:], 0)
ztst = np.nansum(qdepd*(zmwind[qlat,:]),1) / sum(qdepd)
passdif = np.mean(d_pass[11:16]) - np.nanmean(ztst[zmr])

plt.bar([1,2,3, 4],[Natldif, Indpdif, SOBdif,passdif])

# %%
## Tryna make a line plot here ... 

climU = np.nanmean(climaU_natl_str, 0)
du_natl = np.sum(qdepd[0:40]*(np.nanmean(expaU_natl_str,0) - climU),1) / sum(qdepd)
du_indp = np.sum(qdepd[0:40]*(np.nanmean(expaU_indp_str,0) - climU),1) / sum(qdepd)
du_SOB = np.sum(qdepd[0:40]*(np.nanmean(expaU_SOB_str,0) - climU),1) / sum(qdepd)
du_otho = np.sum(qdepd[0:40]*(np.nanmean(expaU_otho_str,0) - climU),1) / sum(qdepd)
du_AB = np.sum(qdepd[0:40]*(np.nanmean(expaU_AB_str,0) - climU),1) / sum(qdepd)
du_s55t = np.sum(qdepd[0:40]*(np.nanmean(expaU_s55t_str,0) - climU),1) / sum(qdepd)


plt.plot(np.arange(-sos,nos), 100*du_natl, color='red')
plt.plot(np.arange(-sos,nos), 100*du_AB, color='pink')
plt.plot(np.arange(-sos,nos), 100*du_indp, color ='orange')
plt.plot(np.arange(-sos,nos), 100*du_SOB, color='lightblue')
plt.plot(np.arange(-sos,nos), 100*du_otho, color='green')
plt.plot(np.arange(-sos,nos), 100*du_s55t, color='black')
plt.legend(['North Atlantic', 'Atl N of 30S', 'Indo-Pac', 'SO, S of 30S', 'All exc N.Atl','All Ocean'])

plt.grid()
#du_pass = np.sum(qdepd[0:40]*(np.nanmean(expapassT_SST4k_str,0)),1) / sum(qdepd)

# %%
qdepd2 = np.diff(depq)
qdepd2 = np.insert(qdepd2,0,10)
#qdepd2
np.nanmean(climaU_natl_str, 0)

# %%
## full depth yields qualitatively the same results...

climU = np.nanmean(climaU_natl_str, 0)
du_natl = np.nansum(qdepd2*(np.nanmean(expaU_natl_str,0) - climU),1) / sum(qdepd2)
du_indp = np.nansum(qdepd2*(np.nanmean(expaU_indp_str,0) - climU),1) / sum(qdepd2)
du_SOB =  np.nansum(qdepd2*(np.nanmean(expaU_SOB_str,0) - climU),1) / sum(qdepd2)
du_otho = np.nansum(qdepd2*(np.nanmean(expaU_otho_str,0) - climU),1) / sum(qdepd2)
du_AB =   np.nansum(qdepd2*(np.nanmean(expaU_AB_str,0) - climU),1) / sum(qdepd2)
du_s55t = np.nansum(qdepd2*(np.nanmean(expaU_s55t_str,0) - climU),1) / sum(qdepd2)


plt.plot(np.arange(-sos,nos), du_natl, color='red')
plt.plot(np.arange(-sos,nos), du_AB, color='pink')
plt.plot(np.arange(-sos,nos), du_indp, color ='orange')
plt.plot(np.arange(-sos,nos), du_SOB, color='lightblue')
plt.plot(np.arange(-sos,nos), du_otho, color='green')
plt.plot(np.arange(-sos,nos), du_s55t, color='black')
plt.legend(['North Atlantic', 'Atl N of 30S', 'Indo-Pac', 'SO, S of 30S', 'All exc N.Atl','All Ocean'])

plt.grid()
#du_pass = np.sum(qdepd[0:40]*(np.nanmean(expapassT_SST4k_str,0)),1) / sum(qdepd)

# %% [markdown]
# ### Processing for Figure 7: CanESM, MIROC, MRI, GFDL, and CESM1 wind-stress locking

# %%
## Load data for CanESM 

mnum = 3 # 0 = GFDL, 1 = MIROC, 2 = MRI, 3 = CanESM, 4 = CESM
mlist = [ "GFDL","MIROC","MRI","CanESM","CESM"]

lats = -70 # write these between -90 and 90
latn = -10  

lonw = 20 #write these between 0 and 360, sorry! # normally 20 to 150. 
lone = 150

depth = 1500

vm = 0.05
vmT = 3
vmc = 1
#fig.suptitle(mlist[mnum]+' output zonal average, '+str(lonw)+' - '+str(lone)+' E')

foldern = 'Jan22means/'
# seems like the best way to do this is to have a dictionary. Probably one dictionary for each model. This will require thinking!
# likely it's not that bad. For a start, you can write a simple code just to pull them from files! 
#Then make the dictionary when you rewrite the read from file codes to make them efficient
pl_heat_u = xr.open_dataarray(foldern + mlist[mnum]+'_heat_u.nc')
pl_heat_theta = xr.open_dataarray(foldern + mlist[mnum]+'_heat_theta.nc')
pl_wind_theta = xr.open_dataarray(foldern + mlist[mnum]+'_wind_theta.nc')
pl_water_theta = xr.open_dataarray(foldern + mlist[mnum]+'_water_theta.nc')

pl_wind_u = xr.open_dataarray(foldern + mlist[mnum]+'_wind_u.nc')
pl_water_u = xr.open_dataarray(foldern + mlist[mnum]+'_water_u.nc')
#pl_heat_sal = xr.open_dataarray(foldern + mlist[mnum]+'_heat_sal.nc')
pl_cont_u = xr.open_dataarray(foldern + mlist[mnum]+'_cont_u.nc')
pl_cont_pass = xr.open_dataarray(foldern + mlist[mnum]+'_cont_pass.nc')
pl_cont_sal = xr.open_dataarray(foldern + mlist[mnum]+'_cont_sal.nc')
pl_cont_theta = xr.open_dataarray(foldern + mlist[mnum]+'_cont_theta.nc')
pl_NA0_theta = xr.open_dataarray(foldern + mlist[mnum]+'_NA0_theta.nc')
pl_NA0_u = xr.open_dataarray(foldern + mlist[mnum]+'_NA0_u.nc')
pl_NA50_theta = xr.open_dataarray(foldern + mlist[mnum]+'_NA50_theta.nc')
pl_NA50_u = xr.open_dataarray(foldern + mlist[mnum]+'_NA50_u.nc')

if mnum==0:
    lonfile = pl_heat_theta.lon
    latfile = pl_heat_theta.lat
    depfile = pl_heat_theta.lev
    pl_cont_sig0 = gsw.sigma0(pl_cont_sal, pl_cont_theta)
    pl_heat_sig0 = gsw.sigma0(pl_heat_sal, pl_heat_theta)
    
elif mnum in (1,2,3): 
    lonfile = pl_cont_u.longitude
    latfile = pl_cont_u.latitude
    depfile = pl_cont_u.lev
    pl_cont_sig0 = gsw.sigma0(pl_cont_sal, pl_cont_theta)
    #if mnum==1: # better solution once I make a dictionary
        #pl_cont_sig0 = MIROC_cont_sig0
    #else:
        #pl_cont_sig0 = 0*MIROC_cont_sig0
    
elif mnum ==4:
    lonfile = pl_cont_u.lon
    latfile = pl_cont_u.lat
    depfile = pl_cont_u.lev
    #pl_cont_sig0 = 0*MIROC_cont_sig0

# 25 to 65 is the region that tends to work best in Indian Ocean. 
 # actual longitude - 80 please; 305 to 345 in Indian for GFDL and MRI
# MIROC is zeroed to 60, which is annoying! 
# and CANESM to 74 hahahah what the heck ... 
# and CESM is just awful. Don't even. 1.125 degrees smh.

# should import C_ant as cant and WOCE data as WOA_TA, T6, T5 etc...


# pick actual latitudes
lonmax = [80, 360, 360, 360, 360]
lonmin = [-280, 0, 0,0,0]

if lone>lonmax[mnum]:
    lone = lone - 360
if lone<lonmin[mnum]:
    lone = lone + 360
    
if lonw>lonmax[mnum]:
    lonw = lonw - 360
if lonw<lonmin[mnum]:
    lonw = lonw + 360
    
lonecd = np.argmin(np.abs(np.array(lone - lonfile[0,:])))
lonwcd = np.argmin(np.abs(np.array(lonw - lonfile[0,:])))  
latncd = np.argmin(np.abs(np.array(latn - latfile[:,0])))
latscd = np.argmin(np.abs(np.array(lats - latfile[:,0])))

if lonwcd>lonecd:
    lonwcd = lonwcd-len(lonfile[0,:])

mylat = np.arange(latscd,latncd)
mylon = np.arange(lonwcd,lonecd)

idealdepth = [40, 48, 48, 30, 46]
idealdepth2 = [40, 48, 48, 29, 46] # just changed CanESM for now.
regdep = np.arange(0,idealdepth2[mnum])

# %%
# Version with improved contour?? 

a = np.load('CanESM_ARCSAF.npz')
pl_ARCSAF_y = a['CanESM_ARCSAF_y']
ARCSAF_xco = a['lon_co']
SAFy = pl_ARCSAF_y[mylon - ARCSAF_xco[0]]


# I am concerned that the current is too far south ... is this a problem with the model solution or my streamline average?
# First good to check what the model solution looks like? 

sos= 12 # integers please
nos = 20
wind = np.arange(-sos,nos)
winddif = np.arange(-sos-0.5, nos+0.5)
heat_T_can_str = np.zeros([len(regdep), sos+nos, len(mylon)])
cont_T_can_str = np.zeros([len(regdep), sos+nos, len(mylon)])
wind_T_can_str = np.zeros([len(regdep), sos+nos, len(mylon)])
water_T_can_str = np.zeros([len(regdep), sos+nos, len(mylon)])
wind_U_can_str = np.zeros([len(regdep), sos+nos, len(mylon)])
water_U_can_str = np.zeros([len(regdep), sos+nos, len(mylon)])
cont_pass_can_str = np.zeros([len(regdep), sos+nos, len(mylon)])
cont_sig0_can_str = np.zeros([len(regdep), sos+nos, len(mylon)])
cont_U_can_str = np.zeros([len(regdep), sos+nos, len(mylon)])
heat_U_can_str = np.zeros([len(regdep), sos+nos, len(mylon)])
cont_T_dif_can_str = np.zeros([len(regdep), sos+nos+1, len(mylon)])
#NA0_T_can_str = np.zeros([len(regdep), sos+nos, len(mylon)])
#NA0_U_can_str = np.zeros([len(regdep), sos+nos, len(mylon)])
#NA50_T_can_str = np.zeros([len(regdep), sos+nos, len(mylon)])
#NA50_U_can_str = np.zeros([len(regdep), sos+nos, len(mylon)])


# we want to get the actual y value at each step within mylon (not the coordinate of the adjusted ARCSAF at every value)
# this is some subset of pl_ARCSAF_y
# it's like mylon - 
 # I think that's pretty much it??? 

for i in np.arange(0,len(mylon)-1):
    # a is the actual latitude that we're looking at.
    a = SAFy[i] # use lm[mylon[i]] or strlat
    winda = a+ wind
    winddifa = a+ winddif
    for l in np.arange(0,len(regdep)):
        heat_T_can_str[l,:,i] = np.interp(winda, pl_heat_theta.latitude.isel(i=i), pl_heat_theta.isel(lev=l, i=mylon[i]))
        wind_T_can_str[l,:,i] = np.interp(winda, pl_heat_theta.latitude.isel(i=i), pl_wind_theta.isel(lev=l, i=mylon[i]))
        water_T_can_str[l,:,i] = np.interp(winda, pl_heat_theta.latitude.isel(i=i), pl_water_theta.isel(lev=l, i=mylon[i]))
        wind_U_can_str[l,:,i] = np.interp(winda, pl_heat_theta.latitude.isel(i=i), pl_wind_u.isel(lev=l, i=mylon[i]))
        water_U_can_str[l,:,i] = np.interp(winda, pl_heat_theta.latitude.isel(i=i), pl_water_u.isel(lev=l, i=mylon[i]))
        cont_T_can_str[l,:,i] = np.interp(winda, pl_heat_theta.latitude.isel(i=i), pl_cont_theta.isel(lev=l, i=mylon[i]))
        cont_pass_can_str[l,:,i] = np.interp(winda, pl_heat_theta.latitude.isel(i=i), pl_cont_pass.isel(lev=l, i=mylon[i]))
        cont_T_dif_can_str[l,:,i] = np.interp(winddifa, pl_heat_theta.latitude.isel(i=i), pl_cont_theta.isel(lev=l, i=mylon[i]))
        heat_U_can_str[l,:,i] = np.interp(winda, pl_heat_theta.latitude.isel(i=i), pl_heat_u.isel(lev=l, i=mylon[i]))
        cont_U_can_str[l,:,i] = np.interp(winda, pl_heat_theta.latitude.isel(i=i), pl_cont_u.isel(lev=l, i=mylon[i]))
        #cont_sig0_can_str[l,:,i] = np.interp(winda, pl_heat_theta.latitude.isel(i=i), pl_cont_sig0.isel(lev=l, i=mylon[i]))
        #NA0_T_can_str[l,:,i] = np.interp(winda, pl_heat_theta.latitude.isel(i=i), pl_NA0_theta.isel(lev=l, i=mylon[i]))
        #NA0_U_can_str[l,:,i] = np.interp(winda, pl_heat_theta.latitude.isel(i=i), pl_NA0_u.isel(lev=l, i=mylon[i]))
        #NA50_T_can_str[l,:,i] = np.interp(winda, pl_heat_theta.latitude.isel(i=i), pl_NA50_theta.isel(lev=l, i=mylon[i]))
        #NA50_U_can_str[l,:,i] = np.interp(winda, pl_heat_theta.latitude.isel(i=i), pl_NA50_u.isel(lev=l, i=mylon[i]))
        #SAFy=np.interp(np.arange(lonw,lone)+0.5,orsiSAFx,orsiSAFy)

    #WOA_sal_str[:,:,i] = sald[wocedep, a-sos:a+nos, wocelon[i]]
    #heat_T_can_str[:,:,i] = pl_heat_theta[regdep, a-sos:a+nos,wocelon[i]]
    #cont_T_can_str[:,:,i] = pl_cont_theta[regdep, a-sos:a+nos,wocelon[i]]
    #cont_pass_can_str[:,:,i] = pl_cont_pass[regdep, a-sos:a+nos,wocelon[i]]

# %%
## Active - passive means 
# only issue is to get the subplots 1 and 2 to be same size

fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(18,5)) 
plt.set_cmap('bwr')

tmplon = np.arange(0,130) # this can be modified to look at a subsection of the region (20-150 E)
#   - np.nanmean(cont_pass_can_str,2) #  np.nanmean(heat_T_can_str[:,:,tmplon],2)- np.nanmean(cont_T_can_str[:,:,tmplon],2) 

mylevs = np.arange(0,2.5,0.1)
# active
vm = 2.5
axs[0].contour(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_sig0_can_str[:,:,tmplon],2) , levels = np.arange(24.2,28.3,0.3), colors='gray')
#axs[0].contour(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_U_can_str[:,:,tmplon],2) , levels = [-0.075,-0.05,-0.03,-0.02,0,0.02,0.05,0.075,0.1,0.125], colors='gray')
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(np.diff(cont_T_dif_can_str[:,:,tmplon],axis=1),2),vmin = -vm, vmax = vm, levels=20)
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_pass_can_str[:,:,tmplon],2) ,vmin = -vm, vmax = vm, levels=20)
A = axs[0].contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(heat_T_can_str[:,:,tmplon],2)  -np.nanmean(cont_T_can_str[:,:,tmplon],2) , vmin = -vm, vmax = vm, levels=mylevs, extend='max')


# passive
axs[1].contour(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_sig0_can_str[:,:,tmplon],2) , levels = np.arange(24.2,28.3,0.3), colors='gray')
#axs[1].contour(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_U_can_str[:,:,tmplon],2) , levels = [-0.075,-0.05,-0.03,-0.02,0,0.02,0.05,0.075,0.1,0.125], colors='gray')
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(np.diff(cont_T_dif_can_str[:,:,tmplon],axis=1),2),vmin = -vm, vmax = vm, levels=20)
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_pass_can_str[:,:,tmplon],2) ,vmin = -vm, vmax = vm, levels=20)
B= axs[1].contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_pass_can_str[:,:,tmplon],2) , vmin = -vm, vmax = vm, levels=mylevs, extend = 'max')
fig.colorbar(B, ax=axs[1])
fig.colorbar(A, ax=axs[0])

# difference 
vm = 1
mylevdif = np.arange(-1,1,0.1)
axs[2].contour(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_sig0_can_str[:,:,tmplon],2) , levels = np.arange(24.2,28.3,0.3), colors='gray')
#axs[2].contour(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_U_can_str[:,:,tmplon],2) , levels = [-0.075,-0.05,-0.03,-0.02,0,0.02,0.05,0.075,0.1,0.125], colors='gray')
C= axs[2].contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(heat_T_can_str[:,:,tmplon], 2) - np.nanmean(cont_T_can_str[:,:,tmplon], 2) - np.nanmean(cont_pass_can_str[:,:,tmplon],2), vmin = -vm, vmax = vm, levels=mylevdif, extend='min')

fig.colorbar(C, ax=axs[2])
for j in np.arange(3):
    axs[j].plot(0*-pl_heat_theta.lev.isel(lev=regdep) -3, -pl_heat_theta.lev.isel(lev=regdep), linestyle='dashed', color='black', linewidth = 1)
    axs[j].plot(0*-pl_heat_theta.lev.isel(lev=regdep) +5, -pl_heat_theta.lev.isel(lev=regdep), linestyle='dashed', color='black', linewidth = 1)
    #axs[j].plot(0*IAPlev+5, -IAPlev, linestyle='dashed', color='black', linewidth = 1)

# %% [markdown]
# Notably, the ARC-SAF front does well except in the 80-110 range, where it's too far north. the model jet is very broad there but strongest about 5 degrees further south. On the whole it does well though.

# %%
## AMOC-related velocity changes

fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(19,5)) 
plt.set_cmap('PRGn')

tmplon = np.arange(0,130) # 20 is 0 # - np.nanmean(cont_T_can_str[:,:,tmplon],2)- np.nanmean(cont_pass_can_str[:,:,tmplon],2)

# U change due to heat! 
vm = 1.5
#   - np.nanmean(cont_pass_can_str,2) #  np.nanmean(heat_T_can_str[:,:,tmplon],2)- np.nanmean(cont_T_can_str[:,:,tmplon],2) 
axs[0].contour(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_U_can_str[:,:,tmplon],2) , levels = [-0.075,-0.05,-0.03,-0.02,0,0.02,0.05,0.075,0.1,0.125], colors='gray')
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(np.diff(cont_T_dif_can_str[:,:,tmplon],axis=1),2),vmin = -vm, vmax = vm, levels=20)
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_pass_can_str[:,:,tmplon],2) ,vmin = -vm, vmax = vm, levels=20)
A = axs[0].contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), 100*np.nanmean(heat_U_can_str[:,:,tmplon],2) - 100*np.nanmean(cont_U_can_str[:,:,tmplon],2)  , vmin = -vm, vmax = vm, levels=20)

# without North Atlantic
axs[1].contour(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_U_can_str[:,:,tmplon],2) , levels = [-0.075,-0.05,-0.03,-0.02,0,0.02,0.05,0.075,0.1,0.125], colors='gray')
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(np.diff(cont_T_dif_can_str[:,:,tmplon],axis=1),2),vmin = -vm, vmax = vm, levels=20)
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_pass_can_str[:,:,tmplon],2) ,vmin = -vm, vmax = vm, levels=20)
B= axs[1].contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), 100*np.nanmean(NA0_U_can_str[:,:,tmplon],2) - 100*np.nanmean(cont_U_can_str[:,:,tmplon],2), vmin = -vm, vmax = vm, levels=20)

# SST minus North Atlantic
axs[2].contour(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_U_can_str[:,:,tmplon],2) , levels = [-0.075,-0.05,-0.03,-0.02,0,0.02,0.05,0.075,0.1,0.125], colors='gray')
C= axs[2].contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), 100*np.nanmean(heat_U_can_str[:,:,tmplon],2)- 100*np.nanmean(NA0_U_can_str[:,:,tmplon],2), vmin = -vm, vmax = vm, levels=20)

Ccb = fig.colorbar(C, ax=axs[2])

Bcb = fig.colorbar(B, ax=axs[1])
Acb = fig.colorbar(A, ax=axs[0])

Acb.set_label("$\Delta$u, cm/s",fontsize = 'large')
Bcb.set_label("$\Delta$u, cm/s",fontsize = 'large')
Ccb.set_label("$\Delta$u, cm/s",fontsize = 'large')

for j in np.arange(3):
    axs[j].plot(0*-pl_heat_theta.lev.isel(lev=regdep) -3, -pl_heat_theta.lev.isel(lev=regdep), linestyle='dashed', color='black', linewidth = 1.5)
    axs[j].plot(0*-pl_heat_theta.lev.isel(lev=regdep) +5, -pl_heat_theta.lev.isel(lev=regdep), linestyle='dashed', color='black', linewidth = 1.5)

# %%
# this is great. Probably a mapped view may be helpful for people to be sure of what they're seeing. 
# Another concern is that I should definitely include a wind stress change plot. That will be helpful to people, I think.
# 
## here's where I'll do just an ARC-SAF T line plots thing...

fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(6,5)) 
plt.set_cmap('bwr')

tmplon = np.arange(0,130) # this can be modified to look at a subsection of the region (20-150 E)
#   - np.nanmean(cont_pass_can_str,2) #  np.nanmean(heat_T_can_str[:,:,tmplon],2)- np.nanmean(cont_T_can_str[:,:,tmplon],2) 

mylevs = np.arange(0,2.5,0.1)
# active
vm = 2.5

depinc = np.array(depfile.diff('lev')[regdep])
depinc = depinc.reshape((len(depinc),1))
depinc[-1] = 2000- sum(depinc[:-1])

tmph = np.nanmean(heat_T_can_str[:,:,tmplon] - cont_T_can_str[:,:,tmplon],2)
tmph = np.sum(tmph*depinc,0)/sum(depinc)
#tmpNA = np.nanmean(NA0_T_can_str[:,:,tmplon] - cont_T_can_str[:,:,tmplon],2)
tmpp = np.nanmean( cont_pass_can_str[:,:,tmplon],2)
tmpw = np.nanmean( wind_T_can_str[:,:,tmplon]- cont_T_can_str[:,:,tmplon],2)
tmpf = np.nanmean( water_T_can_str[:,:,tmplon]- cont_T_can_str[:,:,tmplon],2)

axs.plot(wind, tmph ,  color='red')
#axs[0].contour(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_U_can_str[:,:,tmplon],2) , levels = [-0.075,-0.05,-0.03,-0.02,0,0.02,0.05,0.075,0.1,0.125], colors='gray')
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(np.diff(cont_T_dif_can_str[:,:,tmplon],axis=1),2),vmin = -vm, vmax = vm, levels=20)
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_pass_can_str[:,:,tmplon],2) ,vmin = -vm, vmax = vm, levels=20)
#axs.plot( wind, np.sum(tmpNA*depinc,0)/sum(depinc), color= 'orange')
axs.plot( wind, np.sum(tmpp*depinc,0)/sum(depinc), color= 'gray')
axs.plot( wind, np.sum(tmpw*depinc,0)/sum(depinc), color= 'blue')
axs.plot( wind, np.sum(tmpf*depinc,0)/sum(depinc), color= 'green')

Canwindow = wind
Canplheat = tmph
Canplwind = np.sum(tmpw*depinc,0)/sum(depinc)
Canplwater = np.sum(tmpf*depinc,0)/sum(depinc)
Canplpass = np.sum(tmpp*depinc,0)/sum(depinc)
#CanplHF = plHF/fac
Canlims = [-0.3, 1.2]  


### now adding a piece about transports... 
tmpcontu = np.nanmean(cont_U_can_str[:,:,tmplon],2)
tmphu = np.nanmean( heat_U_can_str[:,:,tmplon]- cont_U_can_str[:,:,tmplon],2)
tmpwu = np.nanmean( wind_U_can_str[:,:,tmplon]- cont_U_can_str[:,:,tmplon],2)
tmpfu = np.nanmean( water_U_can_str[:,:,tmplon]- cont_U_can_str[:,:,tmplon],2)

Canplcont_u = np.sum(tmpcontu*depinc,0)/sum(depinc)
Canplheat_u = np.sum(tmphu*depinc,0)/sum(depinc)
Canplwind_u = np.sum(tmpwu*depinc,0)/sum(depinc)
Canplwater_u = np.sum(tmpfu*depinc,0)/sum(depinc)

# let's save all these Canpl files! Could save some time later .



#yy, zz = np.meshgrid(latfile[mylat,0],  depf[mnum]* depfile[regdep])
#yy2, zz2 = np.meshgrid(latfile[np.arange(lats,latn-1),0],  depf[mnum]* depfile[regdep])

plt.plot( [-3,-3], [-0.5, 1.5], linestyle='dashed', color='black', linewidth = 1.5)
plt.plot( [4,4],  [-0.5, 1.5], linestyle='dashed', color='black', linewidth = 1.5)
#plt.legend(['faf-heat', 'faf-passiveheat','faf-stress'])
plt.legend(['faf-heat', 'faf-passiveheat','faf-stress', 'faf-water'])
axs.set_ylim(Canlims)
#plt.savefig('SISAZ_figures/CanESM_Tlines_Apr24.eps')


# FAFMIP data
#toPl0 = np.mean(pl_heat_theta[regdep,mylat,mylon] - pl_cont_theta[regdep,mylat,mylon],2)
#toPl0 = np.sum(toPl0* depinc,0)/sum(depinc)
#axs.plot(latfile[mylat,0], toPl0, color='red')

# haha! this is potentially really nice as well ...

# %%
#np.savez('CanESM_ARCSAF_zint.npz', Canplcont_u = Canplcont_u, Canplheat_u = Canplheat_u, Canplwind_u = Canplwind_u, Canplwater_u = Canplwater_u,
#           Canwindow= Canwindow, Canplheat = Canplheat, Canplwind = Canplwind, Canplwater = Canplwater, Canplpass =Canplpass )


plt.plot(Canplheat_u)
plt.plot(Canplcont_u*0.1)
plt.plot(Canplwind_u)
plt.plot(Canplwater_u)
plt.plot(0*Canplheat_u, 'k', linewidth =1)

# %%
## here's where I'll do just an ARC-SAF T line plots thing...

#### noob mistake here wihtout weighting by depths!!!

fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(6,5)) 
plt.set_cmap('bwr')

tmplon = np.arange(0,130) # this can be modified to look at a subsection of the region (20-150 E)
#   - np.nanmean(cont_pass_can_str,2) #  np.nanmean(heat_T_can_str[:,:,tmplon],2)- np.nanmean(cont_T_can_str[:,:,tmplon],2) 

mylevs = np.arange(0,2.5,0.1)
# active
vm = 2.5
axs.plot(wind, np.nanmean(np.nanmean(heat_T_can_str[:,:,tmplon] - cont_T_can_str[:,:,tmplon],2),0) ,  color='gray')
#axs[0].contour(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_U_can_str[:,:,tmplon],2) , levels = [-0.075,-0.05,-0.03,-0.02,0,0.02,0.05,0.075,0.1,0.125], colors='gray')
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(np.diff(cont_T_dif_can_str[:,:,tmplon],axis=1),2),vmin = -vm, vmax = vm, levels=20)
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_pass_can_str[:,:,tmplon],2) ,vmin = -vm, vmax = vm, levels=20)
axs.plot( wind, np.nanmean(np.nanmean(NA0_T_can_str[:,:,tmplon] - cont_T_can_str[:,:,tmplon],2),0) , color= 'k')
axs.plot( wind, np.nanmean(np.nanmean( cont_pass_can_str[:,:,tmplon],2),0) , color= 'r')

# haha! this is potentially really nice as well ...

# %%
# rewriting the mitgcm code for CanESM ... 

# what I'm doing here is the few degrees around the ARC-SAF minus 55-40 S. 
# 12 is the ARC-SAF .. 
# Need to identify latitude coordinates for 55-40 S. 
latncd = np.argmin(np.abs(np.array(-40 - latfile[:,0])))
latscd = np.argmin(np.abs(np.array(-55 - latfile[:,0])))
zmr = np.arange(latscd - mylat[0], latncd-mylat[0])

depinc = np.array(depfile.diff('lev')[regdep])
depinc = depinc.reshape((len(depinc),1))
depinc[-1] = 2000- sum(depinc[:-1])


zmSST =pl_heat_theta.isel(j=mylat, i=mylon, lev=regdep) - pl_cont_theta.isel(j=mylat, i=mylon, lev=regdep)
zmSST = zmSST.mean('i')
ztst = np.sum(zmSST*depinc,0) / sum(depinc) # np.sum(tmph*depinc,0)/sum(depinc)
CanSSTdif = np.mean(Canplheat[10:15]) - np.nanmean(ztst[zmr])


zmSSS =pl_water_theta.isel(j=mylat, i=mylon, lev=regdep) - pl_cont_theta.isel(j=mylat, i=mylon, lev=regdep)
zmSSS = zmSSS.mean('i')
ztst = np.sum(zmSSS*depinc,0) / sum(depinc) # np.sum(tmph*depinc,0)/sum(depinc)
CanSSSdif = np.mean(Canplwater[10:15]) - np.nanmean(ztst[zmr])
#
zmW =pl_wind_theta.isel(j=mylat, i=mylon, lev=regdep) - pl_cont_theta.isel(j=mylat, i=mylon, lev=regdep)
zmW = zmW.mean('i')
ztst = np.sum(zmW*depinc,0) / sum(depinc) # np.sum(tmph*depinc,0)/sum(depinc)
CanWdif = np.mean(Canplwind[10:15]) - np.nanmean(ztst[zmr])

plt.bar([1,2,3],[CanSSTdif, CanSSSdif, CanWdif])

# %%
# probably 11:16 is better for MITgcm, but usually 10:15. OK fine.

# %%
plt.plot(ztst[zmr])

# %%
# Still would like to have plots for GFDL, MRI, and CESM (wind-locking and FAFMIP, ideally). 
# Maybe I'll just use this working CanESM code instead? Probably easier than editing this very old one.

# %% [markdown]
# ## streamline averaging for MRI model.

# %%
## Load data for MRI

mnum = 2 # 0 = GFDL, 1 = MIROC, 2 = MRI, 3 = CanESM, 4 = CESM
mlist = [ "GFDL","MIROC","MRI","CanESM","CESM"]

lats = -70 # write these between -90 and 90
latn = -10  

lonw = 20 #write these between 0 and 360, sorry! # normally 20 to 100. 
lone = 150

depth = 1500

vm = 0.05
vmT = 3
vmc = 1
#fig.suptitle(mlist[mnum]+' output zonal average, '+str(lonw)+' - '+str(lone)+' E')

foldern = 'Jan22means/'
# seems like the best way to do this is to have a dictionary. Probably one dictionary for each model. This will require thinking!
# likely it's not that bad. For a start, you can write a simple code just to pull them from files! 
#Then make the dictionary when you rewrite the read from file codes to make them efficient
pl_heat_u = xr.open_dataarray(foldern + mlist[mnum]+'_heat_u.nc')
pl_heat_theta = xr.open_dataarray(foldern + mlist[mnum]+'_heat_theta.nc')
#pl_heat_pass = xr.open_dataarray(foldern + mlist[mnum]+'_heat_pass.nc')
#pl_heat_sal = xr.open_dataarray(foldern + mlist[mnum]+'_heat_sal.nc')
pl_cont_u = xr.open_dataarray(foldern + mlist[mnum]+'_cont_u.nc')
pl_cont_pass = xr.open_dataarray(foldern + mlist[mnum]+'_cont_pass.nc')
pl_cont_sal = xr.open_dataarray(foldern + mlist[mnum]+'_cont_sal.nc')
pl_cont_theta = xr.open_dataarray(foldern + mlist[mnum]+'_cont_theta.nc')
pl_NA0_theta = xr.open_dataarray(foldern + mlist[mnum]+'_NA0_theta.nc')
pl_NA0_u = xr.open_dataarray(foldern + mlist[mnum]+'_NA0_u.nc')
pl_NA50_theta = xr.open_dataarray(foldern + mlist[mnum]+'_NA50_theta.nc')
pl_NA50_u = xr.open_dataarray(foldern + mlist[mnum]+'_NA50_u.nc')
pl_wind_theta = xr.open_dataarray(foldern + mlist[mnum]+'_wind_theta.nc')
pl_water_theta = xr.open_dataarray(foldern + mlist[mnum]+'_water_theta.nc')
pl_wind_u = xr.open_dataarray(foldern + mlist[mnum]+'_wind_u.nc')
pl_water_u = xr.open_dataarray(foldern + mlist[mnum]+'_water_u.nc')

if mnum==0:
    lonfile = pl_heat_theta.lon
    latfile = pl_heat_theta.lat
    depfile = pl_heat_theta.lev
    pl_cont_sig0 = gsw.sigma0(pl_cont_sal, pl_cont_theta)
    pl_heat_sig0 = gsw.sigma0(pl_heat_sal, pl_heat_theta)
    
elif mnum in (1,2,3): 
    lonfile = pl_cont_u.longitude
    latfile = pl_cont_u.latitude
    depfile = pl_cont_u.lev
    pl_cont_sig0 = gsw.sigma0(pl_cont_sal, pl_cont_theta)
    #if mnum==1: # better solution once I make a dictionary
        #pl_cont_sig0 = MIROC_cont_sig0
    #else:
        #pl_cont_sig0 = 0*MIROC_cont_sig0
    
elif mnum ==4:
    lonfile = pl_cont_u.lon
    latfile = pl_cont_u.lat
    depfile = pl_cont_u.lev
    #pl_cont_sig0 = 0*MIROC_cont_sig0

# 25 to 65 is the region that tends to work best in Indian Ocean. 
 # actual longitude - 80 please; 305 to 345 in Indian for GFDL and MRI
# MIROC is zeroed to 60, which is annoying! 
# and CANESM to 74 hahahah what the heck ... 
# and CESM is just awful. Don't even. 1.125 degrees smh.

# should import C_ant as cant and WOCE data as WOA_TA, T6, T5 etc...


# pick actual latitudes
lonmax = [80, 360, 360, 360, 360]
lonmin = [-280, 0, 0,0,0]

if lone>lonmax[mnum]:
    lone = lone - 360
if lone<lonmin[mnum]:
    lone = lone + 360
    
if lonw>lonmax[mnum]:
    lonw = lonw - 360
if lonw<lonmin[mnum]:
    lonw = lonw + 360
    
lonecd = np.argmin(np.abs(np.array(lone - lonfile[0,:])))
lonwcd = np.argmin(np.abs(np.array(lonw - lonfile[0,:])))  
latncd = np.argmin(np.abs(np.array(latn - latfile[:,0])))
latscd = np.argmin(np.abs(np.array(lats - latfile[:,0])))

if lonwcd>lonecd:
    lonwcd = lonwcd-len(lonfile[0,:])

mylat = np.arange(latscd,latncd)
mylon = np.arange(lonwcd,lonecd)

idealdepth = [40, 48, 48, 30, 46]
idealdepth2 = [40, 48, 48, 29, 46] # just changed CanESM for now.
regdep = np.arange(0,idealdepth2[mnum])

# %%
#pl_wind_u.isel(lev=0).plot() #= xr.open_dataarray(foldern + 'MRI'+'_water_theta.nc')
# what is the problem with MRI water? Is the file we downloaded wrong? Or just the averaging?

# %%
a3 = np.load('MRI_ARCSAF.npz')
pl_ARCSAF_y = a3['MRI_ARCSAF_y']
ARCSAF_xco = a3['lon_co']
SAFy = pl_ARCSAF_y[mylon - ARCSAF_xco[0]]
plt.plot(np.arange(20,150),SAFy)

# %%
pl_water_theta.isel(lev=l, x=mylon[i])

# %%
# For MRI, there is even spacing, so i don't technically need to interpolate. However, it should work... 
# A more efficient solution would be just to find the closest index ... can implement later if this is weird. 
# yeah it's pretty slow. u
# implemented alternate contour already!
a3 = np.load('MRI_ARCSAF.npz')
pl_ARCSAF_y = a3['MRI_ARCSAF_y']
ARCSAF_xco = a3['lon_co']
SAFy = pl_ARCSAF_y[mylon - ARCSAF_xco[0]]


sos= 12 # integers please
nos = 20
wind = np.arange(-sos,nos)
winddif = np.arange(-sos-0.5, nos+0.5)
heat_T_mri_str = np.zeros([len(regdep), sos+nos, len(mylon)])
cont_T_mri_str = np.zeros([len(regdep), sos+nos, len(mylon)])
wind_T_mri_str = np.zeros([len(regdep), sos+nos, len(mylon)])
water_T_mri_str = np.zeros([len(regdep), sos+nos, len(mylon)])
wind_U_mri_str = np.zeros([len(regdep), sos+nos, len(mylon)])
water_U_mri_str = np.zeros([len(regdep), sos+nos, len(mylon)])
cont_pass_mri_str = np.zeros([len(regdep), sos+nos, len(mylon)])
cont_U_mri_str = np.zeros([len(regdep), sos+nos, len(mylon)])
heat_U_mri_str = np.zeros([len(regdep), sos+nos, len(mylon)])
#cont_T_dif_mri_str = np.zeros([len(regdep), sos+nos+1, len(mylon)])
NA0_T_mri_str = np.zeros([len(regdep), sos+nos, len(mylon)])
NA0_U_mri_str = np.zeros([len(regdep), sos+nos, len(mylon)])
NA50_T_mri_str = np.zeros([len(regdep), sos+nos, len(mylon)])
NA50_U_mri_str = np.zeros([len(regdep), sos+nos, len(mylon)])

#SAFy=np.interp(mylon + float(pl_cont_theta.longitude.isel(x=0,y=0)),SJFx,SJFy) # using observed ARC-SAF

for i in np.arange(0,len(mylon)-1):
    # a is the actual latitude that we're looking at.
    a = SAFy[i] # use lm[mylon[i]] or strlat
    winda = a+ wind
    winddifa = a+ winddif
    for l in np.arange(0,len(regdep)):
        heat_T_mri_str[l,:,i] = np.interp(winda, pl_heat_theta.latitude.isel(x=i), pl_heat_theta.isel(lev=l, x=mylon[i]))
        cont_T_mri_str[l,:,i] = np.interp(winda, pl_heat_theta.latitude.isel(x=i), pl_cont_theta.isel(lev=l, x=mylon[i]))
        wind_T_mri_str[l,:,i] = np.interp(winda, pl_heat_theta.latitude.isel(x=i), pl_wind_theta.isel(lev=l, x=mylon[i]))
        water_T_mri_str[l,:,i] = np.interp(winda, pl_heat_theta.latitude.isel(x=i), pl_water_theta.isel(lev=l, x=mylon[i]))
        wind_U_mri_str[l,:,i] = np.interp(winda, pl_heat_theta.latitude.isel(x=i,y=mylat), pl_wind_u.isel(lev=l, x=mylon[i],y=mylat))
        water_U_mri_str[l,:,i] = np.interp(winda, pl_heat_theta.latitude.isel(x=i,y=mylat), pl_water_u.isel(lev=l, x=mylon[i],y=mylat))
        cont_pass_mri_str[l,:,i] = np.interp(winda, pl_heat_theta.latitude.isel(x=i), pl_cont_pass.isel(lev=l, x=mylon[i]))
        #cont_T_dif_can_str[l,:,i] = np.interp(winddifa, pl_heat_theta.latitude.isel(x=i), pl_cont_theta.isel(lev=l, x=mylon[i]))
        heat_U_mri_str[l,:,i] = np.interp(winda, pl_heat_theta.latitude.isel(x=i, y=mylat), pl_heat_u.isel(lev=l, x=mylon[i], y= mylat))
        cont_U_mri_str[l,:,i] = np.interp(winda, pl_heat_theta.latitude.isel(x=i, y=mylat), pl_cont_u.isel(lev=l, x=mylon[i], y=mylat))
        #NA0_T_mri_str[l,:,i] = np.interp(winda,  pl_heat_theta.latitude.isel(x=i), pl_NA0_theta.isel(lev=l, x=mylon[i]))
        #NA0_U_mri_str[l,:,i] = np.interp(winda,  pl_heat_theta.latitude.isel(x=i,y=mylat), pl_NA0_u.isel(lev=l, x=mylon[i],y=mylat))
        #NA50_T_mri_str[l,:,i] = np.interp(winda, pl_heat_theta.latitude.isel(x=i), pl_NA50_theta.isel(lev=l, x=mylon[i]))
        #NA50_U_mri_str[l,:,i] = np.interp(winda, pl_heat_theta.latitude.isel(x=i,y=mylat), pl_NA50_u.isel(lev=l, x=mylon[i],y=mylat))
        #SAFy=np.interp(np.arange(lonw,lone)+0.5,orsiSAFx,orsiSAFy)

    #WOA_sal_str[:,:,i] = sald[wocedep, a-sos:a+nos, wocelon[i]]
    #heat_T_can_str[:,:,i] = pl_heat_theta[regdep, a-sos:a+nos,wocelon[i]]
    #cont_T_can_str[:,:,i] = pl_cont_theta[regdep, a-sos:a+nos,wocelon[i]]
    #cont_pass_can_str[:,:,i] = pl_cont_pass[regdep, a-sos:a+nos,wocelon[i]]

# %%
pl_heat_theta.latitude.isel(x=mylon[i]).shape

# %%
plt.contourf(np.nanmean(water_T_mri_str,2) - np.nanmean(cont_T_mri_str,2))
plt.colorbar()

# %%
## AMOC-related velocity changes

fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(19,5)) 
#plt.set_cmap('bwr')
plt.set_cmap('PRGn')
tmplon = np.arange(0,130) # 20 is 0 # - np.nanmean(cont_T_can_str[:,:,tmplon],2)- np.nanmean(cont_pass_can_str[:,:,tmplon],2)

# U change due to heat! 
vm = 2
#   - np.nanmean(cont_pass_can_str,2) #  np.nanmean(heat_T_can_str[:,:,tmplon],2)- np.nanmean(cont_T_can_str[:,:,tmplon],2) 
axs[0].contour(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_U_mri_str[:,:,tmplon],2) , levels = [-0.075,-0.05,-0.03,-0.02,0,0.02,0.05,0.075,0.1,0.125], colors='gray')
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(np.diff(cont_T_dif_can_str[:,:,tmplon],axis=1),2),vmin = -vm, vmax = vm, levels=20)
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_pass_can_str[:,:,tmplon],2) ,vmin = -vm, vmax = vm, levels=20)
A = axs[0].contourf(wind, -pl_heat_theta.lev.isel(lev=regdep), 100*np.nanmean(heat_U_mri_str[:,:,tmplon],2) - 100*np.nanmean(cont_U_mri_str[:,:,tmplon],2)  , vmin = -vm, vmax = vm, levels=20)

# without North Atlantic
axs[1].contour(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_U_mri_str[:,:,tmplon],2) , levels = [-0.075,-0.05,-0.03,-0.02,0,0.02,0.05,0.075,0.1,0.125], colors='gray')
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(np.diff(cont_T_dif_can_str[:,:,tmplon],axis=1),2),vmin = -vm, vmax = vm, levels=20)
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_pass_can_str[:,:,tmplon],2) ,vmin = -vm, vmax = vm, levels=20)
B= axs[1].contourf(wind, -pl_heat_theta.lev.isel(lev=regdep), 100*np.nanmean(NA0_U_mri_str[:,:,tmplon],2) - 100*np.nanmean(cont_U_mri_str[:,:,tmplon],2), vmin = -vm, vmax = vm, levels=20)

# SST minus North Atlantic
axs[2].contour(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_U_mri_str[:,:,tmplon],2) , levels = [-0.075,-0.05,-0.03,-0.02,0,0.02,0.05,0.075,0.1,0.125], colors='gray')
C= axs[2].contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), 100*np.nanmean(heat_U_mri_str[:,:,tmplon],2)- 100*np.nanmean(NA0_U_mri_str[:,:,tmplon],2), vmin = -vm, vmax = vm, levels=20)

Acb= fig.colorbar(A, ax=axs[0])
Bcb= fig.colorbar(B, ax=axs[1])
Ccb= fig.colorbar(C, ax=axs[2])

Acb.set_label("$\Delta$u, cm/s",fontsize = 'large')
Bcb.set_label("$\Delta$u, cm/s",fontsize = 'large')
Ccb.set_label("$\Delta$u, cm/s",fontsize = 'large')

for j in np.arange(3):
    axs[j].plot(0*-pl_heat_theta.lev.isel(lev=regdep) -3, -pl_heat_theta.lev.isel(lev=regdep), linestyle='dashed', color='black', linewidth = 1.5)
    axs[j].plot(0*-pl_heat_theta.lev.isel(lev=regdep) +5, -pl_heat_theta.lev.isel(lev=regdep), linestyle='dashed', color='black', linewidth = 1.5)

# %%
## Active - passive means - MRI
# only issue is to get the subplots 1 and 2 to be same size

fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(18,5)) 
plt.set_cmap('bwr')

tmplon = np.arange(0,60) # this can be modified to look at a subsection of the region (20-150 E)
#   - np.nanmean(cont_pass_can_str,2) #  np.nanmean(heat_T_can_str[:,:,tmplon],2)- np.nanmean(cont_T_can_str[:,:,tmplon],2) 

# active
vm = 3
axs[0].contour(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_U_mri_str[:,:,tmplon],2) , levels = [-0.075,-0.05,-0.03,-0.02,0,0.02,0.05,0.075,0.1,0.125], colors='gray')
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(np.diff(cont_T_dif_can_str[:,:,tmplon],axis=1),2),vmin = -vm, vmax = vm, levels=20)
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_pass_can_str[:,:,tmplon],2) ,vmin = -vm, vmax = vm, levels=20)
A = axs[0].contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(heat_T_mri_str[:,:,tmplon],2)  -np.nanmean(cont_T_mri_str[:,:,tmplon],2) , vmin = -vm, vmax = vm, levels=20)

# passive
axs[1].contour(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_U_mri_str[:,:,tmplon],2) , levels = [-0.075,-0.05,-0.03,-0.02,0,0.02,0.05,0.075,0.1,0.125], colors='gray')
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(np.diff(cont_T_dif_can_str[:,:,tmplon],axis=1),2),vmin = -vm, vmax = vm, levels=20)
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_pass_can_str[:,:,tmplon],2) ,vmin = -vm, vmax = vm, levels=20)
B= axs[1].contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_pass_mri_str[:,:,tmplon],2) , vmin = -vm, vmax = vm, levels=20)


# difference 
vm = 1.5
fig.colorbar(A, ax=axs[1])
axs[2].contour(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_U_mri_str[:,:,tmplon],2) , levels = [-0.075,-0.05,-0.03,-0.02,0,0.02,0.05,0.075,0.1,0.125], colors='gray')
C= axs[2].contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(heat_T_mri_str[:,:,tmplon], 2) - np.nanmean(cont_T_mri_str[:,:,tmplon], 2) - np.nanmean(cont_pass_mri_str[:,:,tmplon],2), vmin = -vm, vmax = vm, levels=20)

fig.colorbar(C, ax=axs[2])

# %%
# this is great. Probably a mapped view may be helpful for people to be sure of what they're seeing. 
# Another concern is that I should definitely include a wind stress change plot. That will be helpful to people, I think.
# 
## here's where I'll do just an ARC-SAF T line plots thing...

fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(6,5)) 
plt.set_cmap('bwr')

tmplon = np.arange(0,130) # this can be modified to look at a subsection of the region (20-150 E)
#   - np.nanmean(cont_pass_can_str,2) #  np.nanmean(heat_T_can_str[:,:,tmplon],2)- np.nanmean(cont_T_can_str[:,:,tmplon],2) 

mylevs = np.arange(0,2.5,0.1)
# active
vm = 2.5

depinc = np.array(depfile.diff('lev')[regdep])
depinc = depinc.reshape((len(depinc),1))
depinc[-1] = 2000 - sum(depinc[:-1])

tmph = np.nanmean(heat_T_mri_str[:,:,tmplon] - cont_T_mri_str[:,:,tmplon],2)
tmph = np.sum(tmph*depinc,0)/sum(depinc)
tmpNA = np.nanmean(NA0_T_mri_str[:,:,tmplon] - cont_T_mri_str[:,:,tmplon],2)
tmpp = np.nanmean( cont_pass_mri_str[:,:,tmplon],2)
tmpw = np.nanmean( wind_T_mri_str[:,:,tmplon]- cont_T_mri_str[:,:,tmplon],2)
tmpf = np.nanmean( water_T_mri_str[:,:,tmplon]- cont_T_mri_str[:,:,tmplon],2)

axs.plot(wind, tmph ,  color='red')
#axs[0].contour(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_U_can_str[:,:,tmplon],2) , levels = [-0.075,-0.05,-0.03,-0.02,0,0.02,0.05,0.075,0.1,0.125], colors='gray')
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(np.diff(cont_T_dif_can_str[:,:,tmplon],axis=1),2),vmin = -vm, vmax = vm, levels=20)
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_pass_can_str[:,:,tmplon],2) ,vmin = -vm, vmax = vm, levels=20)
#axs.plot( wind, np.sum(tmpNA*depinc,0)/sum(depinc), color= 'orange')
axs.plot( wind, np.sum(tmpp*depinc,0)/sum(depinc), color= '#a65628')
axs.plot( wind, np.sum(tmpw*depinc,0)/sum(depinc), color= 'blue')
axs.plot( wind, np.sum(tmpf*depinc,0)/sum(depinc), color= 'green')

MRIwindow = wind
MRIplheat = tmph
MRIplwind = np.sum(tmpw*depinc,0)/sum(depinc)
MRIplwater = np.sum(tmpf*depinc,0)/sum(depinc)
MRIplpass = np.sum(tmpp*depinc,0)/sum(depinc)
#MRIplHF = plHF/fac
MRIlims = [-0.3, 1]  

## velocities here!


tmpcontu = np.nanmean(cont_U_mri_str[:,:,tmplon],2)
tmphu = np.nanmean( heat_U_mri_str[:,:,tmplon]- cont_U_mri_str[:,:,tmplon],2)
tmpwu = np.nanmean( wind_U_mri_str[:,:,tmplon]- cont_U_mri_str[:,:,tmplon],2)
tmpfu = np.nanmean( water_U_mri_str[:,:,tmplon]- cont_U_mri_str[:,:,tmplon],2)

MRIplcont_u = np.sum(tmpcontu*depinc,0)/sum(depinc)
MRIplwind_u = np.sum(tmpwu*depinc,0)/sum(depinc)
MRIplwater_u= np.sum(tmpfu*depinc,0)/sum(depinc)
MRIplheat_u = np.sum(tmphu*depinc,0)/sum(depinc)

#yy, zz = np.meshgrid(latfile[mylat,0],  depf[mnum]* depfile[regdep])
#yy2, zz2 = np.meshgrid(latfile[np.arange(lats,latn-1),0],  depf[mnum]* depfile[regdep])

plt.plot( [-3,-3], [-0.5, 1.5], linestyle='dashed', color='black', linewidth = 1.5)
plt.plot( [4,4],  [-0.5, 1.5], linestyle='dashed', color='black', linewidth = 1.5)
#plt.legend(['faf-heat', 'faf-passiveheat','faf-stress'])
plt.legend(['faf-heat', 'faf-passiveheat','faf-stress', 'faf-water'])
axs.set_ylim(MRIlims)
#plt.savefig('SISAZ_figures/CanESM_Tlines_Apr24.eps')

axs.set_ylabel('$\Delta$ T ($^{\circ}$C)',size=14)
axs.set_xlabel('Degrees north of ARC-SAF     ', size=12)
#plt.savefig('SISAZ_figures/MRI_Tlines_May2.eps')
# FAFMIP data
#toPl0 = np.mean(pl_heat_theta[regdep,mylat,mylon] - pl_cont_theta[regdep,mylat,mylon],2)
#toPl0 = np.sum(toPl0* depinc,0)/sum(depinc)
#axs.plot(latfile[mylat,0], toPl0, color='red')

# haha! this is potentially really nice as well ...

# %%
#np.savez('MRI_ARCSAF_zint.npz', MRIplcont_u = MRIplcont_u, MRIplheat_u = MRIplheat_u, MRIplwind_u = MRIplwind_u, MRIplwater_u = MRIplwater_u,
#           MRIwindow= MRIwindow, MRIplheat = MRIplheat, MRIplwind = MRIplwind, MRIplwater = MRIplwater, MRIplpass =MRIplpass )


plt.plot(MRIplheat_u)
plt.plot(MRIplcont_u*0.1)
plt.plot(MRIplwind_u)
plt.plot(MRIplwater_u)
plt.plot(0*MRIplheat_u, 'k', linewidth =1)

# %%
depinc = np.array(depfile.diff('lev')[regdep])
depinc = depinc.reshape((len(depinc),1))
depinc[-1] = 2000 - sum(depinc[:-1])

# %%
# rewriting the CanESM code for MRI ... 

# what I'm doing here is the few degrees around the ARC-SAF minus 55-40 S. 
# 12 is the ARC-SAF .. 
# Need to identify latitude coordinates for 55-40 S. 

depinc = np.array(depfile.diff('lev')[regdep])
depinc = depinc.reshape((len(depinc),1))
depinc[-1] = 2000 - sum(depinc[:-1])

latncd = np.argmin(np.abs(np.array(-40 - latfile[:,0])))
latscd = np.argmin(np.abs(np.array(-55 - latfile[:,0])))
zmr = np.arange(latscd - mylat[0], latncd-mylat[0])


zmSST = pl_heat_theta.isel(y=mylat, x=mylon, lev=regdep) - pl_cont_theta.isel(y=mylat, x=mylon, lev=regdep)
zmSST = zmSST.mean('x')
ztst = np.sum(zmSST* depinc,0)/sum(depinc) # np.sum(tmph*depinc,0)/sum(depinc)
MRISSTdif = np.mean(MRIplheat[10:15]) - np.nanmean(ztst[zmr])


zmSSS =pl_water_theta.isel(y=mylat, x=mylon, lev=regdep) - pl_cont_theta.isel(y=mylat, x=mylon, lev=regdep)
zmSSS = zmSSS.mean('x')
ztst = np.sum(zmSSS*depinc,0) / sum(depinc) # np.sum(tmph*depinc,0)/sum(depinc)
MRISSSdif = np.mean(MRIplwater[10:15]) - np.nanmean(ztst[zmr])
#
zmW =pl_wind_theta.isel(y=mylat, x=mylon, lev=regdep) - pl_cont_theta.isel(y=mylat, x=mylon, lev=regdep)
zmW = zmW.mean('x')
ztst = np.sum(zmW*depinc,0) / sum(depinc) # np.sum(tmph*depinc,0)/sum(depinc)
MRIWdif = np.mean(MRIplwind[10:15]) - np.nanmean(ztst[zmr])

plt.bar([1,2,3],[MRISSTdif, MRISSSdif, MRIWdif])

# %%
MRISSTdif

# %% [markdown]
# ## GFDL work here

# %%
### Loading GFDL data here 


mnum = 0 # 0 = GFDL, 1 = MIROC, 2 = MRI, 3 = CanESM, 4 = CESM
mlist = ["GFDL","MIROC","MRI","CanESM","CESM"]


lats = -65
latn = -10  

sos = 12 # how many degrees south of streamline
nos = 20 # how many degrees north? Currently this is number of cells. 

lone = 20 # what's the deal with this? 
lonw = 150 # why are these backwards? 

vm = 0.05
vmT = 3
vmc = 0.2

#Drlon = -64.5 # drake passage lat
#Drlat = -55.5 # for defining SAF

pl_heat_u = xr.open_dataarray(foldern + mlist[mnum]+'_heat_u.nc')
pl_heat_theta = xr.open_dataarray(foldern + mlist[mnum]+'_heat_theta.nc')
#pl_heat_pass = xr.open_dataarray(foldern + mlist[mnum]+'_cont_pass.nc')
#pl_heat_sal = xr.open_dataarray(foldern + mlist[mnum]+'_heat_sal.nc')
pl_cont_u = xr.open_dataarray(foldern + mlist[mnum]+'_cont_u.nc')
pl_cont_pass = xr.open_dataarray(foldern + mlist[mnum]+'_cont_pass.nc')
pl_cont_theta = xr.open_dataarray(foldern + mlist[mnum]+'_cont_theta.nc')
#pl_cont_sal = xr.open_dataarray(foldern + mlist[mnum]+'_cont_sal.nc')
#pl_NA0_theta = xr.open_dataarray(foldern + mlist[mnum]+'_NA0_theta.nc')
#pl_NA0_u = xr.open_dataarray(foldern + mlist[mnum]+'_NA0_u.nc')
#pl_NA50_theta = xr.open_dataarray(foldern + mlist[mnum]+'_NA50_theta.nc')
#pl_NA50_u = xr.open_dataarray(foldern + mlist[mnum]+'_NA50_u.nc')
pl_wind_theta = xr.open_dataarray(foldern + mlist[mnum]+'_wind_theta.nc')
pl_wind_u = xr.open_dataarray(foldern + mlist[mnum]+'_wind_u.nc')
pl_water_theta = xr.open_dataarray(foldern + mlist[mnum]+'_water_theta.nc')
pl_water_u = xr.open_dataarray(foldern + mlist[mnum]+'_water_u.nc')
if mnum==0:
    lonfile = pl_heat_u.x
    latfile = pl_heat_u.y
    depfile = pl_heat_u.lev
    #pl_cont_sig0 = gsw.sigma0(pl_cont_sal, pl_cont_theta)
    #pl_cont_psi = psipass
    
    
#elif mnum in (1,2,3): 
#    lonfile = pl_cont_u.longitude
#    latfile = pl_cont_u.latitude
#    depfile = pl_cont_u.lev
#    pl_cont_sig0 = gsw.sigma0(pl_cont_sal, pl_cont_theta)
#    #if mnum==1: # better solution once I make a dictionary
#        #pl_cont_sig0 = MIROC_cont_sig0
#    #else:
#        #pl_cont_sig0 = 0*MIROC_cont_sig0
#    
#elif mnum ==4:
#    lonfile = pl_cont_u.lon
#    latfile = pl_cont_u.lat
#    depfile = pl_cont_u.lev
#    pl_cont_sig0 = 0*MIROC_cont_sig0
#
# 25 to 65 is the region that tends to work best in Indian Ocean. 
 # actual longitude - 80 please; 305 to 345 in Indian for GFDL and MRI
# MIROC is zeroed to 60, which is annoying! 
# and CANESM to 74 hahahah what the heck ... 
# and CESM is just awful. Don't even. 1.125 degrees smh.

# pick actual latitudes
lonmax = [80, 360, 360, 360, 360]
lonmin = [-280, 0, 0,0,0]

if lone>lonmax[mnum]:
    lone = lone - 360
if lone<lonmin[mnum]:
    lone = lone + 360
    
if lonw>lonmax[mnum]:
    lonw = lonw - 360
if lonw<lonmin[mnum]:
    lonw = lonw + 360
    
#if Drlon>lonmax[mnum]:
#    Drlon = Drlon - 360
#if Drlon<lonmin[mnum]:
#    Drlon = Drlon + 360    
    
lonecd = np.argmin(np.abs(np.array(lone - lonfile[:])))
lonwcd = np.argmin(np.abs(np.array(lonw - lonfile[:]))) 

latncd = np.argmin(np.abs(np.array(latn - latfile[:])))
latscd = np.argmin(np.abs(np.array(lats - latfile[:])))

#Drloncd = np.argmin(np.abs(np.array(Drlon - lonfile[0,:])))
#Drlatcd = np.argmin(np.abs(np.array(Drlat - latfile[:,0])))

if lonecd>lonwcd:
    lonecd = lonecd-360

mylat = np.arange(latscd,latncd)
mylon = np.arange(lonecd,lonwcd)

idealdepth = [40, 48, 48, 30, 46]
regdep = np.arange(0,idealdepth[mnum])

# %%
GAS = np.load('GFDL_ARCSAF.npz')
pl_ARCSAF_y = GAS['GFDL_ARCSAF_y']
ARCSAF_xco = GAS['lon_co']
SAFy = pl_ARCSAF_y[mylon - ARCSAF_xco[0]]
plt.plot(SAFy)

# %%
mylon

# %%
np.arange(-61,69)

# %%
## Streamline averaging 

# could update with a better version of ARC-SAF if desired! 

# For GFDL, uneven spacing north of 30, so need to interpolate

sos= 12 # integers please
nos = 20
wind = np.arange(-sos,nos)
winddif = np.arange(-sos-0.5, nos+0.5)

heat_T_gfdl_str = np.zeros([len(regdep), sos+nos, len(mylon)])
cont_T_gfdl_str = np.zeros([len(regdep), sos+nos, len(mylon)])
cont_pass_gfdl_str = np.zeros([len(regdep), sos+nos, len(mylon)])
cont_U_gfdl_str = np.zeros([len(regdep), sos+nos, len(mylon)])
heat_U_gfdl_str = np.zeros([len(regdep), sos+nos, len(mylon)])
#cont_T_dif_mri_str = np.zeros([len(regdep), sos+nos+1, len(mylon)])
#NA0_T_gfdl_str = np.zeros([len(regdep), sos+nos, len(mylon)])
#NA0_U_gfdl_str = np.zeros([len(regdep), sos+nos, len(mylon)])
#NA50_T_gfdl_str = np.zeros([len(regdep), sos+nos, len(mylon)])
#NA50_U_gfdl_str = np.zeros([len(regdep), sos+nos, len(mylon)])
wind_T_gfdl_str = np.zeros([len(regdep), sos+nos, len(mylon)])
wind_U_gfdl_str = np.zeros([len(regdep), sos+nos, len(mylon)])
water_T_gfdl_str = np.zeros([len(regdep), sos+nos, len(mylon)])
water_U_gfdl_str = np.zeros([len(regdep), sos+nos, len(mylon)])


#SAFy=np.interp(mylon + float(pl_cont_theta.x.isel(x=0)+360),SJFx,SJFy) 
GAS = np.load('GFDL_ARCSAF.npz')
pl_ARCSAF_y = GAS['GFDL_ARCSAF_y']
ARCSAF_xco = GAS['lon_co']
SAFy = pl_ARCSAF_y[mylon - ARCSAF_xco[0]]
# SAFy is just 130 long? yes! 

for i in np.arange(0,len(mylon)-1):
    # a is the actual latitude that we're looking at.
    a = SAFy[i] # use lm[mylon[i]] or strlat
    winda = a+ wind
    winddifa = a+ winddif
    for l in np.arange(0,len(regdep)):
        heat_T_gfdl_str[l,:,i] = np.interp(winda, latfile[mylat], pl_heat_theta.isel(lev=l, x=mylon[i],y= mylat))
        cont_T_gfdl_str[l,:,i] = np.interp(winda, latfile[mylat], pl_cont_theta.isel(lev=l, x=mylon[i],y= mylat))
        cont_pass_gfdl_str[l,:,i] = np.interp(winda, latfile[mylat], pl_cont_pass.isel(lev=l, x=mylon[i],y= mylat))
        #cont_T_dif_can_str[l,:,i] = np.interp(wi latfile[mylat],l(x=i), pl_cont_theta.isel(lev=l, x=mylon[i]))
        heat_U_gfdl_str[l,:,i] = np.interp(winda, latfile[mylat], pl_heat_u.isel(lev=l, x=mylon[i], y= mylat))
        cont_U_gfdl_str[l,:,i] = np.interp(winda, latfile[mylat], pl_cont_u.isel(lev=l, x=mylon[i], y=mylat))
        #NA0_T_gfdl_str[l,:,i] = np.interp(winda,  latfile[mylat], pl_NA0_theta.isel(lev=l, x=mylon[i],y= mylat))
        #NA0_U_gfdl_str[l,:,i] = np.interp(winda,  latfile[mylat], pl_NA0_u.isel(lev=l, x=mylon[i],y=mylat))
        #NA50_T_gfdl_str[l,:,i] = np.interp(winda, latfile[mylat], pl_NA50_theta.isel(lev=l, x=mylon[i],y= mylat))
        #NA50_U_gfdl_str[l,:,i] = np.interp(winda, latfile[mylat], pl_NA50_u.isel(lev=l, x=mylon[i],y=mylat))
        wind_T_gfdl_str[l,:,i] = np.interp(winda, latfile[mylat], pl_wind_theta.isel(lev=l, x=mylon[i],y= mylat))
        wind_U_gfdl_str[l,:,i] = np.interp(winda, latfile[mylat], pl_wind_u.isel(lev=l, x=mylon[i],y=mylat))
        water_T_gfdl_str[l,:,i] = np.interp(winda, latfile[mylat], pl_water_theta.isel(lev=l, x=mylon[i],y= mylat))
        water_U_gfdl_str[l,:,i] = np.interp(winda, latfile[mylat], pl_water_u.isel(lev=l, x=mylon[i],y=mylat))
        #SAFy=np.interp(np.arange(lonw,lone)+0 latfile[mylat],tr[:,:,i] = sald[wocedep, a-sos:a+nos, wocelon[i]]
    #heat_T_can_str[:,:,i] = pl_heat_theta[regdep, a-sos:a+nos,wocelon[i]]
    #cont_T_can_str[:,:,i] = pl_cont_theta[regdep, a-sos:a+nos,wocelon[i]]
    #cont_pass_can_str[:,:,i] = pl_cont_pass[regdep, a-sos:a+nos,wocelon[i]]

# %%
# Here I just want to implement enough to get those same averages.

## here's where I'll do just an ARC-SAF T line plots thing...

fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(6,5)) 
plt.set_cmap('bwr')

tmplon = np.arange(0,130) # this can be modified to look at a subsection of the region (20-150 E)
# - np.nanmean(cont_pass_can_str,2) #  np.nanmean(heat_T_can_str[:,:,tmplon],2)- np.nanmean(cont_T_can_str[:,:,tmplon],2) 

mylevs = np.arange(0,2.5,0.1)
# active
vm = 2.5

depinc = np.array(depfile.diff('lev')[regdep])
depinc = depinc.reshape((len(depinc),1))
depinc[-1] = 2000 - sum(depinc[:-1])

tmph = np.nanmean(heat_T_gfdl_str[:,:,tmplon] - cont_T_gfdl_str[:,:,tmplon],2)
tmph = np.sum(tmph*depinc,0)/sum(depinc)
#tmpNA = np.nanmean(NA0_T_mri_str[:,:,tmplon] - cont_T_mri_str[:,:,tmplon],2)
tmpp = np.nanmean( cont_pass_gfdl_str[:,:,tmplon],2)
tmpw = np.nanmean( wind_T_gfdl_str[:,:,tmplon]- cont_T_gfdl_str[:,:,tmplon],2)
tmpf = np.nanmean( water_T_gfdl_str[:,:,tmplon]- cont_T_gfdl_str[:,:,tmplon],2)

axs.plot(wind, tmph ,  color='red')
#axs[0].contour(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_U_can_str[:,:,tmplon],2) , levels = [-0.075,-0.05,-0.03,-0.02,0,0.02,0.05,0.075,0.1,0.125], colors='gray')
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(np.diff(cont_T_dif_can_str[:,:,tmplon],axis=1),2),vmin = -vm, vmax = vm, levels=20)
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_pass_can_str[:,:,tmplon],2) ,vmin = -vm, vmax = vm, levels=20)
#axs.plot( wind, np.sum(tmpNA*depinc,0)/sum(depinc), color= 'orange')
axs.plot( wind, np.sum(tmpp*depinc,0)/sum(depinc), color= '#a65628')
axs.plot( wind, np.sum(tmpw*depinc,0)/sum(depinc), color= 'blue')
axs.plot( wind, np.sum(tmpf*depinc,0)/sum(depinc), color= 'green')

GFDLwindow = wind
GFDLplheat = tmph
GFDLplwind = np.sum(tmpw*depinc,0)/sum(depinc)
GFDLplwater = np.sum(tmpf*depinc,0)/sum(depinc)
GFDLplpass = np.sum(tmpp*depinc,0)/sum(depinc)
#MRIplHF = plHF/fac
GFDLlims = [-0.3, 1]  

## velocities here!


tmpcontu=np.nanmean(cont_U_gfdl_str[:,:,tmplon],2)
tmphu = np.nanmean( heat_U_gfdl_str[:,:,tmplon]- cont_U_gfdl_str[:,:,tmplon],2)
tmpwu = np.nanmean( wind_U_gfdl_str[:,:,tmplon]- cont_U_gfdl_str[:,:,tmplon],2)
tmpfu =np.nanmean( water_U_gfdl_str[:,:,tmplon]- cont_U_gfdl_str[:,:,tmplon],2)

GFDLplcont_u = np.sum(tmpcontu*depinc,0)/sum(depinc)
GFDLplwind_u = np.sum(tmpwu*depinc,0)/sum(depinc)
GFDLplwater_u= np.sum(tmpfu*depinc,0)/sum(depinc)
GFDLplheat_u = np.sum(tmphu*depinc,0)/sum(depinc)

#yy, zz = np.meshgrid(latfile[mylat,0],  depf[mnum]* depfile[regdep])
#yy2, zz2 = np.meshgrid(latfile[np.arange(lats,latn-1),0],  depf[mnum]* depfile[regdep])

plt.plot( [-3,-3], [-0.5, 1.5], linestyle='dashed', color='black', linewidth = 1.5)
plt.plot( [4,4],  [-0.5, 1.5], linestyle='dashed', color='black', linewidth = 1.5)
#plt.legend(['faf-heat', 'faf-passiveheat','faf-stress'])
plt.legend(['faf-heat', 'faf-passiveheat','faf-stress', 'faf-water'])
#axs.set_ylim(MRIlims)
#plt.savefig('SISAZ_figures/CanESM_Tlines_Apr24.eps')

axs.set_ylabel('$\Delta$ T ($^{\circ}$C)',size=14)
axs.set_xlabel('Degrees north of ARC-SAF     ', size=12)
#plt.savefig('SISAZ_figures/MRI_Tlines_May2.eps')
# FAFMIP data
#toPl0 = np.mean(pl_heat_theta[regdep,mylat,mylon] - pl_cont_theta[regdep,mylat,mylon],2)
#toPl0 = np.sum(toPl0* depinc,0)/sum(depinc)
#axs.plot(latfile[mylat,0], toPl0, color='red')

# haha! this is potentially really nice as well ...

# %% [markdown]
# GFDL is clearly pretty disappointing - but goes to show that it's helpful to look at multiple models!
#
# I think it will be illuminating to consider wind stress anomalies together with these. Hopefully we can at least attach some of the trend in GFDL to a strong wind stress forcing.
#
# Another consideration would be whether the Atlantic is warming rapidly even in NA0 and NA50. But that's not ideal.

# %%
#np.savez('GFDL_ARCSAF_zint.npz', GFDLplcont_u = GFDLplcont_u, GFDLplheat_u = GFDLplheat_u, GFDLplwind_u = GFDLplwind_u, GFDLplwater_u = GFDLplwater_u,
#           GFDLwindow= GFDLwindow, GFDLplheat = GFDLplheat, GFDLplwind = GFDLplwind, GFDLplwater = GFDLplwater, GFDLplpass =GFDLplpass )
np.savez('MIROC_ARCSAF_zint.npz', MIROCplcont_u = MIROCplcont_u, MIROCplheat_u = MIROCplheat_u, MIROCplwind_u = MIROCplwind_u, MIROCplwater_u = MIROCplwater_u,
           MIROCwindow= MIROCwindow, MIROCplheat = MIROCplheat, MIROCplwind = MIROCplwind, MIROCplwater = MIROCplwater) #MIROCplpass =MIROCplpass )

# %%
plt.plot(GFDLplcont_u )
plt.plot(GFDLplwind_u )
plt.plot(GFDLplwater_u)
plt.plot(GFDLplheat_u )

## wow! This is crazy!! I'm enjoying this though. Apparently wind makes a big difference for GFDL.

# %%
## AMOC-related velocity changes

fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(18,5)) 
#plt.set_cmap('bwr')
plt.set_cmap('PRGn')

tmplon = np.arange(0,130) # 20 is 0 # - np.nanmean(cont_T_can_str[:,:,tmplon],2)- np.nanmean(cont_pass_can_str[:,:,tmplon],2)

# U change due to heat! 
vm = 0.02
#   - np.nanmean(cont_pass_can_str,2) #  np.nanmean(heat_T_can_str[:,:,tmplon],2)- np.nanmean(cont_T_can_str[:,:,tmplon],2) 
axs[0].contour(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_U_gfdl_str[:,:,tmplon],2) , levels = [-0.075,-0.05,-0.03,-0.02,0,0.02,0.05,0.075,0.1,0.125], colors='gray')
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(np.diff(cont_T_dif_can_str[:,:,tmplon],axis=1),2),vmin = -vm, vmax = vm, levels=20)
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_pass_can_str[:,:,tmplon],2) ,vmin = -vm, vmax = vm, levels=20)
A = axs[0].contourf(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(heat_U_gfdl_str[:,:,tmplon],2) - np.nanmean(cont_U_gfdl_str[:,:,tmplon],2)  , vmin = -vm, vmax = vm, levels=20)

# without North Atlantic
axs[1].contour(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_U_gfdl_str[:,:,tmplon],2) , levels = [-0.075,-0.05,-0.03,-0.02,0,0.02,0.05,0.075,0.1,0.125], colors='gray')
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(np.diff(cont_T_dif_can_str[:,:,tmplon],axis=1),2),vmin = -vm, vmax = vm, levels=20)
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_pass_can_str[:,:,tmplon],2) ,vmin = -vm, vmax = vm, levels=20)
B= axs[1].contourf(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(NA50_U_gfdl_str[:,:,tmplon],2) - np.nanmean(cont_U_gfdl_str[:,:,tmplon],2), vmin = -vm, vmax = vm, levels=20)

# SST minus North Atlantic
axs[2].contour(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_U_gfdl_str[:,:,tmplon],2) , levels = [-0.075,-0.05,-0.03,-0.02,0,0.02,0.05,0.075,0.1,0.125], colors='gray')
C= axs[2].contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(heat_U_gfdl_str[:,:,tmplon],2)- np.nanmean(NA50_U_gfdl_str[:,:,tmplon],2), vmin = -vm, vmax = vm, levels=20)

fig.colorbar(A, ax=axs[0])
fig.colorbar(B, ax=axs[1])
fig.colorbar(C, ax=axs[2])

# %%
## Active - passive means - GFDL?
# only issue is to get the subplots 1 and 2 to be same size

fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(18,5)) 
plt.set_cmap('bwr')

tmplon = np.arange(90,130) # this can be modified to look at a subsection of the region (20-150 E)
#   - np.nanmean(cont_pass_can_str,2) #  np.nanmean(heat_T_can_str[:,:,tmplon],2)- np.nanmean(cont_T_can_str[:,:,tmplon],2) 

# active
vm = 3
axs[0].contour(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_U_gfdl_str[:,:,tmplon],2) , levels = [-0.075,-0.05,-0.03,-0.02,0,0.02,0.05,0.075,0.1,0.125], colors='gray')
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(np.diff(cont_T_dif_can_str[:,:,tmplon],axis=1),2),vmin = -vm, vmax = vm, levels=20)
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_pass_can_str[:,:,tmplon],2) ,vmin = -vm, vmax = vm, levels=20)
A = axs[0].contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(heat_T_gfdl_str[:,:,tmplon],2)  -np.nanmean(cont_T_gfdl_str[:,:,tmplon],2) , vmin = -vm, vmax = vm, levels=20)

# passive
axs[1].contour(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_U_gfdl_str[:,:,tmplon],2) , levels = [-0.075,-0.05,-0.03,-0.02,0,0.02,0.05,0.075,0.1,0.125], colors='gray')
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(np.diff(cont_T_dif_can_str[:,:,tmplon],axis=1),2),vmin = -vm, vmax = vm, levels=20)
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_pass_can_str[:,:,tmplon],2) ,vmin = -vm, vmax = vm, levels=20)
B= axs[1].contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_pass_gfdl_str[:,:,tmplon],2) , vmin = -vm, vmax = vm, levels=20)


# difference 
vm = 1.5
#fig.colorbar(A, ax=axs[1])
axs[2].contour(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_U_gfdl_str[:,:,tmplon],2) , levels = [-0.075,-0.05,-0.03,-0.02,0,0.02,0.05,0.075,0.1,0.125], colors='gray')
C= axs[2].contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(heat_T_gfdl_str[:,:,tmplon], 2) - np.nanmean(cont_T_gfdl_str[:,:,tmplon], 2) - np.nanmean(cont_pass_gfdl_str[:,:,tmplon],2), vmin = -vm, vmax = vm, levels=20)

fig.colorbar(A, ax=axs[0])
fig.colorbar(B, ax=axs[1])
fig.colorbar(C, ax=axs[2])

# %% [markdown]
# ### MIROC analysis (quick and dirty)

# %%
### Loading MIROC


mnum = 1 # 0 = GFDL, 1 = MIROC, 2 = MRI, 3 = CanESM, 4 = CESM
mlist = ["GFDL","MIROC","MRI","CanESM","CESM"]


lats = -65
latn = -10  

sos = 12 # how many degrees south of streamline
nos = 20 # how many degrees north? Currently this is number of cells. 

lone = 20 # what's the deal with this? 
lonw = 150 # why are these backwards? 

vm = 0.05
vmT = 3
vmc = 0.2

#Drlon = -64.5 # drake passage lat
#Drlat = -55.5 # for defining SAF

pl_heat_u = xr.open_dataarray(foldern + mlist[mnum]+'_heat_u.nc')
pl_heat_theta = xr.open_dataarray(foldern + mlist[mnum]+'_heat_theta.nc')
#pl_heat_pass = xr.open_dataarray(foldern + mlist[mnum]+'_cont_pass.nc')
#pl_heat_sal = xr.open_dataarray(foldern + mlist[mnum]+'_heat_sal.nc')
pl_cont_u = xr.open_dataarray(foldern + mlist[mnum]+'_cont_u.nc')
#pl_cont_pass = xr.open_dataarray(foldern + mlist[mnum]+'_cont_pass.nc')
pl_cont_theta = xr.open_dataarray(foldern + mlist[mnum]+'_cont_theta.nc')
#pl_cont_sal = xr.open_dataarray(foldern + mlist[mnum]+'_cont_sal.nc')
#pl_NA0_theta = xr.open_dataarray(foldern + mlist[mnum]+'_NA0_theta.nc')
#pl_NA0_u = xr.open_dataarray(foldern + mlist[mnum]+'_NA0_u.nc')
#pl_NA50_theta = xr.open_dataarray(foldern + mlist[mnum]+'_NA50_theta.nc')
#pl_NA50_u = xr.open_dataarray(foldern + mlist[mnum]+'_NA50_u.nc')
pl_wind_theta = xr.open_dataarray(foldern + mlist[mnum]+'_wind_theta.nc')
pl_wind_u = xr.open_dataarray(foldern + mlist[mnum]+'_wind_u.nc')
pl_water_theta = xr.open_dataarray(foldern + mlist[mnum]+'_water_theta.nc')
pl_water_u = xr.open_dataarray(foldern + mlist[mnum]+'_water_u.nc')
#if mnum==0:
#    lonfile = pl_heat_u.x
#    latfile = pl_heat_u.y
#    depfile = pl_heat_u.lev
#    #pl_cont_sig0 = gsw.sigma0(pl_cont_sal, pl_cont_theta)
#    #pl_cont_psi = psipass
#    
    
if mnum in (1,2,3): 
    lonfile = pl_cont_u.longitude
    latfile = pl_cont_u.latitude
    depfile = pl_cont_u.lev
    #pl_cont_sig0 = gsw.sigma0(pl_cont_sal, pl_cont_theta)
    #if mnum==1: # better solution once I make a dictionary
        #pl_cont_sig0 = MIROC_cont_sig0
    #else:
        #pl_cont_sig0 = 0*MIROC_cont_sig0
    
#elif mnum ==4:
#    lonfile = pl_cont_u.lon
#    latfile = pl_cont_u.lat
#    depfile = pl_cont_u.lev
#    pl_cont_sig0 = 0*MIROC_cont_sig0
#
# 25 to 65 is the region that tends to work best in Indian Ocean. 
 # actual longitude - 80 please; 305 to 345 in Indian for GFDL and MRI
# MIROC is zeroed to 60, which is annoying! 
# and CANESM to 74 hahahah what the heck ... 
# and CESM is just awful. Don't even. 1.125 degrees smh.

# pick actual latitudes
lonmax = [80, 360, 360, 360, 360]
lonmin = [-280, 0, 0,0,0]

if lone>lonmax[mnum]:
    lone = lone - 360
if lone<lonmin[mnum]:
    lone = lone + 360
    
if lonw>lonmax[mnum]:
    lonw = lonw - 360
if lonw<lonmin[mnum]:
    lonw = lonw + 360
    
#if Drlon>lonmax[mnum]:
#    Drlon = Drlon - 360
#if Drlon<lonmin[mnum]:
#    Drlon = Drlon + 360    
    
lonecd = np.argmin(np.abs(np.array(lone - lonfile[0,:])))
lonwcd = np.argmin(np.abs(np.array(lonw - lonfile[0,:]))) 

latncd = np.argmin(np.abs(np.array(latn - latfile[:,0])))
latscd = np.argmin(np.abs(np.array(lats - latfile[:,0])))

#Drloncd = np.argmin(np.abs(np.array(Drlon - lonfile[0,:])))
#Drlatcd = np.argmin(np.abs(np.array(Drlat - latfile[:,0])))

if lonecd>lonwcd:
    lonecd = lonecd-360

mylat = np.arange(latscd,latncd)
mylon = np.arange(lonecd,lonwcd)

idealdepth = [40, 48, 48, 30, 46]
regdep = np.arange(0,idealdepth[mnum])

# %%
MAS = np.load('MIROC_ARCSAF.npz')
pl_ARCSAF_y = MAS['MIROC_ARCSAF_y']
ARCSAF_xco = MAS['lon_co']
SAFy = pl_ARCSAF_y[mylon - ARCSAF_xco[0]]
# SAFy is just 130 long? yes!
#plt.plot(SAFy)

# %%
mylat

# %%
## Streamline averaging 

# could update with a better version of ARC-SAF if desired! 

# For GFDL, uneven spacing north of 30, so need to interpolate

sos= 12 # integers please
nos = 20
wind = np.arange(-sos,nos)
winddif = np.arange(-sos-0.5, nos+0.5)

heat_T_miroc_str = np.zeros([len(regdep), sos+nos, len(mylon)])
cont_T_miroc_str = np.zeros([len(regdep), sos+nos, len(mylon)])
cont_U_miroc_str = np.zeros([len(regdep), sos+nos, len(mylon)])
heat_U_miroc_str = np.zeros([len(regdep), sos+nos, len(mylon)])
wind_T_miroc_str = np.zeros([len(regdep), sos+nos, len(mylon)])
wind_U_miroc_str = np.zeros([len(regdep), sos+nos, len(mylon)])
water_T_miroc_str = np.zeros([len(regdep), sos+nos, len(mylon)])
water_U_miroc_str = np.zeros([len(regdep), sos+nos, len(mylon)])


#SAFy=np.interp(mylon + float(pl_cont_theta.x.isel(x=0)+360),SJFx,SJFy) 
MAS = np.load('MIROC_ARCSAF.npz')
pl_ARCSAF_y = MAS['MIROC_ARCSAF_y']
ARCSAF_xco = MAS['lon_co']
SAFy = pl_ARCSAF_y[mylon - ARCSAF_xco[0]]
# SAFy is just 130 long? yes! 

for i in np.arange(0,len(mylon)-1):
    # a is the actual latitude that we're looking at.
    a = SAFy[i] # use lm[mylon[i]] or strlat
    winda = a+ wind
    winddifa = a+ winddif
    for l in np.arange(0,len(regdep)):
        heat_T_miroc_str[l,:,i]  = np.interp(winda, latfile[mylat,0], pl_heat_theta.isel(lev=l, x=mylon[i],y= mylat))
        cont_T_miroc_str[l,:,i]  = np.interp(winda, latfile[mylat,0], pl_cont_theta.isel(lev=l, x=mylon[i],y= mylat))
        heat_U_miroc_str[l,:,i]  = np.interp(winda, latfile[mylat,0], pl_heat_u.isel(lev=l, x=mylon[i], y= mylat))
        cont_U_miroc_str[l,:,i]  = np.interp(winda, latfile[mylat,0], pl_cont_u.isel(lev=l, x=mylon[i], y=mylat))
        wind_T_miroc_str[l,:,i]  = np.interp(winda, latfile[mylat,0], pl_wind_theta.isel(lev=l, x=mylon[i],y= mylat))
        wind_U_miroc_str[l,:,i]  = np.interp(winda, latfile[mylat,0], pl_wind_u.isel(lev=l, x=mylon[i],y=mylat))
        water_T_miroc_str[l,:,i] = np.interp(winda, latfile[mylat,0], pl_water_theta.isel(lev=l, x=mylon[i],y= mylat))
        water_U_miroc_str[l,:,i] = np.interp(winda, latfile[mylat,0], pl_water_u.isel(lev=l, x=mylon[i],y=mylat))
        #SAFy=np.interp(np.arange(lonw,lone)+0 latfile[mylat],tr[:,:,i] = sald[wocedep, a-sos:a+nos, wocelon[i]]
    #heat_T_can_str[:,:,i] = pl_heat_theta[regdep, a-sos:a+nos,wocelon[i]]
    #cont_T_can_str[:,:,i] = pl_cont_theta[regdep, a-sos:a+nos,wocelon[i]]
    #cont_pass_can_str[:,:,i] = pl_cont_pass[regdep, a-sos:a+nos,wocelon[i]]

# %%
# this is great. Probably a mapped view may be helpful for people to be sure of what they're seeing. 
# Another concern is that I should definitely include a wind stress change plot. That will be helpful to people, I think.
# 
## here's where I'll do just an ARC-SAF T line plots thing...

fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(6,5)) 
plt.set_cmap('bwr')

tmplon = np.arange(0,130) # this can be modified to look at a subsection of the region (20-150 E)
#   - np.nanmean(cont_pass_can_str,2) #  np.nanmean(heat_T_can_str[:,:,tmplon],2)- np.nanmean(cont_T_can_str[:,:,tmplon],2) 

mylevs = np.arange(0,2.5,0.1)
# active
vm = 2.5

depinc = np.array(depfile.diff('lev')[regdep])
depinc = depinc.reshape((len(depinc),1))
depinc[-1] = 2000 - sum(depinc[:-1])

tmph = np.nanmean(heat_T_miroc_str[:,:,tmplon] - cont_T_miroc_str[:,:,tmplon],2)
tmph = np.sum(tmph*depinc,0)/sum(depinc)
#tmpNA = np.nanmean(NA0_T_mri_str[:,:,tmplon] - cont_T_mri_str[:,:,tmplon],2)
#tmpp = np.nanmean( cont_pass_mri_str[:,:,tmplon],2)
tmpw = np.nanmean( wind_T_miroc_str[:,:,tmplon]- cont_T_miroc_str[:,:,tmplon],2)
tmpf = np.nanmean( water_T_miroc_str[:,:,tmplon]- cont_T_miroc_str[:,:,tmplon],2)

axs.plot(wind, tmph ,  color='red')
#axs[0].contour(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_U_can_str[:,:,tmplon],2) , levels = [-0.075,-0.05,-0.03,-0.02,0,0.02,0.05,0.075,0.1,0.125], colors='gray')
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(np.diff(cont_T_dif_can_str[:,:,tmplon],axis=1),2),vmin = -vm, vmax = vm, levels=20)
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_pass_can_str[:,:,tmplon],2) ,vmin = -vm, vmax = vm, levels=20)
#axs.plot( wind, np.sum(tmpNA*depinc,0)/sum(depinc), color= 'orange')
#axs.plot( wind, np.sum(tmpp*depinc,0)/sum(depinc), color= '#a65628')
axs.plot( wind, np.sum(tmpw*depinc,0)/sum(depinc), color= 'blue')
axs.plot( wind, np.sum(tmpf*depinc,0)/sum(depinc), color= 'green')

MIROCwindow = wind
MIROCplheat = tmph
MIROCplwind = np.sum(tmpw*depinc,0)/sum(depinc)
MIROCplwater = np.sum(tmpf*depinc,0)/sum(depinc)
#MRIplpass = np.sum(tmpp*depinc,0)/sum(depinc)
#MRIplHF = plHF/fac
MRIlims = [-0.3, 1]  

## velocities here!


tmpcontu =np.nanmean(cont_U_miroc_str[:,:,tmplon],2)
tmphu =  np.nanmean( heat_U_miroc_str[:,:,tmplon]- cont_U_miroc_str[:,:,tmplon],2)
tmpwu =  np.nanmean( wind_U_miroc_str[:,:,tmplon]- cont_U_miroc_str[:,:,tmplon],2)
tmpfu = np.nanmean( water_U_miroc_str[:,:,tmplon]- cont_U_miroc_str[:,:,tmplon],2)

MIROCplcont_u = np.sum(tmpcontu*depinc,0)/sum(depinc)
MIROCplwind_u = np.sum(tmpwu*depinc,0)/sum(depinc)
MIROCplwater_u= np.sum(tmpfu*depinc,0)/sum(depinc)
MIROCplheat_u = np.sum(tmphu*depinc,0)/sum(depinc)

#yy, zz = np.meshgrid(latfile[mylat,0],  depf[mnum]* depfile[regdep])
#yy2, zz2 = np.meshgrid(latfile[np.arange(lats,latn-1),0],  depf[mnum]* depfile[regdep])

plt.plot( [-3,-3], [-0.5, 1.5], linestyle='dashed', color='black', linewidth = 1.5)
plt.plot( [4,4],  [-0.5, 1.5], linestyle='dashed', color='black', linewidth = 1.5)
#plt.legend(['faf-heat', 'faf-passiveheat','faf-stress'])
plt.legend(['faf-heat', 'faf-passiveheat','faf-stress', 'faf-water'])
axs.set_ylim(MRIlims)
#plt.savefig('SISAZ_figures/CanESM_Tlines_Apr24.eps')

axs.set_ylabel('$\Delta$ T ($^{\circ}$C)',size=14)
axs.set_xlabel('Degrees north of ARC-SAF     ', size=12)
#plt.savefig('SISAZ_figures/MRI_Tlines_May2.eps')
# FAFMIP data
#toPl0 = np.mean(pl_heat_theta[regdep,mylat,mylon] - pl_cont_theta[regdep,mylat,mylon],2)
#toPl0 = np.sum(toPl0* depinc,0)/sum(depinc)
#axs.plot(latfile[mylat,0], toPl0, color='red')

# haha! this is potentially really nice as well ...

# %%
plt.plot(MIROCplcont_u )
plt.plot(MIROCplwind_u )
plt.plot(MIROCplwater_u)
plt.plot(MIROCplheat_u )

## wow! This is crazy!! I'm enjoying this though. Apparently wind makes a big difference for GFDL.

# %% [markdown]
# ### CESM1 experiment here

# %%
## Now for CESM - let's do the streamline average here. 

# Here I'm importing data from my experiments

#cont_u_4=xr.open_dataset('/nfs/data/TAULOCK_mluongo/Clim1a/ocn/UVEL/CC1_x2oOutput.pop.h.UVEL.004001-004912.nc')

foldert= 'TauLockMeans/'
cont_tm_4=xr.open_dataarray(foldert +'cont_tm_4.nc')
tau1_tm_4=xr.open_dataarray(foldert +'tau1_tm_4.nc')
cont_um_4=xr.open_dataarray(foldert +'cont_um_4.nc')
tau1_um_4=xr.open_dataarray(foldert +'tau1_um_4.nc')
coup_tm_4=xr.open_dataarray(foldert +'coup_tm_4.nc')
tau4_tm_4=xr.open_dataarray(foldert +'tau4_tm_4.nc')
coup_um_4=xr.open_dataarray(foldert +'coup_um_4.nc')

tau4_um_4=xr.open_dataarray(foldert +'tau4_um_4.nc')
coup2_tm_4=xr.open_dataset(foldert +'coup2_tm_4.nc')
coup2_tm_4 = coup2_tm_4.TEMP
tau2c1_tm_4=xr.open_dataset(foldert +'tau2c1_tm_4.nc')
tau2c1_tm_4= tau2c1_tm_4.TEMP
tau2c1_um_4=xr.open_dataset(foldert +'tau2c1_um_4.nc')
tau2c1_um_4 = tau2c1_um_4.UVEL
tau1c2_tm_4=xr.open_dataset(foldert +'tau1c2_tm_4.nc')
tau1c2_tm_4 = tau1c2_tm_4.TEMP
tau1c2_um_4=xr.open_dataset(foldert +'tau1c2_um_4.nc')
tau1c2_um_4 = tau1c2_um_4.UVEL
# we would also need v, which I doubt is saved, to make the map. 

depth = 2000
lonw = 20
lone = 150 ## change to 80 for nice results!
matlats = tau1_um_4.TLAT[:,0]
#matlatc = np.arange(np.argmin(np.abs(np.array(matlats-lats)))-1, np.argmin(np.abs(np.array(matlats-latn)))+1)
mylat = np.arange(0,140)
matlons = tau1_um_4.TLONG[0,:]
matlonc = np.arange(np.argmin(np.abs(np.array(matlons-lonw))), 1+np.argmin(np.abs(np.array(matlons-lone))))
matdepc = np.arange(0, 1+np.argmin(np.abs(np.array(tau1_um_4.z_t/100-depth))))

# %%
matlonc

# %%
ca = np.load('CESM1_ARCSAF.npz')
mat_ARCSAF_y = ca['CESM1_ARCSAF_y']
ARCSAF_xco = ca['lon_co']
SAFy = mat_ARCSAF_y[matlonc - ARCSAF_xco[0]]

# %%
## Streamline averaging 

# For CESM, uneven spacing all over the place, so need to interpolate

ca = np.load('CESM1_ARCSAF.npz')
mat_ARCSAF_y = ca['CESM1_ARCSAF_y']
ARCSAF_xco = ca['lon_co']
SAFy = mat_ARCSAF_y[matlonc - ARCSAF_xco[0]]

regdep = matdepc

sos= 12 # integers please
nos = 20
wind = np.arange(-sos,nos)
winddif = np.arange(-sos-0.5, nos+0.5)

#cont_pass_gfdl_str = np.zeros([len(regdep), sos+nos, len(mylon)])
cont_U_tau1_str = np.zeros([len(regdep), sos+nos, len(matlonc)])
heat_U_tau1_str = np.zeros([len(regdep), sos+nos, len(matlonc)])
heat_T_tau1_str = np.zeros([len(regdep), sos+nos, len(matlonc)])
cont_T_tau1_str = np.zeros([len(regdep), sos+nos, len(matlonc)])
wind_T_tau4_str = np.zeros([len(regdep), sos+nos, len(matlonc)])
coup_T_tau4_str = np.zeros([len(regdep), sos+nos, len(matlonc)])
wind_U_tau4_str = np.zeros([len(regdep), sos+nos, len(matlonc)])
coup_U_tau4_str = np.zeros([len(regdep), sos+nos, len(matlonc)])

#SAFy=np.interp(tau1_um_4.TLONG[0, matlonc],SJFx,SJFy) # observed ARC-SAF

# SAFy

for i in np.arange(0,len(matlonc)-1):
    # a is the actual latitude that we're looking at.
    a = SAFy[i] # use lm[mylon[i]] or strlat
    winda = a+ wind
    winddifa = a+ winddif
    for l in np.arange(0,len(regdep)):
        heat_T_tau1_str[l,:,i] = np.interp(winda, tau1_um_4.TLAT[mylat,0], tau1_tm_4.isel(z_t=l, nlon=matlonc[i], nlat= mylat))
        cont_T_tau1_str[l,:,i] = np.interp(winda, tau1_um_4.TLAT[mylat,0], cont_tm_4.isel(z_t=l, nlon=matlonc[i], nlat= mylat))
        wind_T_tau4_str[l,:,i] = np.interp(winda, tau1_um_4.TLAT[mylat,0], tau4_tm_4.isel(z_t=l, nlon=matlonc[i], nlat= mylat))

        wind_U_tau4_str[l,:,i] = np.interp(winda, tau1_um_4.TLAT[mylat,0], tau4_um_4.isel(z_t=l, nlon=matlonc[i], nlat= mylat))
        coup_T_tau4_str[l,:,i] = np.interp(winda, tau1_um_4.TLAT[mylat,0], coup_tm_4.isel(z_t=l, nlon=matlonc[i], nlat= mylat))
        #cont_T_dif_can_str[l,:,i] = np.interp(wi latfile[mylat],l(x=i), pl_cont_theta.isel(lev=l, x=mylon[i]))
        heat_U_tau1_str[l,:,i] = np.interp(winda, tau1_um_4.TLAT[mylat,0], tau1_um_4.isel(z_t=l, nlon=matlonc[i], nlat= mylat))
        cont_U_tau1_str[l,:,i] = np.interp(winda, tau1_um_4.TLAT[mylat,0], cont_um_4.isel(z_t=l, nlon=matlonc[i], nlat=mylat))
        coup_U_tau4_str[l,:,i] = np.interp(winda, tau1_um_4.TLAT[mylat,0], coup_um_4.isel(z_t=l, nlon=matlonc[i], nlat= mylat))

        #SAFy=np.interp(np.arange(lonw,lone)+0 latfile[mylat],tr[:,:,i] = sald[wocedep, a-sos:a+nos, wocelon[i]]
    #heat_T_can_str[:,:,i] = pl_heat_theta[regdep, a-sos:a+nos,wocelon[i]]
    #cont_T_can_str[:,:,i] = pl_cont_theta[regdep, a-sos:a+nos,wocelon[i]]
    #cont_pass_can_str[:,:,i] = pl_cont_pass[regdep, a-sos:a+nos,wocelon[i]]

# %%
tstp = np.concatenate([np.arange(0,48), np.arange(64,116)])
tstp

# %%
tau1_um_4.TLONG[0,53+tstp] 
cutl=tstp

# %%
plt.contourf(np.nanmean(cont_U_tau1_str[:,:,tstp],2))#heat_U_tau1_str[0,:,tstp]-cont_U_tau1_str[0,:,tstp], vmin= -5, vmax = 5)
plt.colorbar()

# %%
# u changes

fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(6,5)) 
plt.set_cmap('PRGn')

tmplon = np.arange(0,130) # 20 is 0 # - np.nanmean(cont_T_can_str[:,:,tmplon],2)- np.nanmean(cont_pass_can_str[:,:,tmplon],2)

## U change due to heat! 
#vm = 0.02
##   - np.nanmean(cont_pass_can_str,2) #  np.nanmean(heat_T_can_str[:,:,tmplon],2)- np.nanmean(cont_T_can_str[:,:,tmplon],2) 
#axs[0].contour(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_U_gfdl_str[:,:,tmplon],2) , levels = [-0.075,-0.05,-0.03,-0.02,0,0.02,0.05,0.075,0.1,0.125], colors='gray')
##plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(np.diff(cont_T_dif_can_str[:,:,tmplon],axis=1),2),vmin = -vm, vmax = vm, levels=20)
##plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_pass_can_str[:,:,tmplon],2) ,vmin = -vm, vmax = vm, levels=20)
#A = axs[0].contourf(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(heat_U_gfdl_str[:,:,tmplon],2) - np.nanmean(cont_U_gfdl_str[:,:,tmplon],2)  , vmin = -vm, vmax = vm, levels=20)
#
#fig.colorbar(A, ax=axs[2])
um = 2

C = axs.contourf(wind, -tau1_um_4.z_t[matdepc]/100, (np.nanmean(wind_U_tau4_str[:,:,tstp],2) - np.nanmean(cont_U_tau1_str[:,:,tstp],2)), vmin = -um, vmax=um, levels=50)
# Matt's contours.

#cvals = np.arange(-0.02, 0.02, 30)
axs.contour(wind, -tau1_um_4.z_t[matdepc]/100, np.nanmean(cont_U_tau1_str[:,:,tstp],2), colors='grey',  levels = 15)
axs.set_ylim(-depth*10,0)
axs.set_xlim(-sos,nos-1)
plt.colorbar(C)


#Ccb= fig.colorbar(C, ax=axs)

#Ccb.set_label("$\Delta$u, cm/s",fontsize = 'large')


axs.plot(0*-tau1_um_4.z_t[matdepc]/100 -3, -tau1_um_4.z_t[matdepc]/100, linestyle='dashed', color='black', linewidth = 1.5)
axs.plot(0*-tau1_um_4.z_t[matdepc]/100 +5, -tau1_um_4.z_t[matdepc]/100, linestyle='dashed', color='black', linewidth = 1.5)

# %%
# warming pattern 

fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(6,5)) 
plt.set_cmap('bwr')

tmplon = np.arange(0,130) # 20 is 0 # - np.nanmean(cont_T_can_str[:,:,tmplon],2)- np.nanmean(cont_pass_can_str[:,:,tmplon],2)

## U change due to heat! 
#vm = 0.02
##   - np.nanmean(cont_pass_can_str,2) #  np.nanmean(heat_T_can_str[:,:,tmplon],2)- np.nanmean(cont_T_can_str[:,:,tmplon],2) 
#axs[0].contour(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_U_gfdl_str[:,:,tmplon],2) , levels = [-0.075,-0.05,-0.03,-0.02,0,0.02,0.05,0.075,0.1,0.125], colors='gray')
##plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(np.diff(cont_T_dif_can_str[:,:,tmplon],axis=1),2),vmin = -vm, vmax = vm, levels=20)
##plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_pass_can_str[:,:,tmplon],2) ,vmin = -vm, vmax = vm, levels=20)
#A = axs[0].contourf(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(heat_U_gfdl_str[:,:,tmplon],2) - np.nanmean(cont_U_gfdl_str[:,:,tmplon],2)  , vmin = -vm, vmax = vm, levels=20)

#fig.colorbar(A, ax=axs[2])
um = 3.5

C = axs.contourf(wind, -tau1_um_4.z_t[matdepc]/100, (np.nanmean(wind_T_tau4_str,2) - np.nanmean(cont_T_tau1_str,2)), vmin = -um, vmax=um, levels=50)
# Matt's contours.

#cvals = np.arange(-0.02, 0.02, 30)
axs.contour(wind, -tau1_um_4.z_t[matdepc]/100, np.nanmean(cont_U_tau1_str,2), colors='grey',  levels = 15)
axs.set_ylim(-depth,0)
axs.set_xlim(-sos,nos-1)
plt.colorbar(C)


#Ccb= fig.colorbar(C, ax=axs)

#Ccb.set_label("$\Delta$u, cm/s",fontsize = 'large')


axs.plot(0*-tau1_um_4.z_t[matdepc]/100 -3, -tau1_um_4.z_t[matdepc]/100, linestyle='dashed', color='black', linewidth = 1.5)
axs.plot(0*-tau1_um_4.z_t[matdepc]/100 +5, -tau1_um_4.z_t[matdepc]/100, linestyle='dashed', color='black', linewidth = 1.5)

# %%
#depinc[-1] = 200000 - sum(depinc[:-1])

# %%
# plotting depth-average temperature change in top 2181 m. 
ax= plt.axes()
depinc = np.array(tau1_um_4.z_t.diff('z_t')[matdepc])
depinc = depinc.reshape((len(depinc),1))


heat1 = np.nanmean(heat_T_tau1_str,2) - np.nanmean(cont_T_tau1_str,2)
wind1 = np.nanmean(wind_T_tau4_str,2) - np.nanmean(cont_T_tau1_str,2)
coup1 = np.nanmean(coup_T_tau4_str,2) - np.nanmean(cont_T_tau1_str,2)



plt.plot(wind, sum(heat1*depinc,0)/sum(depinc), color = 'red')
plt.plot(wind, sum(wind1*depinc,0)/sum(depinc), color = 'blue')
plt.plot(wind, sum(coup1*depinc,0)/sum(depinc), color = 'violet')

plt.plot( [-3,-3], [-0.5, 1.5], linestyle='dashed', color='black', linewidth = 1.5)
plt.plot( [4,4],  [-0.5, 1.5], linestyle='dashed', color='black', linewidth = 1.5)
plt.legend(['Buoyancy', 'Stress', 'Coupled'])
ax.set_ylim([-0.1, 1.3])

CESMwindow = wind
CESMplheat = sum(heat1*depinc,0)/sum(depinc)
CESMplwind =sum(wind1*depinc,0)/sum(depinc)
CESMplcoup =sum(coup1*depinc,0)/sum(depinc)
CESMlims = [-0.1,1.3]

# %%
## CESM - this one is important! 

# what I'm doing here is the few degrees around the ARC-SAF minus 55-40 S. 
# 12 is the ARC-SAF ..
depinc = np.array(tau1_um_4.z_t.diff('z_t')[matdepc])
depinc = depinc.reshape((len(depinc),1))
depinc[-1] = 200000 - sum(depinc[:-1])

CESMplheat = sum(heat1*depinc,0)/sum(depinc)
CESMplwind = sum(wind1*depinc,0)/sum(depinc)
CESMplcoup = sum(coup1*depinc,0)/sum(depinc) 

matzmc = np.arange(np.argmin(np.abs(np.array(matlats+55))), 1+np.argmin(np.abs(np.array(matlats+40))))

zmSST = np.nanmean(tau1_tm_4[:,:,matlonc] - cont_tm_4[:,:,matlonc], 2)
ztst = np.nansum(zmSST[matdepc,:]*depinc,0) / sum(depinc)
Buoydif = np.mean(CESMplheat[10:15]) - np.nanmean(ztst[matzmc])

zmSST = np.nanmean(tau4_tm_4[:,:,matlonc] - cont_tm_4[:,:,matlonc], 2)
ztst = np.nansum(zmSST[matdepc,:]*depinc,0) / sum(depinc)
Taudif = np.mean(CESMplwind[10:15]) - np.nanmean(ztst[matzmc])

zmSST = np.nanmean(coup_tm_4[:,:,matlonc] - cont_tm_4[:,:,matlonc], 2)
ztst = np.nansum(zmSST[matdepc,:]*depinc,0) / sum(depinc)
Coupdif = np.mean(CESMplcoup[10:15]) - np.nanmean(ztst[matzmc])



plt.bar([1,2,3],[Buoydif, Taudif, Coupdif])

# %% [markdown]
# ### Assembling Fig 7

# %%
# Load vertical integral data for all the FAFMIP runs. 
MIROCz = np.load('MIROC_ARCSAF_zint.npz')
MRIz = np.load('MRI_ARCSAF_zint.npz')
Canz = np.load('CanESM_ARCSAF_zint.npz')
GFDLz = np.load('GFDL_ARCSAF_zint.npz')

# %%
# here is the Full Fig 7 piece. 

# this is where I omit the problem region!!
cutl = np.concatenate([np.arange(0,48), np.arange(64,116)])

fig, axs = plt.subplots(nrows=4, ncols=2, figsize=(10,11),  constrained_layout=True) 
#fig.tight_layout()

plt.set_cmap('PRGn')
um=3
Uh = axs[0,1].contourf(wind, -tau1_um_4.z_t[matdepc]/100, (np.nanmean(heat_U_tau1_str[:,:,cutl],2) - np.nanmean(cont_U_tau1_str[:,:,cutl],2)), vmin = -um, vmax=um, levels=50)
Uw = axs[1,1].contourf(wind, -tau1_um_4.z_t[matdepc]/100, (np.nanmean(wind_U_tau4_str[:,:,cutl],2) - np.nanmean(cont_U_tau1_str[:,:,cutl],2)), vmin = -um, vmax=um, levels=50)


plt.set_cmap('bwr')

#tmplon = np.arange(0,130) # 20 is 0 # - np.nanmean(cont_T_can_str[:,:,tmplon],2)- np.nanmean(cont_pass_can_str[:,:,tmplon],2)

tmh = 3.5
tmw = 1
Th = axs[0,0].contourf(wind, -tau1_um_4.z_t[matdepc]/100, (np.nanmean(heat_T_tau1_str[:,:,cutl],2) - np.nanmean(cont_T_tau1_str[:,:,cutl],2)), vmin = -tmh, vmax=tmh, levels=30)
Tw = axs[1,0].contourf(wind, -tau1_um_4.z_t[matdepc]/100, (np.nanmean(wind_T_tau4_str[:,:,cutl],2) - np.nanmean(cont_T_tau1_str[:,:,cutl],2)), vmin = -tmw, vmax=tmw, levels=30)
# Matt's contours.

#cvals = np.arange(-0.02, 0.02, 30)

for j in range(2):
    for i in range(2):
        axs[i,j].contour(wind, -tau1_um_4.z_t[matdepc]/100, np.nanmean(cont_U_tau1_str[:,:,cutl],2), colors='grey',  levels = 15)
        axs[i,j].set_ylim(-2000,0)
        #axs[i,j].set_xlim(-sos,nos-1)
    for i in range(4):
        axs[i,j].set_xlim(-sos,nos-1)
        
depinc = np.array(tau1_um_4.z_t.diff('z_t')[matdepc])
depinc = depinc.reshape((len(depinc),1))
depinc[-1] = 200000 - sum(depinc[:-1])


heat1 = np.nanmean(heat_T_tau1_str[:,:,cutl],2) - np.nanmean(cont_T_tau1_str[:,:,cutl],2)
wind1 = np.nanmean(wind_T_tau4_str[:,:,cutl],2) - np.nanmean(cont_T_tau1_str[:,:,cutl],2)
coup1 = np.nanmean(coup_T_tau4_str[:,:,cutl],2) - np.nanmean(cont_T_tau1_str[:,:,cutl],2)


heatUz = np.nanmean(heat_U_tau1_str[:,:,cutl],2) - np.nanmean(cont_U_tau1_str[:,:,cutl],2)
windUz = np.nanmean(wind_U_tau4_str[:,:,cutl],2) - np.nanmean(cont_U_tau1_str[:,:,cutl],2)
coupUz = np.nanmean(coup_U_tau4_str[:,:,cutl],2) - np.nanmean(cont_U_tau1_str[:,:,cutl],2)
contUz = np.nanmean(cont_U_tau1_str[:,:,cutl],2)


#tmph = np.nanmean(heat_T_can_str[:,:,tmplon] - cont_T_can_str[:,:,tmplon],2)
#tmph = np.sum(tmph*depinc,0)/sum(depinc)

axs[2,0].plot(wind, sum(heat1*depinc,0)/sum(depinc), color = 'red')
axs[2,0].plot(wind, sum(wind1*depinc,0)/sum(depinc), color = 'gray')
axs[2,0].plot(wind, sum(coup1*depinc,0)/sum(depinc), color = 'violet')  

axs[2,1].plot(wind, sum(heatUz*depinc,0)/sum(depinc), color = 'red')
axs[2,1].plot(wind, sum(windUz*depinc,0)/sum(depinc), color = 'gray')
axs[2,1].plot(wind, sum(coupUz*depinc,0)/sum(depinc), color = 'violet')
axs[2,1].plot(wind, 0.2*sum(contUz*depinc,0)/sum(depinc), color = 'k')
axs[2,1].plot(wind, 0*wind, 'k-', linewidth = 1)

axs[2,0].set_ylabel('Avg. $\Delta$T ($^{\circ}$C)', size = 11)
axs[2,1].set_ylabel('Avg. $\Delta$U (cm/s)', size = 11)
axs[1,0].set_ylabel('z (m)')
axs[0,0].set_ylabel('z (m)')
axs[2,1].legend(['$\Delta$Buoyancy', '$\Delta$Wind Stress', 'Coupled (4xCO2)', '0.2*Control'])

CESMulims = [-1.5,2.5]
CESMtlims = [-0.3,1.5]
axs[2,0].plot([i * 0 for i in CESMtlims], CESMtlims, linestyle='dashed', linewidth = 1.5)
axs[2,1].plot([i*0 for i in CESMulims],CESMulims, linestyle='dashed', linewidth = 1.5)

axs[2,0].set_ylim(CESMtlims)
axs[2,1].set_ylim(CESMulims)

# FAFMIP model plotting ... 
lw = 0.75 
lw2 = 2

MIROCz = np.load('MIROC_ARCSAF_zint.npz')
MRIz = np.load('MRI_ARCSAF_zint.npz')
Canz = np.load('CanESM_ARCSAF_zint.npz')
GFDLz = np.load('GFDL_ARCSAF_zint.npz')

Canwindow = Canz['Canwindow']
MRIwindow = MRIz['MRIwindow']

MRIplheat   =MRIz['MRIplheat']
MRIplwater  =MRIz['MRIplwater']
MRIplwind   =MRIz['MRIplwind']
MRIplpass   =MRIz['MRIplpass']
Canplheat   =Canz['Canplheat']
Canplwater  =Canz['Canplwater']
Canplwind   =Canz['Canplwind']
Canplpass   =Canz['Canplpass']
GFDLplheat  =GFDLz['GFDLplheat'] 
GFDLplwater =GFDLz['GFDLplwater']
GFDLplwind  =GFDLz['GFDLplwind']
GFDLplpass  =GFDLz['GFDLplpass']
MIROCplheat =MIROCz['MIROCplheat']
MIROCplwater=MIROCz['MIROCplwater']
MIROCplwind =MIROCz['MIROCplwind']

MRIplheat_u   =MRIz['MRIplheat_u']
MRIplwater_u  =MRIz['MRIplwater_u']
MRIplwind_u   =MRIz['MRIplwind_u']
MRIplcont_u   =MRIz['MRIplcont_u']
Canplheat_u   =Canz['Canplheat_u']
Canplwater_u  =Canz['Canplwater_u']
Canplwind_u   =Canz['Canplwind_u']
Canplcont_u   =Canz['Canplcont_u']
GFDLplheat_u  =GFDLz['GFDLplheat_u'] 
GFDLplwater_u =GFDLz['GFDLplwater_u']
GFDLplwind_u  =GFDLz['GFDLplwind_u']
GFDLplcont_u  =GFDLz['GFDLplcont_u']
MIROCplheat_u = MIROCz['MIROCplheat_u']
MIROCplwater_u= MIROCz['MIROCplwater_u']
MIROCplwind_u =MIROCz['MIROCplwind_u']
MIROCplcont_u =MIROCz['MIROCplcont_u']


axs[3,0].plot(Canwindow, 0.25*(Canplheat + MRIplheat + MIROCplheat + GFDLplheat) ,  color='red',linewidth = lw2)
axs[3,0].plot(Canwindow, 0.25*(Canplwater + MRIplwater + MIROCplwater + GFDLplwater), color= '#377eb8',linewidth = lw2) 
axs[3,0].plot(Canwindow, 0.25*(Canplwind + MRIplwind + MIROCplwind + GFDLplwind), color= 'gray' ,linewidth = lw2)
axs[3,0].plot(Canwindow, 0.333* (Canplpass + MRIplpass + GFDLplpass), '#a65628' ,linewidth = lw2)

axs[3,0].legend(['faf-heat','faf-water','faf-stress','faf-passive',], ncol = 2, loc= 'lower right')#,'faf-water'])
axs[3,0].set_xlabel('Degrees north of mARC-SAF', size=11)
axs[3,0].set_ylabel('Avg. $\Delta$T ($^{\circ}$C)')
axs[3,0].set_ylim(MRIlims)

axs[3,0].plot(MRIwindow, MRIplheat ,  color='red', linewidth = lw)
axs[3,0].plot(MRIwindow, MRIplwater, color= '#377eb8',linewidth = lw)
axs[3,0].plot(MRIwindow, MRIplwind, color= 'gray',linewidth = lw )
axs[3,0].plot(MRIwindow, MRIplpass, color= '#a65628',linewidth = lw) 
#axs[3,0].plot( [-3,-3], [-0.5, 1.5], linestyle='dashed', color='black', linewidth = 1.5)
#axs[3,0].plot( [4,4],  [-0.5, 1.5], linestyle='dashed', color='black', linewidth = 1.5)

axs[3,0].plot(Canwindow, Canplheat ,  color='red',linewidth = lw)
axs[3,0].plot(Canwindow, Canplwater, color= '#377eb8',linewidth = lw )
axs[3,0].plot(Canwindow, Canplwind, color= 'gray',linewidth = lw) 
axs[3,0].plot(Canwindow, Canplpass,  color='#a65628',linewidth = lw)

axs[3,0].plot(Canwindow, GFDLplheat ,  color='red',linewidth = lw)
axs[3,0].plot(Canwindow, GFDLplwater, color= '#377eb8',linewidth = lw )
axs[3,0].plot(Canwindow, GFDLplwind, color= 'gray',linewidth = lw) 
axs[3,0].plot(Canwindow, GFDLplpass,  color='#a65628',linewidth = lw)

axs[3,0].plot(Canwindow, MIROCplheat ,  color='red',linewidth = lw)
axs[3,0].plot(Canwindow, MIROCplwater, color= '#377eb8',linewidth = lw )
axs[3,0].plot(Canwindow, MIROCplwind, color= 'gray',linewidth = lw) 
#axs[3,0].plot(Canwindow, MIROCplpass,  color='#a65628',linewidth = lw)



#axs[3,0].plot( [-3,-3], [-0.5, 1.5], linestyle='dashed', color='black', linewidth = 1.5)
#axs[3,0].plot( [4,4],  [-0.5, 1.5], linestyle='dashed', color='black', linewidth = 1.5)
#axs[3,0].legend(['faf-heat','faf-water','faf-stress','faf-passiveheat'])
#axs[3,0].set_xlabel('Degrees north of mARC-SAF', size=12)
#axs[3,0].set_ylim(Canlims)


# So many lines! I should make an array ... 

axs[3,1].plot(Canwindow, 25*(Canplheat_u + MRIplheat_u +MIROCplheat_u + GFDLplheat_u) ,  color='red',linewidth = lw2)
axs[3,1].plot(Canwindow, 25*(Canplwater_u +MRIplwater_u+MIROCplwater_u + GFDLplheat_u), color= '#377eb8',linewidth = lw2) 
axs[3,1].plot(Canwindow, 25*(Canplwind_u + MRIplwind_u+ MIROCplwind_u + GFDLplwind_u), color= 'gray' ,linewidth = lw2)
axs[3,1].plot(Canwindow, 5*(Canplcont_u + MRIplcont_u + MIROCplcont_u + GFDLplcont_u), 'k--' ,linewidth = lw2)

#axs[3,1].plot( [-3,-3], [-0.5, 1.5], linestyle='dashed', color='black', linewidth = 1.5)
#axs[3,1].plot( [4,4],  [-0.5, 1.5], linestyle='dashed', color='black', linewidth = 1.5)
axs[3,1].legend(['faf-heat','faf-water','faf-stress','0.2*Control'])#,'faf-water'])
axs[3,1].set_xlabel('Degrees north of mARC-SAF', size=11)
axs[3,1].set_ylabel('Avg. $\Delta$U (cm/s)', size = 11)
#axs[3,1].set_ylim(MRIlims)


axs[3,1].plot(MRIwindow, 100*MRIplheat_u ,  color='red',linewidth = lw)
axs[3,1].plot(MRIwindow, 100*MRIplwater_u, color= '#377eb8',linewidth = lw) 
axs[3,1].plot(MRIwindow, 100*MRIplwind_u, color='gray',linewidth = lw)
axs[3,1].plot(MRIwindow, 20*MRIplcont_u, 'k--' ,linewidth = lw)

axs[3,1].plot(Canwindow, 100*Canplheat_u ,  color='red',linewidth = lw)
axs[3,1].plot(Canwindow, 100*Canplwater_u, color= '#377eb8',linewidth = lw) 
axs[3,1].plot(Canwindow, 100*Canplwind_u, color= 'gray' ,linewidth = lw)
axs[3,1].plot(Canwindow, 20*Canplcont_u, 'k--' ,linewidth = lw)

axs[3,1].plot(Canwindow, 100*MIROCplheat_u ,  color='red',linewidth = lw)
axs[3,1].plot(Canwindow, 100*MIROCplwater_u, color= '#377eb8',linewidth = lw) 
axs[3,1].plot(Canwindow, 100*MIROCplwind_u, color= 'gray' ,linewidth = lw)
axs[3,1].plot(Canwindow, 20* MIROCplcont_u, 'k--' ,linewidth = lw)

axs[3,1].plot(Canwindow, 100*GFDLplheat_u ,  color='red',linewidth = lw)
axs[3,1].plot(Canwindow, 100*GFDLplwater_u, color= '#377eb8',linewidth = lw) 
axs[3,1].plot(Canwindow, 100*GFDLplwind_u, color= 'gray' ,linewidth = lw)
axs[3,1].plot(Canwindow, 20* GFDLplcont_u, 'k--' ,linewidth = lw)
#axs[3,1].plot( [-3,-3], [-0.5, 1.5], linestyle='dashed', color='black', linewidth = 1.5)
#axs[3,1].plot( [4,4],  [-0.5, 1.5], linestyle='dashed', color='black', linewidth = 1.5)

#axs[3,1].legend(['faf-heat','faf-water','faf-stress','Control U'])#,'faf-water'])
#axs[3,1].set_xlabel('Degrees north of mARC-SAF', size=12)
fafulims = [-1.5,2]
faftlims = [-0.8,1.2]
axs[3,0].plot([i * 0 for i in faftlims],faftlims, linestyle='dashed', linewidth = 1.5)
axs[3,1].plot([i*0 for i in fafulims],fafulims, linestyle='dashed', linewidth = 1.5)

axs[3,0].set_ylim(faftlims)
axs[3,1].set_ylim(fafulims)


# mean values?? 
plabels = ['a','b', 'c', 'd','e','f','g','h', 'i', 'j']
for i in range(8):#np.arange(0,8):#[2,4,6]:
    j = i//2
    k = i%2 
    if j<2:
        axs[j,k].plot(0*depq[qlev], -depq[qlev], linestyle='dashed', linewidth = 1.5) # default blue?? 
    #axs[j,k].set_aspect('auto')
    #if (k==1 or i==0):
    #    axs[j,k].contour(np.arange(-sos,nos), - depq[qlev], toPl_iso, levels=12, colors= 'gray')
    axs[j,k].text(0.02, 0.05, plabels[i], size = 16, transform = axs[j,k].transAxes)
    

        
#plt.colorbar(C)
Thcb= fig.colorbar(Th, ax=axs[0,0])
Twcb= fig.colorbar(Tw, ax=axs[1,0])
Uhcb= fig.colorbar(Uh, ax=axs[0,1])
Uwcb= fig.colorbar(Uw, ax=axs[1,1])

Uhcb.set_label("$\Delta$u, cm/s",fontsize = 'medium')
Uwcb.set_label("$\Delta$u, cm/s",fontsize = 'medium')
Thcb.set_label("$\Delta$T, $^{\circ}$C",fontsize = 'medium')
Twcb.set_label("$\Delta$T, $^{\circ}$C",fontsize = 'medium')

## adding subplot labels, to make easier. 
axs[0,0].set_title('T change under $\Delta$ Buoyancy')
axs[0,1].set_title('U change under $\Delta$ Buoyancy') 
axs[1,0].set_title('T change under $\Delta$ Wind Stress')
axs[1,1].set_title('U change under $\Delta$ Wind Stress')
axs[2,0].set_title('T change (upper 2000 m)')
axs[2,1].set_title('U change (upper 2000 m)')
axs[3,0].set_title('T change under FAFMIP ')
axs[3,1].set_title('U change under FAFMIP')

#plt.savefig('SISAZ_figures/Coupled_ARCSAFm_7-29.eps', format='eps')

# %%
# not sure what happens!

#tau1c2_tm_4=xr.open_dataset(fo
#tau1c2_tm_4 = tau1c2_tm_4.TEMP
#tau1c2_um_4=xr.open_dataset(fo
#tau1c2_um_4 = tau1c2_um_4.UVEL
## we would also need v, which 
#depth = 2000
#lonw = 20
#lone = 150 ## change to 80 for
#matlats = tau1_um_4.TLAT[:,0]
##matlatc = np.arange(np.argmin
#mylat = np.arange(0,140)
#matlons = tau1_um_4.TLONG[0,:]

# %%
ztst.shape

# %% [markdown]
# ## Processing FAFMIP-o data, beginning with ACCESS

# %%
#ACC_water_u_file =  xr.open_dataset("uo_yr_ACCESS-OM2_FAF-water_01-70.nc")
ACC_stress_u_file =  xr.open_dataset("/nfs/data/FAFMIP/OFAFMIP/ACCESS-OM2/uo_ACCESS-OM2_FAF-stress_r1i1p1_61-70.nc")

# %%
#ACC_water_u = ACC_water_u_file.u.isel(time = np.arange(50,70)).mean('time')
ACC_stress_u = ACC_stress_u_file.u

# %%
foldera = "Apr24means/"

#Had_heat_v.to_netcdf(foldera+'Had_heat_v.nc')
#ACC_heat_t.to_netcdf(foldera+'ACC_heat_t.nc')
#ACC_cont_t.to_netcdf(foldera+'ACC_cont_t.nc')

#ACC_water_u.to_netcdf(foldera+'ACC_water_u.nc')
#ACC_stress_t.to_netcdf(foldera+'ACC_wind_t.nc')
ACC_stress_u.to_netcdf(foldera+'ACC_wind_u.nc')

# %%
#ACC_water_t_file

# %%
# this is just grabbing the OFAFMIP data. 
import matplotlib.ticker as mticker
    
    
mnum = 5 # 0 = GFDL2 1 = MIROC, 2 = MRI, 3 = CanESM, 4 = CESM, 5 = "ACCESS", 6= "Had" (HadOM3)
mlist = [ "GFDL","MIROC","MRI","CanESM","CESM", "ACC", "Had"]

lats = -65 # write these between -90 and 90
latn = -25  

lonw = 10 #write these between 0 and 360, sorry!
lone = 170

oglonw = int(lonw)
oglone = int(lone)

depth = 200

vm = 0.05
vmT = 3
vmc = 0.2
nlev = 15 # number of contours of the mean circulation

um = 4
#fig.suptitle(mlist[mnum]+' output zonal average, '+str(lonw)+' - '+str(lone)+' E')

foldern = 'Apr24means/'#'Jan22means/'
# seems like the best way to do this is to have a dictionary. Probably one dictionary for each model. This will require thinking!
# likely it's not that bad. For a start, you can write a simple code just to pull them from files! 
#Then make the dictionary when you rewrite the read from file codes to make them efficient
pl_heat_u = xr.open_dataarray(foldern + mlist[mnum]+'_heat_u.nc')
pl_heat_v = xr.open_dataarray(foldern + mlist[mnum]+'_heat_v.nc')
pl_heat_theta = xr.open_dataarray(foldern + mlist[mnum]+'_heat_t.nc')
#pl_heat_pass = xr.open_dataarray(foldern + mlist[mnum]+'_heat_pass.nc')
#pl_heat_sal = xr.open_dataarray(foldern + mlist[mnum]+'_heat_sal.nc')
pl_cont_u = xr.open_dataarray(foldern + mlist[mnum]+'_cont_u.nc')
#pl_cont_v = xr.open_dataarray(foldern + mlist[mnum]+'_cont_v.nc')
#pl_cont_pass = xr.open_dataarray(foldern + mlist[mnum]+'_cont_pass.nc')
#pl_cont_sal = xr.open_dataarray(foldern + mlist[mnum]+'_cont_sal.nc')
pl_cont_theta = xr.open_dataarray(foldern + mlist[mnum]+'_cont_t.nc')
pl_wind_theta = xr.open_dataarray(foldern + mlist[mnum]+'_wind_t.nc')
pl_water_theta = xr.open_dataarray(foldern + mlist[mnum]+'_water_t.nc')

pl_wind_u = xr.open_dataarray(foldern + mlist[mnum]+'_wind_u.nc') # not present weirdly. 
pl_water_u = xr.open_dataarray(foldern + mlist[mnum]+'_water_u.nc')

# to do it everywhere else we need to mean the meridional velocities. whew another day. 


if mnum==0:
    lonfile = pl_heat_theta.lon
    latfile = pl_heat_theta.lat
    depfile = pl_heat_theta.lev
    #pl_cont_sig0 = gsw.sigma0(pl_cont_sal, pl_cont_theta)
    
    
elif mnum in (1,2,3): 
    lonfile = pl_cont_u.longitude
    latfile = pl_cont_u.latitude
    depfile = pl_cont_u.lev
    #pl_cont_sig0 = gsw.sigma0(pl_cont_sal, pl_cont_theta)
    #if mnum==1: # better solution once I make a dictionary
        #pl_cont_sig0 = MIROC_cont_sig0
    #else:
        #pl_cont_sig0 = 0*MIROC_cont_sig0
    
elif mnum ==4:
    lonfile = pl_cont_u.lon
    latfile = pl_cont_u.lat
    depfile = pl_cont_u.lev
    
elif mnum==5:
    lonfile = pl_cont_u.xu_ocean
    latfile = pl_cont_u.yu_ocean
    depfile = pl_cont_u.depth

elif mnum==6:
    lonfile = pl_cont_u.longitude
    latfile = pl_cont_u.latitude
    depfile = pl_cont_u.depth
    
    #pl_cont_sig0 = 0*MIROC_cont_sig0


# pick actual latitudes
lonmax = [80, 360, 360, 360, 360, 80]
lonmin = [-280, 0, 0,0,0, -280]


if lone>lonmax[mnum]:
    lone = lone - 360
if lone<lonmin[mnum]:
    lone = lone + 360
    
if lonw>lonmax[mnum]:
    lonw = lonw - 360
if lonw<lonmin[mnum]:
    lonw = lonw + 360
    
lonecd = np.argmin(np.abs(np.array(lone - lonfile)))
lonwcd = np.argmin(np.abs(np.array(lonw - lonfile)))  
latncd = np.argmin(np.abs(np.array(latn - latfile)))
latscd = np.argmin(np.abs(np.array(lats - latfile)))

if lonwcd>lonecd:
    lonwcd = lonwcd-len(lonfile)

mylat = np.arange(latscd,latncd)
mylon = np.arange(lonwcd,lonecd)

idealdepth = [40, 48, 48, 30, 46, 36] # for 2000m 
regdep = np.arange(0,idealdepth[mnum])

# fix this! for now... this isn't great.


depf = [-1, -1, -1, -1, -0.01, -1]
# yy, zz = np.meshgrid(latfile[mylat],  depf[mnum]* depfile[regdep])
#yy2, zz2 = np.meshgrid(latfile[np.arange(lats,latn-1),0],  depf[mnum]* depfile[regdep])

pl_cont_u = pl_cont_u.where(pl_cont_u <1000) # make all the values nan that don't satisfy this?? 
#pl_cont_u = xr.where(pl_cont_u, np.nan, pl_cont_u)
#x = np.where(tst ==0 , np.nan, tst)

#plot1 = np.mean(pl_cont_u[:,:,mylon],2)

# %%
a2 = np.load('ACCESS_ARCSAF.npz')
pl_ARCSAF_y = a2['ACC_ARCSAF_y']
ARCSAF_xco = a2['lon_co']
SAFy = pl_ARCSAF_y[mylon - ARCSAF_xco[0]]

# %%
plt.plot(SAFy)

# %%
plt.plot(pl_cont_u[:,40,0])

# %%
faf_HF = xr.open_dataset('FAFMIP_inputs/FAFMIP_hfds_v2.nc')
faf_HF = faf_HF.mean('time')
#faf_HF.surface_downward_heat_flux_in_sea_water.plot()
#faf_HF.latitude

# %%
## Need a code to average along the ARC-SAF in this model. Will copy CanESM code. 

a2 = np.load('ACCESS_ARCSAF.npz')
pl_ARCSAF_y = a2['ACC_ARCSAF_y']
ARCSAF_xco = a2['lon_co']
SAFy = pl_ARCSAF_y[mylon - ARCSAF_xco[0]] 

sos= 12 # integers please
nos = 20
wind = np.arange(-sos,nos)
#winddif = np.arange(-sos-0.5, nos+0.5)
heat_T_acc_str = np.zeros([len(regdep), sos+nos, len(mylon)])
cont_T_acc_str = np.zeros([len(regdep), sos+nos, len(mylon)])
wind_T_acc_str = np.zeros([len(regdep), sos+nos, len(mylon)])
water_T_acc_str = np.zeros([len(regdep), sos+nos, len(mylon)])
#cont_sig0_acc_str = np.zeros([len(regdep), sos+nos, len(mylon)])
cont_U_acc_str = np.zeros([len(regdep), sos+nos, len(mylon)])
heat_U_acc_str = np.zeros([len(regdep), sos+nos, len(mylon)])
water_U_acc_str = np.zeros([len(regdep), sos+nos, len(mylon)])
wind_U_acc_str = np.zeros([len(regdep), sos+nos, len(mylon)])

#cont_T_dif_acc_str = np.zeros([len(regdep), sos+nos+1, len(mylon)])
faf_HF_str = np.zeros([sos+nos, len(mylon)])


# we want to get the actual y value at each step within mylon (not the coordinate of the adjusted ARCSAF at every value)
# this is some subset of pl_ARCSAF_y
# it's like mylon - 
 # I think that's pretty much it??? 

for i in np.arange(0,len(mylon)-1):
    # a is the actual latitude that we're looking at.
    a = SAFy[i] # use lm[mylon[i]] or strlat
    winda = a+ wind
    winddifa = a+ winddif
    faf_HF_str[:,i] = np.interp(winda, faf_HF.latitude, np.array(faf_HF.surface_downward_heat_flux_in_sea_water.isel(longitude=oglonw-1 +i)))
    for l in np.arange(0,len(regdep)):
        heat_T_acc_str[l,:,i] = np.interp(winda, pl_heat_theta.yt_ocean, pl_heat_theta.isel(depth=l, xt_ocean=mylon[i]))
        wind_T_acc_str[l,:,i] = np.interp(winda, pl_heat_theta.yt_ocean, pl_wind_theta.isel(depth=l, xt_ocean=mylon[i]))
        water_T_acc_str[l,:,i] = np.interp(winda, pl_heat_theta.yt_ocean, pl_water_theta.isel(depth=l, xt_ocean=mylon[i]))
        cont_T_acc_str[l,:,i] = np.interp(winda, pl_heat_theta.yt_ocean, pl_cont_theta.isel(depth=l, xt_ocean=mylon[i]))
        #cont_pass_can_str[l,:,i] = np.interp(winda, pl_heat_theta.latitude.isel(i=i), pl_cont_pass.isel(lev=l, i=mylon[i]))
        #cont_T_dif_can_str[l,:,i] = np.interp(winddifa, pl_heat_theta.latitude.isel(i=i), pl_cont_theta.isel(lev=l, i=mylon[i]))
        heat_U_acc_str[l,:,i] = np.interp(winda, pl_heat_theta.yt_ocean, pl_heat_u.isel(depth=l, xu_ocean=mylon[i]))
        cont_U_acc_str[l,:,i] = np.interp(winda, pl_heat_theta.yt_ocean, pl_cont_u.isel(depth=l, xu_ocean=mylon[i]))
        water_U_acc_str[l,:,i] = np.interp(winda, pl_heat_theta.yt_ocean, pl_water_u.isel(depth=l, xu_ocean=mylon[i]))
        wind_U_acc_str[l,:,i] = np.interp(winda, pl_heat_theta.yt_ocean, pl_wind_u.isel(depth=l, xu_ocean=mylon[i]))

        #cont_sig0_can_str[l,:,i] = np.interp(winda, pl_heat_theta.latitude.isel(i=i), pl_cont_sig0.isel(lev=l, i=mylon[i]))
        #NA0_T_can_str[l,:,i] = np.interp(winda, pl_heat_theta.latitude.isel(i=i), pl_NA0_theta.isel(lev=l, i=mylon[i]))
        #NA0_U_can_str[l,:,i] = np.interp(winda, pl_heat_theta.latitude.isel(i=i), pl_NA0_u.isel(lev=l, i=mylon[i]))
        #NA50_T_can_str[l,:,i] = np.interp(winda, pl_heat_theta.latitude.isel(i=i), pl_NA50_theta.isel(lev=l, i=mylon[i]))
        #NA50_U_can_str[l,:,i] = np.interp(winda, pl_heat_theta.latitude.isel(i=i), pl_NA50_u.isel(lev=l, i=mylon[i]))
        #SAFy=np.interp(np.arange(lonw,lone)+0.5,orsiSAFx,orsiSAFy)

    #WOA_sal_str[:,:,i] = sald[wocedep, a-sos:a+nos, wocelon[i]]
    #heat_T_can_str[:,:,i] = pl_heat_theta[regdep, a-sos:a+nos,wocelon[i]]
    #cont_T_can_str[:,:,i] = pl_cont_theta[regdep, a-sos:a+nos,wocelon[i]]
    #cont_pass_can_str[:,:,i] = pl_cont_pass[regdep, a-sos:a+nos,wocelon[i]]

# %%
faf_HF.longitude.isel(longitude = np.arange(oglonw-1, oglone-1))

# %%
heat_T_acc_str.shape # OK yeah so this is a problem - we've been consistently averaging an extra 
# 10 degrees on the early

# %%
#plt.contourf(np.mean(wind_T_acc_str - cont_T_acc_str,2))

# %%
# for ACCESS, copied from CanESM
## here's where I'll do just an ARC-SAF T line plots thing...

fig, ax1 = plt.subplots(nrows=1, ncols=1, figsize=(6,5)) 
plt.set_cmap('bwr')


## BUG: tmplon needs to now be more like 10, 140 because ARCSAF runs from 10 to 170. 
tmplon = np.arange(10,140) # this can be modified to look at a subsection of the region (20-150 E)

depinc = np.array(depfile.diff('depth')[regdep])
depinc = depinc.reshape((len(depinc),1))

tmph = np.nanmean(heat_T_acc_str[:,:,tmplon] - cont_T_acc_str[:,:,tmplon],2)
tmph = np.sum(tmph*depinc,0)/sum(depinc)

tmpw = np.nanmean( wind_T_acc_str[:,:,tmplon]- cont_T_acc_str[:,:,tmplon],2)
tmpf = np.nanmean( water_T_acc_str[:,:,tmplon]- cont_T_acc_str[:,:,tmplon],2)

plHF = np.nanmean(faf_HF_str[:,tmplon],1)


ax1.plot(wind, tmph ,  color='red')
#axs[0].contour(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_U_can_str[:,:,tmplon],2) , levels = [-0.075,-0.05,-0.03,-0.02,0,0.02,0.05,0.075,0.1,0.125], colors='gray')
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(np.diff(cont_T_dif_can_str[:,:,tmplon],axis=1),2),vmin = -vm, vmax = vm, levels=20)
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_pass_can_str[:,:,tmplon],2) ,vmin = -vm, vmax = vm, levels=20)
#axs.plot( wind, np.sum(tmpNA*depinc,0)/sum(depinc), color= 'orange')
ax1.plot( wind, np.sum(tmpw*depinc,0)/sum(depinc), color= '#377eb8' )
ax1.plot( wind, np.sum(tmpf*depinc,0)/sum(depinc), color= 'gray')

fac=5
# saving these values for the combined figure
ACCwindow = wind
ACCplheat = tmph
ACCplwind = np.sum(tmpw*depinc,0)/sum(depinc)
ACCplwater = np.sum(tmpf*depinc,0)/sum(depinc)
ACCplHF = plHF/fac
ACClims = [-0.4, 1.1]  



tmpcontu = np.nanmean(cont_U_acc_str[:,:,tmplon],2)
tmphu = np.nanmean(heat_U_acc_str[:,:,tmplon] - cont_U_acc_str[:,:,tmplon],2)
tmpwu = np.nanmean( wind_U_acc_str[:,:,tmplon]- cont_U_acc_str[:,:,tmplon],2)
tmpfu = np.nanmean( water_U_acc_str[:,:,tmplon]- cont_U_acc_str[:,:,tmplon],2)

ACCplcont_u = np.sum(tmpcontu*depinc,0)/sum(depinc)
ACCplheat_u = np.sum(tmphu*depinc,0)/sum(depinc)
ACCplwind_u = np.sum(tmpwu*depinc,0)/sum(depinc)
ACCplwater_u = np.sum(tmpfu*depinc,0)/sum(depinc)


fac=8
#yy, zz = np.meshgrid(latfile[mylat,0],  depf[mnum]* depfile[regdep])
#yy2, zz2 = np.meshgrid(latfile[np.arange(lats,latn-1),0],  depf[mnum]* depfile[regdep])
ax1.plot(wind, plHF/fac, '-..', color= '#f781bf') 
plt.plot( [-3,-3], [-0.5, 1.5], linestyle='dashed', color='black', linewidth = 1.5)
plt.plot( [4,4],  [-0.5, 1.5], linestyle='dashed', color='black', linewidth = 1.5)
plt.legend(['ofaf-heat','ofaf-stress', 'ofaf-water', 'faf-heat flux'])
lims = [-0.4, 1.1]         
ax1.set_ylim(lims)
ax1.set_ylabel('$\Delta$ T ($^{\circ}$C)',size=14)
ax1.set_xlabel('Degrees north of ARC-SAF     ', size=12)

plt.legend(['ofaf-heat', 'ofaf-stress', 'ofaf-water','faf-heat flux'])

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis


ax2.set_ylabel('Heat flux (W/m$^2$)', size=12)  # we already handled the x-label with ax1
#ax2.plot(t, data2, color=color)
#ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim([i * fac for i in lims])

fig.tight_layout()  # otherwise the right y-label is slightly clipped
#plt.savefig('SISAZ_figures/MRI_faf-heat_speedmap_v3.eps')
#plt.savefig('SISAZ_figures/ACCESS_Tlineplots_5-2.eps')

# %%
np.savez('ACC_ARCSAF_zint.npz', ACCplcont_u = ACCplcont_u, ACCplheat_u = ACCplheat_u, 
         ACCplwind_u = ACCplwind_u, 
         ACCplwater_u = ACCplwater_u, ACCwindow= ACCwindow, ACCplheat = ACCplheat, ACCplwind = ACCplwind, ACCplwater = ACCplwater) #MIROCplpass =MIROCplpass )

# %%
# rewriting the MRI code for ACCESS

# what I'm doing here is the few degrees around the ARC-SAF minus 55-40 S. 
# 12 is the ARC-SAF .. 
# Need to identify latitude coordinates for 55-40 S. 

depinc = np.array(depfile.diff('depth')[regdep])
depinc = depinc.reshape((len(depinc),1))
depinc[-1] = 2000 - sum(depinc[:-1])

latncd = np.argmin(np.abs(np.array(-40 - latfile[:])))
latscd = np.argmin(np.abs(np.array(-55 - latfile[:])))
zmr = np.arange(latscd - mylat[0], latncd-mylat[0])


zmSST = pl_heat_theta.isel(yt_ocean=mylat, xt_ocean=mylon, depth=regdep) - pl_cont_theta.isel(yt_ocean=mylat, xt_ocean=mylon, depth=regdep)
zmSST = zmSST.mean('xt_ocean')
ztst = np.sum(zmSST* depinc,0)/sum(depinc) # np.sum(tmph*depinc,0)/sum(depinc)
ACCSSTdif = np.mean(ACCplheat[10:15]) - np.nanmean(ztst[zmr])


zmSSS =pl_water_theta.isel(yt_ocean=mylat, xt_ocean=mylon, depth=regdep) - pl_cont_theta.isel(yt_ocean=mylat, xt_ocean=mylon, depth=regdep)
zmSSS = zmSSS.mean('xt_ocean')
ztst = np.sum(zmSSS*depinc,0) / sum(depinc) # np.sum(tmph*depinc,0)/sum(depinc)
ACCSSSdif = np.mean(ACCplwater[10:15]) - np.nanmean(ztst[zmr])
#
zmW =pl_wind_theta.isel(yt_ocean=mylat, xt_ocean=mylon, depth=regdep) - pl_cont_theta.isel(yt_ocean=mylat, xt_ocean=mylon, depth=regdep)
zmW = zmW.mean('xt_ocean')
ztst = np.sum(zmW*depinc,0) / sum(depinc) # np.sum(tmph*depinc,0)/sum(depinc)
ACCWdif = np.mean(ACCplwind[10:15]) - np.nanmean(ztst[zmr])

plt.bar([0.5,1,1.5],[ACCSSTdif, ACCSSSdif, ACCWdif], width=[0.5], color = ['red', '#377eb8', 'gray'], edgecolor='black')

# %%
x

# %%
# the next thing to do is to try a big figure to add. This would show the result clearly. 
# maybe all the models? 

fig, ax = plt.subplots()
wid = 0.2
hits = [SSTdif,SSSdif,winddif, ACCSSTdif, ACCSSSdif, ACCWdif, Buoydif, 0, Taudif, CanSSTdif, CanSSSdif, CanWdif, MRISSTdif, MRISSSdif, MRIWdif]
colors = ['red', '#377eb8', 'gray']*2
x = []
for i in range(1,6):
    x.append(i-wid)
    x.append(i)
    x.append(i+wid)

ax.bar(x ,hits, width=wid, color = colors, edgecolor='black')


# sketchy hack!
labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = 'MITgcm'
labels[2] = 'ACCESS-OM2'
labels[3] = 'CESM1'
labels[4] = 'CanESM5'
labels[5] = 'MRI-ESM2'

ax.plot([0.5,5.5], [0,0], 'k')
ax.set_xticklabels(labels)
ax.tick_params(axis='x', bottom=False)
ax.set_ylabel('Excess ARC-SAF warming ($^{\circ}$C)')

#plt.savefig('SISAZ_figures/bargraph1_7-9.eps')

# %%
# the next thing to do is to try a big figure to add. This would show the result clearly. 
# maybe all the models? 

fig, ax = plt.subplots()
wid = 0.2
hits = [SSTdif,SSSdif,winddif, ACCSSTdif, ACCSSSdif, ACCWdif, Buoydif, 0, Taudif, CanSSTdif, CanSSSdif, CanWdif, MRISSTdif, MRISSSdif, MRIWdif]
colors = ['red', '#377eb8', 'gray']*2
x = []
for i in range(1,6):
    x.append(i-wid)
    x.append(i)
    x.append(i+wid)
#labs = ['','boom','']*5




# We need to draw the canvas, otherwise the labels won't be positioned and 
# won't have values yet.

ax.bar(x ,hits, width=wid, color = colors, edgecolor='black')
ax.annotate('MITgcm', (0.8,-0.03))
ax.annotate('ACCESS-OM2', (1.6,-0.03))
ax.annotate('CESM1-tau', (2.7,-0.03))
ax.annotate('CanESM5 faf', (3.6,-0.05))
ax.annotate('MRI faf', (4.7,-0.05))
plt.plot([0.5,5.5], [0,0], 'k')

# sketchy hack!
#labels = [item.get_text() for item in ax.get_xticklabels()]
#labels = range(6)
#labels[1] = 'MIT'
#labels[2] = 'ACCESS-OM2'
#labels[3] = 'CESM1'
#labels[4] = 'CanESM5'
#labels[5] = 'MRI-ESM2'

#ax.set_xticklabels(labels)

# %%
plt.contourf(cont_U_acc_str[:,:,100])
plt.colorbar()

# %%
#asdf = xr.Dataset(cont_U_acc_str)
#tst = asdf.where(asdf<10)

cont_U_acc_str[cont_U_acc_str>10] = np.nan

#tmpcontu = np.nanmean(cont_U_acc_str[:,:,tmplon],2)

# %% [markdown]
# ## NEMO FAFMIP-o output

# %%
# Here I'm just seeing what's in these. If it's nice, we can just copy the ACCESS code and move along. 

# it seems like the
cont_theta_file = xr.open_dataset('Apr24means/NEMO34/thetao_yr_NEMO34_FAF-control_61-70.nc')
heat_theta_file = xr.open_dataset('Apr24means/NEMO34/thetao_yr_NEMO34_FAF-heat_61-70.nc')
wind_theta_file = xr.open_dataset('Apr24means/NEMO34/thetao_yr_NEMO34_FAF-stress_61-70.nc')
water_theta_file = xr.open_dataset('Apr24means/NEMO34/thetao_yr_NEMO34_FAF-water_61-70.nc')

NEMO_cont_theta =   cont_theta_file.votemper
NEMO_heat_theta =   heat_theta_file.votemper
NEMO_wind_theta =   wind_theta_file.votemper
NEMO_water_theta = water_theta_file.votemper

cont_u_file = xr.open_dataset('Apr24means/NEMO34/uo_yr_NEMO34_FAF-control_61-70.nc')
heat_u_file = xr.open_dataset('Apr24means/NEMO34/uo_yr_NEMO34_FAF-heat_61-70.nc')
wind_u_file = xr.open_dataset('Apr24means/NEMO34/uo_yr_NEMO34_FAF-stress_61-70.nc')
water_u_file = xr.open_dataset('Apr24means/NEMO34/uo_yr_NEMO34_FAF-water_61-70.nc')

NEMO_cont_u = cont_u_file.vozocrtx
NEMO_heat_u = heat_u_file.vozocrtx
NEMO_wind_u = wind_u_file.vozocrtx
NEMO_water_u = water_u_file.vozocrtx

cont_v_file = xr.open_dataset('Apr24means/NEMO34/vo_yr_NEMO34_FAF-control_61-70.nc')
NEMO_cont_v = cont_v_file.vomecrty

lonfile = NEMO_cont_u.nav_lon[0,0:360]
latfile = NEMO_cont_u.nav_lat[1:180,0]
# this latfile is not generally valid, just for less than 180 where it's still uniform. 
depfile = NEMO_cont_u.depthu

# %%
#foldera = 'Apr24means/'
#NEMO_heat_theta.to_netcdf(foldera+'NEMO_heat_t.nc')
#NEMO_water_theta.to_netcdf(foldera+'NEMO_water_t.nc')
#NEMO_wind_theta.to_netcdf(foldera+'NEMO_wind_t.nc')
#NEMO_cont_theta.to_netcdf(foldera+'NEMO_cont_t.nc')
#NEMO_heat_u.to_netcdf(foldera+'NEMO_heat_u.nc')
#NEMO_water_u.to_netcdf(foldera+'NEMO_water_u.nc')
#NEMO_wind_theta.to_netcdf(foldera+'NEMO_wind_u.nc')
#NEMO_cont_theta.to_netcdf(foldera+'NEMO_cont_u.nc')
#ACC_cont_t.to_netcdf(foldera+'ACC_cont_t.nc')

# %%
x = NEMO_heat_u #- NEMO_cont_u
# = NEMO_cont_u

plt.contourf(x[0:20,:,:].mean("depthu"), vmin = -0.03, vmax = 0.03, levels=50)
plt.colorbar()

# %%
dimdict = {}
dimdict['depthv'] = 'depthu'
tst = NEMO_cont_v.rename(dimdict)

pl_cont_mke = (NEMO_cont_u[regdep,mylat,mylon]**2 + tst[regdep,mylat,mylon]**2)**0.5

# %%
#plt.contourf(lonfile[mylon],latfile[mylat],np.nanmean(pl_cont_mke,0), levels=50)
#plt.colorbar()
NEMO_heat_u

# %%
mylat = np.arange(15,120) # this is roughly OK!
lonfile[mylon]

# %%
depfile

# %%
init_ARCSAF_y = np.interp(np.arange(oglonw, oglone), SJFx, SJFy) 
# og lons are 10 to 170. current mylon is 4 to 161. This creates an issue. Please fix and we should be fine! 

#mylat = np.arange(15,120) # this is roughly OK 

NEMO_ARCSAF_y = 0*init_ARCSAF_y
NEMO_ARCSAF_co = 0*init_ARCSAF_y

NEMO_lon = np.arange(oglonw, oglone) # this may need to be modified.

#speed = cont_speed_4.isel(z_t=idep).mean('z_t')
dif=3 # this is a bit sketchy! 
difu = 5

# the only potential difficulty is that NEMO starts at 73 .. 
# uhh weird. so the coordinate is supposed to be 

for i in np.arange(len(mylon)):
    AS_co = np.argmin(np.abs(init_ARCSAF_y[i] - np.array(latfile[mylat])))
    NEMO_ARCSAF_co[i] = np.argmax(np.array(pl_cont_mke[AS_co-dif:AS_co+difu,i]))
    NEMO_ARCSAF_co[i] = NEMO_ARCSAF_co[i] + AS_co-dif # this gets the coordinate within mylat.
    NEMO_ARCSAF_y[i] =  latfile[int(mylat[0] +NEMO_ARCSAF_co[i])]
    
## Ok that basically works.

# %%
np.savez('NEMO_ARCSAF.npz', NEMO_ARCSAF_y = NEMO_ARCSAF_y, NEMO_ARCSAF_co = NEMO_ARCSAF_co, lat_co= mylat, lon_co = mylon, NEMO_x = lonfile[mylon])

# %%
## Need a code to average along the ARC-SAF for NEMO. Will copy ACCESS

# dang not sure what the .yt_ocean means in the averaging step! Tricky tricky ... 

NemA = np.load('NEMO_ARCSAF.npz')

pl_ARCSAF_y = NemA['NEMO_ARCSAF_y']
ARCSAF_xco = NemA['lon_co']
SAFy = pl_ARCSAF_y[mylon - ARCSAF_xco[0]] # this might not work because of the weird longitude coord. 

# currently mylon is between 10 and 170 E. 
# do I want to change that? No it's OK, just need to set tmplon correctly!!! 

sos= 12 # integers please
nos = 20
wind = np.arange(-sos,nos)
#winddif = np.arange(-sos-0.5, nos+0.5)
heat_T_NEMO_str = np.zeros([len(regdep), sos+nos, len(mylon)])
cont_T_NEMO_str = np.zeros([len(regdep), sos+nos, len(mylon)])
wind_T_NEMO_str = np.zeros([len(regdep), sos+nos, len(mylon)])
cont_U_NEMO_str = np.zeros([len(regdep), sos+nos, len(mylon)])
heat_U_NEMO_str = np.zeros([len(regdep), sos+nos, len(mylon)])
wind_U_NEMO_str = np.zeros([len(regdep), sos+nos, len(mylon)])
water_U_NEMO_str = np.zeros([len(regdep), sos+nos, len(mylon)])
water_T_NEMO_str = np.zeros([len(regdep), sos+nos, len(mylon)])
#cont_T_dif_acc_str = np.zeros([len(regdep), sos+nos+1, len(mylon)])
faf_HF_str = np.zeros([sos+nos, len(mylon)])

#OK here NEMO is annoying enough I'm just going to make them all numpy arrays
# no we'll give it a chance

for i in np.arange(0,len(mylon)-1):
    # a is the actual latitude that we're looking at.
    a = SAFy[i] # use lm[mylon[i]] or strlat
    winda = a+ wind
    #winddifa = a+ winddif
    #faf_HF_str[:,i] = np.interp(winda, faf_HF.latitude, np.array(faf_HF.surface_downward_heat_flux_in_sea_water.isel(longitude=oglonw-1 +i)))
    for l in np.arange(0,len(regdep)):
        heat_T_NEMO_str[l,:,i] = np.interp(winda, latfile.nav_lat[mylat], NEMO_heat_theta.isel(deptht=l, dim2=mylon[i], dim1=mylat))
        heat_U_NEMO_str[l,:,i] = np.interp(winda, latfile.nav_lat[mylat], NEMO_heat_u.isel(depthu=l, dim2=mylon[i], dim1=mylat))
        wind_T_NEMO_str[l,:,i] = np.interp(winda, latfile.nav_lat[mylat], NEMO_wind_theta.isel(deptht=l, dim2=mylon[i], dim1=mylat))
        wind_U_NEMO_str[l,:,i] = np.interp(winda, latfile.nav_lat[mylat], NEMO_wind_u.isel(depthu=l, dim2=mylon[i], dim1=mylat))
        cont_T_NEMO_str[l,:,i] = np.interp(winda, latfile.nav_lat[mylat], NEMO_cont_theta.isel(deptht=l, dim2=mylon[i], dim1=mylat))
        cont_U_NEMO_str[l,:,i] = np.interp(winda, latfile.nav_lat[mylat], NEMO_cont_u.isel(depthu=l, dim2=mylon[i], dim1=mylat))
        water_T_NEMO_str[l,:,i] = np.interp(winda,latfile.nav_lat[mylat], NEMO_water_theta.isel(deptht=l, dim2=mylon[i], dim1=mylat))
        water_U_NEMO_str[l,:,i] = np.interp(winda,latfile.nav_lat[mylat], NEMO_water_u.isel(depthu=l, dim2=mylon[i], dim1=mylat))
#cont_sig0_can_str[l,:,i] = np.interp(winda, pl_heat_theta.latitude.isel(i=i), pl_cont_sig0.isel(lev=l, i=mylon[i]))
        #NA0_T_can_str[l,:,i] = np.interp(winda, pl_heat_theta.latitude.isel(i=i), pl_NA0_theta.isel(lev=l, i=mylon[i]))
        #NA50_U_can_str[l,:,i] = np.interp(winda, pl_heat_theta.latitude.isel(i=i), pl_NA50_u.isel(lev=l, i=mylon[i]))
        #SAFy=np.interp(np.arange(lonw,lone)+0.5,orsiSAFx,orsiSAFy)

    #WOA_sal_str[:,:,i] = sald[wocedep, a-sos:a+nos, wocelon[i]]
    #heat_T_can_str[:,:,i] = pl_heat_theta[regdep, a-sos:a+nos,wocelon[i]]
    #cont_T_can_str[:,:,i] = pl_cont_theta[regdep, a-sos:a+nos,wocelon[i]]
    #cont_pass_can_str[:,:,i] = pl_cont_pass[regdep, a-sos:a+nos,wocelon[i]]

# %%
plt.contourf(cont_U_NEMO_str[0,:,:])
plt.colorbar()

# %%
depfile

# %%
#NEMO_heat_theta.isel(deptht=l, dim1=mylon[i], dim2=mylat)


fig, ax1 = plt.subplots(nrows=1, ncols=1, figsize=(6,5)) 
plt.set_cmap('bwr')


## BUG: tmplon needs to now be more like 10, 140 because ARCSAF runs from 10 to 170. 
tmplon = np.arange(10,140) # this can be modified to look at a subsection of the region (20-150 E)

depinc = np.array(depfile.diff('depthu')[regdep])
depinc = depinc.reshape((len(depinc),1))
depinc[-1] = 2000 - sum(depinc[:-1])

tmph = np.nanmean(heat_T_NEMO_str[:,:,tmplon] - cont_T_NEMO_str[:,:,tmplon],2)
tmph = np.sum(tmph*depinc,0)/sum(depinc)

tmpw = np.nanmean( wind_T_NEMO_str[:,:,tmplon]- cont_T_NEMO_str[:,:,tmplon],2)
tmpf = np.nanmean( water_T_NEMO_str[:,:,tmplon]- cont_T_NEMO_str[:,:,tmplon],2)

#plHF = np.nanmean(faf_HF_str[:,tmplon],1)


ax1.plot(wind, tmph ,  color='red')
#axs[0].contour(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_U_can_str[:,:,tmplon],2) , levels = [-0.075,-0.05,-0.03,-0.02,0,0.02,0.05,0.075,0.1,0.125], colors='gray')
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(np.diff(cont_T_dif_can_str[:,:,tmplon],axis=1),2),vmin = -vm, vmax = vm, levels=20)
#plt.contourf( wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_pass_can_str[:,:,tmplon],2) ,vmin = -vm, vmax = vm, levels=20)
#axs.plot( wind, np.sum(tmpNA*depinc,0)/sum(depinc), color= 'orange')
ax1.plot( wind, np.sum(tmpw*depinc,0)/sum(depinc), color= '#377eb8' )
ax1.plot( wind, np.sum(tmpf*depinc,0)/sum(depinc), color= 'gray')

fac=5
# saving these values for the combined figure
NEMOwindow = wind
NEMOplheat = tmph
NEMOplwind = np.sum(tmpw*depinc,0)/sum(depinc)
NEMOplwater = np.sum(tmpf*depinc,0)/sum(depinc)
#NEMOplHF = plHF/fac
NEMOlims = [-0.4, 1.1]  



tmpcontu = np.nanmean(cont_U_NEMO_str[:,:,tmplon],2)
tmphu = np.nanmean(heat_U_NEMO_str[:,:,tmplon] - cont_U_NEMO_str[:,:,tmplon],2)
tmpwu = np.nanmean( wind_U_NEMO_str[:,:,tmplon]- cont_U_NEMO_str[:,:,tmplon],2)
tmpfu = np.nanmean( water_U_NEMO_str[:,:,tmplon]- cont_U_NEMO_str[:,:,tmplon],2)

NEMOplcont_u = np.sum(tmpcontu*depinc,0)/sum(depinc)
NEMOplheat_u = np.sum(tmphu*depinc,0)/sum(depinc)
NEMOplwind_u = np.sum(tmpwu*depinc,0)/sum(depinc)
NEMOplwater_u = np.sum(tmpfu*depinc,0)/sum(depinc)


fac=8
#yy, zz = np.meshgrid(latfile[mylat,0],  depf[mnum]* depfile[regdep])
#yy2, zz2 = np.meshgrid(latfile[np.arange(lats,latn-1),0],  depf[mnum]* depfile[regdep])
#ax1.plot(wind, plHF/fac, '-..', color= '#f781bf') 
plt.plot( [-3,-3], [-0.5, 1.5], linestyle='dashed', color='black', linewidth = 1.5)
plt.plot( [4,4],  [-0.5, 1.5], linestyle='dashed', color='black', linewidth = 1.5)
plt.legend(['ofaf-heat','ofaf-stress', 'ofaf-water', 'faf-heat flux'])
lims = [-0.4, 1.1]         
ax1.set_ylim(lims)
ax1.set_ylabel('$\Delta$ T ($^{\circ}$C)',size=14)
ax1.set_xlabel('Degrees north of ARC-SAF     ', size=12)

plt.legend(['ofaf-heat', 'ofaf-stress', 'ofaf-water','faf-heat flux'])

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis


ax2.set_ylabel('Heat flux (W/m$^2$)', size=12)  # we already handled the x-label with ax1
#ax2.plot(t, data2, color=color)
#ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim([i * fac for i in lims])

fig.tight_layout()  # otherwise the right y-label is slightly clipped
#plt.savefig('SISAZ_figures/MRI_faf-heat_speedmap_v3.eps')
#plt.savefig('SISAZ_figures/ACCESS_Tlineplots_5-2.eps')

# %%
np.savez('NEMO_ARCSAF_zint.npz', NEMOplcont_u = NEMOplcont_u, NEMOplheat_u = NEMOplheat_u, 
         NEMOplwind_u = NEMOplwind_u, 
         NEMOplwater_u = NEMOplwater_u, NEMOwindow= NEMOwindow, NEMOplheat = NEMOplheat, NEMOplwind = NEMOplwind, NEMOplwater = NEMOplwater) #MIROCplpass =MIROCplpass )

# %%
plt.plot(NEMOplcont_u*0.1)
plt.plot(NEMOplheat_u)
plt.plot(NEMOplwind_u)
plt.plot(NEMOplwater_u)

# %%
# depfile[regdep]

# %% [markdown]
# ## MOM5 FAFMIP-o output

# %%
momf = '/zdata/mana/bataylor/OFAFMIP/MOM5/'
cont_theta_file = xr.open_dataset(momf +'thetao_yr_MOM5_FAF-control_01-70.nc')
heat_theta_file = xr.open_dataset(momf +'thetao_yr_MOM5_FAF-heat_r1i1p1_1-70.nc')
wind_theta_file = xr.open_dataset(momf +'thetao_yr_MOM5_FAF-stress_01-70.nc')
water_theta_file = xr.open_dataset(momf+'thetao_yr_MOM5_FAF-water_01-70.nc')
#heat_theta_file = xr.open_dataset('Apr24means/NEMO34/thetao_yr_NEMO34_FAF-heat_61-70.nc')
#wind_theta_file = xr.open_dataset('Apr24means/NEMO34/thetao_yr_NEMO34_FAF-stress_61-70.nc')
#water_theta_file = xr.open_dataset('Apr24means/NEMO34/thetao_yr_NEMO34_FAF-water_61-70.nc')

# %%
MOM_heat_th  = heat_theta_file.sea_water_potential_temperature.isel(time = range(60,70)).mean('time')
MOM_cont_th  = cont_theta_file.sea_water_potential_temperature.isel(time = range(60,70)).mean('time')
MOM_wind_th  = wind_theta_file.temp.isel(time = range(60,70)).mean('time')
MOM_water_th  = water_theta_file.temp.isel(time = range(60,70)).mean('time')

# %%
heat_pass_file = xr.open_dataset(momf+'pathetao_yr_MOM5_FAF-heat_r1i1p1_1-70.nc')
MOM_heat_pass  = heat_pass_file.sea_water_additional_potential_temperature.isel(time = range(60,70)).mean('time')

# %%
cont_u_file =  xr.open_dataset(momf+'uo_yr_MOM5_FAF-control_01-70.nc')
heat_u_file =  xr.open_dataset(momf+'uo_yr_MOM5_FAF-heat_r1i1p1_1-70.nc')
wind_u_file =  xr.open_dataset(momf+'uo_yr_MOM5_FAF-stress_01-70.nc')
water_u_file = xr.open_dataset(momf+'uo_yr_MOM5_FAF-water_01-70.nc')

# %%
MOM_heat_u  = heat_u_file.sea_water_x_velocity.isel(time = range(60,70)).mean('time')
MOM_cont_u  = cont_u_file.sea_water_x_velocity.isel(time = range(60,70)).mean('time')
MOM_wind_u  = wind_u_file.u.isel(time = range(60,70)).mean('time')
MOM_water_u  = water_u_file.u.isel(time = range(60,70)).mean('time')

# %%
#foldera = '~/Apr24means/'
#MOM_heat_th.to_netcdf(foldera+'MOM_heat_t.nc')
#MOM_heat_u.to_netcdf(foldera+'MOM_heat_u.nc')
#MOM_wind_th.to_netcdf(foldera+'MOM_wind_t.nc')
#MOM_wind_u.to_netcdf(foldera+'MOM_wind_u.nc')
#MOM_water_th.to_netcdf(foldera+'MOM_water_t.nc')
#MOM_water_u.to_netcdf(foldera+'MOM_water_u.nc')
#MOM_cont_th.to_netcdf(foldera+'MOM_cont_t.nc')
#MOM_cont_u.to_netcdf(foldera+'MOM_cont_u.nc')

MOM_heat_th= xr.open_dataarray(foldera+'MOM_heat_t.nc')
MOM_heat_u= xr.open_dataarray(foldera+'MOM_heat_u.nc')
MOM_wind_th= xr.open_dataarray(foldera+'MOM_wind_t.nc')
MOM_wind_u= xr.open_dataarray(foldera+'MOM_wind_u.nc')
MOM_water_th= xr.open_dataarray(foldera+'MOM_water_t.nc')
MOM_water_u= xr.open_dataarray(foldera+'MOM_water_u.nc')
MOM_cont_th= xr.open_dataarray(foldera+'MOM_cont_t.nc')
MOM_cont_u= xr.open_dataarray(foldera+'MOM_cont_u.nc')
#wind_theta_file

# %%
# i should be able to plot this initially! I think that'd be nice. 
# 

# cont_theta_file
mylon = np.arange(-61,69)

GAS = np.load('GFDL_ARCSAF.npz')
pl_ARCSAF_y = GAS['GFDL_ARCSAF_y']
ARCSAF_xco = GAS['lon_co']
SAFy = pl_ARCSAF_y[mylon - ARCSAF_xco[0]]
plt.plot(SAFy)

# %%
cont_u_file.sea_water_x_velocity
#sea_water_potential_temperature

# %%
## Streamline averaging 

# could update with a better version of ARC-SAF if desired! 
mylat = range(16,75)
latfile = MOM_heat_th.yt_ocean

sos= 12 # integers please
nos = 20
wind = np.arange(-sos,nos)
winddif = np.arange(-sos-0.5, nos+0.5)

regdep = np.arange(0,39)

#MOM_heat_th = 

heat_T_MOM_str = np.zeros([len(regdep), sos+nos, len(mylon)])
cont_T_MOM_str = np.zeros([len(regdep), sos+nos, len(mylon)])
heat_p_MOM_str = np.zeros([len(regdep), sos+nos, len(mylon)])
cont_U_MOM_str = np.zeros([len(regdep), sos+nos, len(mylon)])
heat_U_MOM_str = np.zeros([len(regdep), sos+nos, len(mylon)])
#cont_T_dif_mri_str = np.zeros([len(regdep), sos+nos+1, len(mylon)])
#NA0_T_gfdl_str = np.zeros([len(regdep), sos+nos, len(mylon)])
#NA0_U_gfdl_str = np.zeros([len(regdep), sos+nos, len(mylon)])
#NA50_T_gfdl_str = np.zeros([len(regdep), sos+nos, len(mylon)])
#NA50_U_gfdl_str = np.zeros([len(regdep), sos+nos, len(mylon)])
wind_T_MOM_str = np.zeros([len(regdep), sos+nos, len(mylon)])
wind_U_MOM_str = np.zeros([len(regdep), sos+nos, len(mylon)])
water_T_MOM_str = np.zeros([len(regdep), sos+nos, len(mylon)])
water_U_MOM_str = np.zeros([len(regdep), sos+nos, len(mylon)])

#SAFy=np.interp(mylon + float(pl_cont_theta.x.isel(x=0)+360),SJFx,SJFy) 
GAS = np.load('GFDL_ARCSAF.npz')
pl_ARCSAF_y = GAS['GFDL_ARCSAF_y']
ARCSAF_xco = GAS['lon_co']
SAFy = pl_ARCSAF_y[mylon - ARCSAF_xco[0]]
# SAFy is just 130 long? yes! 

for i in np.arange(0,len(mylon)-1):
    # a is the actual latitude that we're looking at.
    a = SAFy[i] # use lm[mylon[i]] or strlat
    winda = a+ wind
    winddifa = a+ winddif
    for l in np.arange(0,len(regdep)):
        heat_T_MOM_str[l,:,i] = np.interp(winda, latfile[mylat], MOM_heat_th.isel(depth=l, xt_ocean=mylon[i],yt_ocean= mylat))
        cont_T_MOM_str[l,:,i] = np.interp(winda, latfile[mylat], MOM_cont_th.isel(depth=l, xt_ocean=mylon[i],yt_ocean= mylat))
        heat_p_MOM_str[l,:,i] = np.interp(winda, latfile[mylat], MOM_heat_pass.isel(depth=l, xt_ocean=mylon[i],yt_ocean= mylat))
        #cont_TMOM_can_str[l,:,i] = np.interp(wi latfile[mylat],l(x=i), pl_cont_theta.isel(lev=l, x=mylon[i]))
        heat_U_MOM_str[l,:,i] = np.interp(winda, latfile[mylat], MOM_heat_u.isel(depth=l, xu_ocean=mylon[i],yu_ocean= mylat))
        cont_U_MOM_str[l,:,i] = np.interp(winda, latfile[mylat], MOM_cont_u.isel(depth=l, xu_ocean=mylon[i],yu_ocean= mylat))
        wind_T_MOM_str[l,:,i] = np.interp(winda, latfile[mylat], MOM_wind_th.isel(depth=l, xt_ocean=mylon[i],yt_ocean= mylat))
        wind_U_MOM_str[l,:,i] = np.interp(winda, latfile[mylat], MOM_wind_u.isel(depth=l, xu_ocean=mylon[i],yu_ocean= mylat))
        water_T_MOM_str[l,:,i] = np.interp(winda, latfile[mylat], MOM_water_th.isel(depth=l, xt_ocean=mylon[i],yt_ocean= mylat))
        water_U_MOM_str[l,:,i] = np.interp(winda, latfile[mylat], MOM_water_u.isel(depth=l, xu_ocean=mylon[i],yu_ocean= mylat))
        #SAFy=np.interp(np.arange(lonw,lone)+0 latfile[mylat],tr[:,:,i] = sald[wocedep, a-sos:a+nos, wocelon[i]]
    #heat_T_can_str[:,:,i] = pl_heat_theta[regdep, a-sos:a+nos,wocelon[i]]
    #cont_T_can_str[:,:,i] = pl_cont_theta[regdep, a-sos:a+nos,wocelon[i]]
    #cont_pass_can_str[:,:,i] = pl_cont_pass[regdep, a-sos:a+nos,wocelon[i]]

# %%
# Here I just want to implement enough to get those same averages.

## here's where I'll do just an ARC-SAF T line plots thing...

depfile = MOM_heat_th.depth

fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(6,5)) 
plt.set_cmap('bwr')

tmplon = np.arange(0,130) # this can be modified to look at a subsection of the region (20-150 E)
# - np.nanmean(cont_pass_can_str,2) #  np.nanmean(heat_T_can_str[:,:,tmplon],2)- np.nanmean(cont_T_can_str[:,:,tmplon],2) 

mylevs = np.arange(0,2.5,0.1)
# active
vm = 2.5

depinc = np.array(depfile.diff('depth')[0:39])
depinc = depinc.reshape((len(depinc),1))
depinc[-1] = 2000 - sum(depinc[:-1])

tmph = np.nanmean(heat_T_MOM_str[:,:,tmplon] - cont_T_MOM_str[:,:,tmplon],2)
tmph = np.sum(tmph*depinc,0)/sum(depinc)
#tmpNA = np.nanmean(NA0_T_mri_str[:,:,tmplon] - cont_T_mri_str[:,:,tmplon],2)
tmpp = np.nanmean( heat_p_MOM_str[:,:,tmplon],2)
tmpw = np.nanmean( wind_T_MOM_str[:,:,tmplon]- cont_T_MOM_str[:,:,tmplon],2)
tmpf = np.nanmean( water_T_MOM_str[:,:,tmplon]- cont_T_MOM_str[:,:,tmplon],2)

axs.plot(wind, tmph ,  color='red')
#axs[0].contour(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_U_can_str[:,:,tmplon],2) , levels = [-0.075,-0.05,-0.03,-0.02,0,0.02,0.05,0.075,0.1,0.125], colors='gray')
#axs.plot( wind, np.sum(tmpNA*depinc,0)/sum(depinc), color= 'orange')
axs.plot( wind, np.sum(tmpp*depinc,0)/sum(depinc), color= '#a65628')
axs.plot( wind, np.sum(tmpw*depinc,0)/sum(depinc), color= 'blue')
axs.plot( wind, np.sum(tmpf*depinc,0)/sum(depinc), color= 'green')

MOMwindow = wind
MOMplheat = tmph
MOMplwind = np.sum(tmpw*depinc,0)/sum(depinc)
MOMplwater = np.sum(tmpf*depinc,0)/sum(depinc)
MOMplpass = np.sum(tmpp*depinc,0)/sum(depinc)
#MRIplHF = plHF/fac
MOMlims = [-0.3, 1]  

## velocities here!


tmpcontu=np.nanmean(cont_U_MOM_str[:,:,tmplon],2)
tmphu = np.nanmean( heat_U_MOM_str[:,:,tmplon]- cont_U_MOM_str[:,:,tmplon],2)
tmpwu = np.nanmean( wind_U_MOM_str[:,:,tmplon]- cont_U_MOM_str[:,:,tmplon],2)
tmpfu =np.nanmean( water_U_MOM_str[:,:,tmplon]- cont_U_MOM_str[:,:,tmplon],2)

MOMplcont_u = np.sum(tmpcontu*depinc,0)/sum(depinc)
MOMplwind_u = np.sum(tmpwu*depinc,0)/sum(depinc)
MOMplwater_u= np.sum(tmpfu*depinc,0)/sum(depinc)
MOMplheat_u = np.sum(tmphu*depinc,0)/sum(depinc)

#yy, zz = np.meshgrid(latfile[mylat,0],  depf[mnum]* depfile[regdep])
#yy2, zz2 = np.meshgrid(latfile[np.arange(lats,latn-1),0],  depf[mnum]* depfile[regdep])

plt.plot( [-3,-3], [-0.5, 1.5], linestyle='dashed', color='black', linewidth = 1.5)
plt.plot( [4,4],  [-0.5, 1.5], linestyle='dashed', color='black', linewidth = 1.5)
#plt.legend(['faf-heat', 'faf-passiveheat','faf-stress'])
plt.legend(['faf-heat', 'faf-passiveheat','faf-stress', 'faf-water'])
#axs.set_ylim(MRIlims)
#plt.savefig('SISAZ_figures/CanESM_Tlines_Apr24.eps')

axs.set_ylabel('$\Delta$ T ($^{\circ}$C)',size=14)
axs.set_xlabel('Degrees north of ARC-SAF     ', size=12)
#plt.savefig('SISAZ_figures/MRI_Tlines_May2.eps')
# FAFMIP data
#toPl0 = np.mean(pl_heat_theta[regdep,mylat,mylon] - pl_cont_theta[regdep,mylat,mylon],2)
#toPl0 = np.sum(toPl0* depinc,0)/sum(depinc)
#axs.plot(latfile[mylat,0], toPl0, color='red')

# haha! this is potentially really nice as well ...

# %%
plt.contourf(tmpw)

# %%
fig, axs = plt.subplots()
axs.plot(wind, MOMplheat_u ,  color='red')
#axs[0].contour(wind, -pl_heat_theta.lev.isel(lev=regdep), np.nanmean(cont_U_can_str[:,:,tmplon],2) , levels = [-0.075,-0.05,-0.03,-0.02,0,0.02,0.05,0.075,0.1,0.125], colors='gray')
#axs.plot( wind, np.sum(tmpNA*depinc,0)/sum(depinc), color= 'orange')
axs.plot( wind, MOMplcont_u*0.1, color= 'black')
axs.plot( wind, MOMplwind_u, color= 'blue')
axs.plot( wind, MOMplwater_u, color= 'green')

# %%
## change this for MOM5. 

np.savez('MOM5_ARCSAF_zint.npz', MOM5plcont_u = MOMplcont_u, MOM5plheat_u = MOMplheat_u, 
         MOM5plwind_u = MOMplwind_u, 
         MOM5plwater_u = MOMplwater_u, MOM5window= MOMwindow, MOM5plheat = MOMplheat, MOM5plwind = MOMplwind, MOM5plwater = MOMplwater) #MIROCplpass =MIROCplpass )

# %%
asdf = np.load('MOM5_ARCSAF_zint.npz')

# %%
asdf['MOM5plheat']

# %%
MOM5plheat # 1.6 C 
# Alright something strange has happened. 
#

# %% [markdown]
# ## Combining panels into one coherent figure.

# %%
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(10,10)) 




axs[0,1].plot(ACCwindow, ACCplheat ,  color='red')
axs[0,1].plot(ACCwindow, ACCplwind, color= '#377eb8' )
axs[0,1].plot(ACCwindow, ACCplwater, color= 'gray')
#yy, zz = np.meshgrid(latfile[mylat,0],  depf[mnum]* depfile[regdep])
#yy2, zz2 = np.meshgrid(latfile[np.arange(lats,latn-1),0],  depf[mnum]* depfile[regdep])
axs[0,1].plot(ACCwindow, ACCplHF, '-..', color= '#f781bf') 
axs[0,1].plot( [-3,-3], [-0.5, 1.5], linestyle='dashed', color='black', linewidth = 1.5)
axs[0,1].plot( [4,4],  [-0.5, 1.5], linestyle='dashed', color='black', linewidth = 1.5)
axs[0,1].legend(['ofaf-heat','ofaf-stress', 'ofaf-water', 'faf-heat flux'])
lims = [-0.4, 1.1]         
axs[0,1].set_ylim(lims)


#axs[0,1].set_ylabel('$\Delta$ T ($^{\circ}$C)',size=12)
axs[0,1].set_xlabel('Degrees north of mARC-SAF', size=12)

#plt.legend(['ofaf-heat', 'ofaf-stress', 'ofaf-water','faf-heat flux'])

axr = axs[0,1].twinx()  # instantiate a second axes that shares the same x-axis
axr.set_ylabel('Heat flux (W/m$^2$)', size=12)  # we already handled the x-label with ax1
#ax2.plot(t, data2, color=color)
#ax2.tick_params(axis='y', labelcolor=color)
axr.set_ylim([i * fac for i in ACClims])

fig.tight_layout()  # otherwise the right y-label is slightly clipped

axs[0,0].plot(CESMwindow, CESMplheat ,  color='red')
axs[0,0].plot(CESMwindow, CESMplwind, color= '#377eb8' )
axs[0,0].plot(CESMwindow, CESMplcoup, color= 'purple') 
#axs[0,0].plot(CESMwindow, CESMplheat+ CESMplwind, color= 'yellow')
axs[0,0].plot( [-3,-3], [-0.5, 1.5], linestyle='dashed', color='black', linewidth = 1.5)
axs[0,0].plot( [4,4],  [-0.5, 1.5], linestyle='dashed', color='black', linewidth = 1.5)
axs[0,0].legend(['Buoyancy','Wind Stress','Coupled'])
axs[0,0].set_xlabel('Degrees north of mARC-SAF', size=12)
axs[0,0].set_ylim(CESMlims)




axs[1,0].plot(MRIwindow, MRIplheat ,  color='red')
axs[1,0].plot(MRIwindow, MIRplpass, color= '#a65628') 
axs[1,0].plot(MRIwindow, MRIplwind, color= '#377eb8' )
#axs[1,0].plot(MRIwindow, MRIpl, color= 'gray') 
axs[1,0].plot( [-3,-3], [-0.5, 1.5], linestyle='dashed', color='black', linewidth = 1.5)
axs[1,0].plot( [4,4],  [-0.5, 1.5], linestyle='dashed', color='black', linewidth = 1.5)
axs[1,0].legend(['faf-heat','faf-passiveheat','faf-stress'])#,'faf-water'])
axs[1,0].set_xlabel('Degrees north of mARC-SAF', size=12)
axs[1,0].set_ylim(MRIlims)

axs[1,1].plot(Canwindow, Canplheat ,  color='red')
axs[1,1].plot(Canwindow, Canplpass,  color='#a65628')
axs[1,1].plot(Canwindow, Canplwind, color= '#377eb8' )
axs[1,1].plot(Canwindow, Canplwater, color= 'gray') 
axs[1,1].plot( [-3,-3], [-0.5, 1.5], linestyle='dashed', color='black', linewidth = 1.5)
axs[1,1].plot( [4,4],  [-0.5, 1.5], linestyle='dashed', color='black', linewidth = 1.5)
axs[1,1].legend(['faf-heat','faf-passiveheat','faf-stress','faf-water'])
axs[1,1].set_xlabel('Degrees north of mARC-SAF', size=12)
axs[1,1].set_ylim(Canlims)


axs[0,0].set_ylabel('$\Delta$ T ($^{\circ}$C)',size=12)
axs[1,0].set_ylabel('$\Delta$ T ($^{\circ}$C)',size=12)

#plt.savefig('SISAZ_figures/MRI_faf-heat_speedmap_v3.eps')
#plt.savefig('SISAZ_figures/Combined_Tlineplots_5-6.eps')

# %%
#uo_Omon_MIROC6_faf-water_r1i1p1f1_gn_326001-326912.nc
heat_u_tmp6

# %%
heat_th_tmp6 = xr.open_dataset("/nfs/data/FAFMIP/faf-water/thetao_Omon_MIROC6_faf-water_r1i1p1f1_gn_325001-325912.nc")
heat_th_tmp7 = xr.open_dataset("/nfs/data/FAFMIP/faf-water/thetao_Omon_MIROC6_faf-water_r1i1p1f1_gn_326001-326912.nc")
MIROC_water_theta = (np.mean(heat_th_tmp6.thetao,0) + np.mean(heat_th_tmp7.thetao,0))/2
#uo_Omon_GFDL-ESM2M_faf-water_r1i1p1f1_gn_016101-017012.nc

#heat_u_tmp6 = xr.open_dataset("/nfs/data/FAFMIP/faf-water/uo_Omon_GFDL-ESM2M_faf-water_r1i1p1f1_gn_014101-016012.nc")
#heat_u_tmp7 = xr.open_dataset("/nfs/data/FAFMIP/faf-water/uo_Omon_GFDL-ESM2M_faf-water_r1i1p1f1_gn_016101-017012.nc")
#GFDL_water_u = (np.mean(heat_u_tmp6.uo.isel(time= np.arange(120,240)),0) + np.mean(heat_u_tmp7.uo,0))/2

# %%
heat_u_tmp6 = xr.open_dataset("/nfs/data/FAFMIP/faf-water/thetao_Omon_GFDL-ESM2M_faf-water_r1i1p1f1_gn_014101-016012.nc")
heat_u_tmp7 = xr.open_dataset("/nfs/data/FAFMIP/faf-water/thetao_Omon_GFDL-ESM2M_faf-water_r1i1p1f1_gn_016101-017012.nc")
GFDL_water_theta = (np.mean(heat_u_tmp6.thetao.isel(time= np.arange(120,240)),0) + np.mean(heat_u_tmp7.thetao,0))/2

# %%
#MRI_water_u.to_netcdf(foldern+'MRI_water_u.nc')
#MIROC_water_theta.to_netcdf(foldern+'MIROC_water_theta.nc')
GFDL_water_theta.to_netcdf(foldern+'GFDL_water_theta.nc')

# %%
## Assembling Figure 4

# %%
momf = np.load('MOM5_ARCSAF_zint.npz')
MOM5plheat =  momf['MOM5plheat']
MOM5plwater = momf['MOM5plwater']
MOM5plwind =  momf['MOM5plwind']
MOM5plheat_u =momf['MOM5plheat_u']
MOM5plwater_u=momf['MOM5plwater_u']
MOM5plwind_u =momf['MOM5plwind_u']

# %%
# Figure 4

# degrees North of ARC-SAF sould b

# then somehow I need to add in both the line plots and the oFAFMIP line plots at the bottom

# top 2 are mean velocity and ideally passive T .. nah I like my line plots. 
# Then simply SST, SSS, wind. heat and velocity change! 

## Streamline velocity plots here.

fig, axs = plt.subplots(nrows=5, ncols=2, figsize=(10,13), constrained_layout=True) 
#fig.tight_layout()

toPl0 = np.transpose(np.nanmean(climaU_natl_str, 0)) 
toPl_iso = np.transpose(np.nanmean(climaSig0_str, 0)) 

qdepd = np.diff(depq)
qdepd = np.insert(qdepd,0,10) # up to 37 is 2000 m
qdepd[37:50]=0
# np.nanmean(expaU_natl_str,0)

toPl2 =  np.transpose(np.nanmean(expaU_sst_str,0)) - toPl0
toPl4 =  np.transpose(np.nanmean(expaU_dSSS_str,0)) - toPl0
toPl6 =  np.transpose(np.nanmean(expaU_dWind_str,0)) - toPl0

climU = np.nanmean(climaU_natl_str, 0)
tmp2 = np.sum(qdepd[0:40]*(np.nanmean(expaU_sst_str,0) - climU),1) / sum(qdepd)
tmp4 = np.sum(qdepd[0:40]*(np.nanmean(expaU_dSSS_str,0) - climU),1) / sum(qdepd)
tmp6 = np.sum(qdepd[0:40]*(np.nanmean(expaU_dWind_str,0) - climU),1) / sum(qdepd)
#tmp4 = np.sum(qdepd[0:40]*(np.nanmean(expapassT_SST4k_str,0)),1) / sum(qdepd) # passive

# exploring an alternate version of figure E here with line plots.
axs[3,1].plot(np.arange(-sos,nos), 100*(tmp2), color='red')
axs[3,1].plot(np.arange(-sos,nos), 100*(tmp4), color = '#377eb8')
axs[3,1].plot(np.arange(-sos,nos), 100*(tmp6), color = 'gray') 
#axs[3,0].plot(np.arange(-sos,nos), (tmp4), color = '#a65628') 


vmb = 15
vmd = 2


plt.set_cmap('PiYG')

#A = axs[0,0].contourf(np.arange(-sos,nos), - depq[qlev], 100*toPl0, vmin = -vmb, vmax = vmb, levels=30)
plt.set_cmap('PRGn') 
B = axs[0,1].contourf(np.arange(-sos,nos), - depq[qlev], 100*toPl2, vmin = -vmd, vmax = vmd, levels=30)
C = axs[1,1].contourf(np.arange(-sos,nos), - depq[qlev], 100*toPl4, vmin = -vmd, vmax = vmd, levels=30)
D = axs[2,1].contourf(np.arange(-sos,nos), - depq[qlev], 100*toPl6, vmin = -vmd, vmax = vmd, levels=30)




Acb = plt.colorbar(B, ax=axs[0,1])
Bcb = plt.colorbar(C, ax=axs[1,1])
Ccb = plt.colorbar(D, ax=axs[2,1])
#Dcb = plt.colorbar(D, ax=axs[3,1])

Acb.set_label("$\Delta$u, cm/s",fontsize = 'medium')
Bcb.set_label("$\Delta$u, cm/s",fontsize = 'medium')
Ccb.set_label("$\Delta$u, cm/s",fontsize = 'medium')
#Acb.set_label("u, cm/s",fontsize = 'medium')


Tb = 25
Tdh = 5
Td = 2

# exploring an alternate version of figure E here with line plots. 
qdepd = np.diff(depq)
qdepd = np.insert(qdepd,0,10) # up to 37 is 2000 m
qdepd[37:50]=0
sum(qdepd)
climT = np.nanmean(climaT_natl_str, 0)
tmp3 = np.sum(qdepd[0:40]*(np.nanmean(expaT_sst_str,0) - climT),1) / sum(qdepd)
tmp5 = np.sum(qdepd[0:40]*(np.nanmean(expaT_dSSS_str,0) - climT),1) / sum(qdepd)
tmp7 = np.sum(qdepd[0:40]*(np.nanmean(expaT_dWind_str,0) - climT),1) / sum(qdepd)
tmp4 = np.sum(qdepd[0:40]*(np.nanmean(expapassT_SST4k_str,0)),1) / sum(qdepd) # passive


plt.set_cmap('bwr')
climTtr = np.transpose(np.nanmean(climaT_natl_str, 0)) 
toPl3 =  np.transpose(np.nanmean(expaT_sst_str,0)) - climTtr
toPl5 =  np.transpose(np.nanmean(expaT_dSSS_str,0)) - climTtr
toPl7 =  np.transpose(np.nanmean(expaT_dWind_str,0)) - climTtr

# exploring an alternate version of figure E here with line plots.
axs[3,0].plot(np.arange(-sos,nos), (tmp3), color='red')
axs[3,0].plot(np.arange(-sos,nos), (tmp5), color = '#377eb8')
axs[3,0].plot(np.arange(-sos,nos), (tmp7), color = 'gray') # wind! 
#axs[3,0].plot(np.arange(-sos,nos), (tmp4), color = '#a65628') 
#E = axs[0,1].contourf(np.arange(-sos,nos), - depq[qlev], climT, vmin = 0, vmax = Tb, levels=30)
F = axs[0,0].contourf(np.arange(-sos,nos), - depq[qlev], toPl3, vmin = -Tdh, vmax = Tdh, levels=30)
G = axs[1,0].contourf(np.arange(-sos,nos), - depq[qlev], toPl5, vmin = -Td, vmax = Td, levels=30)
H = axs[2,0].contourf(np.arange(-sos,nos), - depq[qlev], toPl7, vmin = -Td, vmax = Td, levels=30)

#Ecb = plt.colorbar(E, ax=axs[0,0])
Fcb = plt.colorbar(F, ax=axs[0,0])
Gcb = plt.colorbar(G, ax=axs[1,0])
Hcb = plt.colorbar(H, ax=axs[2,0])

#cb.set_label("$\Delta$T, $^{\circ}$C",fontsize = 'medium')
Fcb.set_label("$\Delta$T, $^{\circ}$C",fontsize = 'medium')
Gcb.set_label("$\Delta$T, $^{\circ}$C",fontsize = 'medium')
Hcb.set_label("$\Delta$T, $^{\circ}$C",fontsize = 'medium')

axs[3,0].set_ylabel("$\Delta$T, $^{\circ}$C",fontsize = 'medium')
axs[4,0].set_ylabel("$\Delta$T, $^{\circ}$C",fontsize = 'medium')
axs[3,1].set_ylabel("$\Delta$u, cm/s",fontsize = 'medium')
axs[4,1].set_ylabel("$\Delta$u, cm/s",fontsize = 'medium')
axs[3,0].legend( ['dSST', 'dSSS', 'dWind'],fontsize = 'medium', loc = 'upper left')
axs[3,1].legend( ['dSST', 'dSSS', 'dWind'],fontsize = 'medium', loc = 'upper right')

plabels = ['a','b', 'c', 'd','e','f','g','h', 'i', 'j']
for i in range(10):#np.arange(0,8):#[2,4,6]:
    j = i//2
    k = i%2 
    if j<3:
        axs[j,k].contour(np.arange(-sos,nos), - depq[qlev], toPl0, levels=20, colors= 'gray')
        axs[j,k].set_ylim(-2000,0)    
        axs[j,k].plot(0*depq[qlev] , -depq[qlev], linestyle='dashed', linewidth = 1.5)
        #axs[j,k].plot(0*depq[qlev] +5, -depq[qlev], linestyle='dashed', color='black', linewidth = 1.5)
    #axs[j,k].set_aspect('auto')
    #if (k==1 or i==0):
    #    axs[j,k].contour(np.arange(-sos,nos), - depq[qlev], toPl_iso, levels=12, colors= 'gray')
    axs[j,k].set_xlim(-12,19)
    axs[j,k].text(0.02, 0.05, plabels[i], size = 16, transform = axs[j,k].transAxes)
#axs[3,0].text(0.02, 0.05, plabels[1], size = 16, transform = axs[0,1].transAxes)    
boty = -0.5
topy =2.1
#axs[3,0].plot([-3,-3], [boty,topy], linestyle='dashed', color='black', linewidth = 1.5)
#axs[3,0].plot([5,5], [boty,topy], linestyle='dashed', color='black', linewidth = 1.5)
axs[3,0].set_ylim(boty,topy)

#axs[3,0].set_xlim(-12,20)
#axs[3,1].set_xlim(-12,20)

#plt.setp(axs[2,0].get_xticklabels(), visible=True)




# bringing in oFAFMIP data to try here! 
accf = np.load('ACC_ARCSAF_zint.npz')  
# need to add window to these!! And save 
ACCplheat = accf['ACCplheat']
ACCplwater = accf['ACCplwater']
ACCplwind = accf['ACCplwind']
ACCplheat_u = accf['ACCplheat_u']
ACCplwater_u = accf['ACCplwater_u']
ACCplcont_u = accf['ACCplcont_u']
ACCplwind_u = accf['ACCplwind_u']

nemof = np.load('NEMO_ARCSAF_zint.npz') 
NEMOplheat =  nemof['NEMOplheat']
NEMOplwater = nemof['NEMOplwater']
NEMOplwind =  nemof['NEMOplwind']
NEMOplheat_u =nemof['NEMOplheat_u']
NEMOplwater_u=nemof['NEMOplwater_u']
NEMOplcont_u =nemof['NEMOplcont_u']
NEMOplwind_u =nemof['NEMOplwind_u']

ACCwindow = accf['ACCwindow']
NEMOwindow = nemof['NEMOwindow']

lw1 = 1

momf = np.load('MOM5_ARCSAF_zint.npz') 
MOM5plheat =  momf['MOM5plheat']
MOM5plwater = momf['MOM5plwater']
MOM5plwind =  momf['MOM5plwind']
MOM5plheat_u =momf['MOM5plheat_u']
MOM5plwater_u=momf['MOM5plwater_u']
MOM5plwind_u =momf['MOM5plwind_u']
MOM5plcont_u =momf['MOM5plcont_u']

axs[4,0].plot(ACCwindow, ACCplheat ,  color='red',linewidth=lw1)
axs[4,0].plot(ACCwindow, ACCplwater, color= '#377eb8',linewidth=lw1)
axs[4,0].plot(ACCwindow, ACCplwind, color= 'gray' ,linewidth=lw1)
#axs[4,0].plot(ACCwindow, ACCplHF/2, '--', color= '#f781bf',linewidth=lw1) # why is it in half? 
axs[4,0].plot(NEMOwindow, NEMOplheat ,  color='red',linewidth=lw1)
axs[4,0].plot(NEMOwindow, NEMOplwater, color= '#377eb8',linewidth=lw1)
axs[4,0].plot(NEMOwindow, NEMOplwind, color= 'gray',linewidth=lw1 )

axs[4,0].plot(NEMOwindow, MOM5plheat ,  color='red',linewidth=lw1)
axs[4,0].plot(NEMOwindow, MOM5plwater, color= '#377eb8',linewidth=lw1)
axs[4,0].plot(NEMOwindow, MOM5plwind, color= 'gray',linewidth=lw1 )
#yy, zz = np.meshgrid(latfile[mylat,0],  depf[mnum]* depfile[regdep])
#yy2, zz2 = np.meshgrid(latfile[np.arange(lats,latn-1),0],  depf[mnum]* depfile[regdep])

#axs[4,0].plot( [-3,-3], [-0.5, 1.5], linestyle='dashed', color='black', linewidth = 1.5)
#axs[4,0].plot( [4,4],  [-0.5, 1.5], linestyle='dashed', color='black', linewidth = 1.5)
axs[4,0].legend(['faf-heat-o', 'faf-water-o','faf-stress-o'], loc='upper right', ncol=1)
lims = [-0.4, 1.1]         
axs[4,0].set_ylim(lims)
axs[4,0].set_xlabel('Degrees North of ARC-SAF',fontsize = 'medium' )
axs[4,1].set_xlabel('Degrees North of ARC-SAF',fontsize = 'medium')



axs[4,1].plot(NEMOwindow, 100*NEMOplheat_u ,  color='red',linewidth=lw1)
axs[4,1].plot(NEMOwindow, 100*NEMOplwater_u, color= '#377eb8',linewidth=lw1)
axs[4,1].plot(NEMOwindow, 100*NEMOplwind_u, color= 'gray',linewidth=lw1 )
axs[4,1].plot(NEMOwindow, 10* NEMOplcont_u, 'k--' ,linewidth=lw1 )


axs[4,1].plot(ACCwindow, 100*ACCplheat_u ,  color='red',linewidth=lw1)
axs[4,1].plot(ACCwindow, 100*ACCplwater_u, color= '#377eb8',linewidth=lw1)
axs[4,1].plot(ACCwindow, 100*ACCplwind_u, color= 'gray' ,linewidth=lw1)
axs[4,1].plot(ACCwindow, 10*ACCplcont_u, 'k--',linewidth=lw1 )

axs[4,1].plot(NEMOwindow, 100*MOM5plheat_u ,  color='red',linewidth=lw1)
axs[4,1].plot(NEMOwindow, 100*MOM5plwater_u, color= '#377eb8',linewidth=lw1)
axs[4,1].plot(NEMOwindow, 100*MOM5plwind_u, color= 'gray' ,linewidth=lw1 )
axs[4,1].plot(NEMOwindow, 10* MOM5plcont_u, 'k--',linewidth=lw1 )

axs[4,1].legend(['faf-heat-o', 'faf-water-o', 'faf-stress-o', '0.1*ctrl'], loc='upper right')
lims4 = [-0.7, 1.1]         
axs[4,1].set_ylim(lims4)
lims3 = [-1.3, 1.5]
axs[3,1].set_ylim(lims3)

axs[3,0].plot(np.arange(-sos,nos), 0*np.arange(-sos,nos), 'k', linewidth = 1)
axs[3,1].plot(np.arange(-sos,nos), 0*np.arange(-sos,nos), 'k', linewidth = 1)
axs[4,0].plot(ACCwindow, 0*ACCwindow, 'k', linewidth = 1)
axs[4,1].plot(ACCwindow, 0*ACCwindow, 'k', linewidth = 1)

axs[3,1].plot([0,0], lims3 , linestyle='dashed', linewidth = 1.5)
axs[4,1].plot([0,0], lims4, linestyle='dashed', linewidth = 1.5)

lims40 = [-0.7, 1.4] #i think? 
axs[4,0].set_ylim(lims40)
lims30 = [-0.5, 2.2]
axs[3,0].set_ylim(lims30)

axs[3,0].plot([0,0], lims30 , linestyle='dashed', linewidth = 1.5)
axs[4,0].plot([0,0], lims40, linestyle='dashed', linewidth = 1.5)


#ax2 = axs[4,0].twinx()  # instantiate a second axes that shares the same x-axis


#ax2.set_ylabel('Heat flux (W/m$^2$)', size='medium')  # we already handled the x-label with ax1
#ax2.plot(t, data2, color=color)
#ax2.tick_params(axis='y', labelcolor=color)
#ax2.set_ylim([i * fac for i in lims40])
#fig.tight_layout()

## adding subplot labels, to make easier. 
axs[0,0].set_title('T change under dSST')
axs[0,1].set_title('U change under dSST') 
axs[1,0].set_title('T change under dSSS')
axs[1,1].set_title('U change under dSSS')
axs[2,0].set_title('T change under dWind')
axs[2,1].set_title('U change under dWind')
axs[3,0].set_title('T change (depth mean)')
axs[3,1].set_title('U change (depth mean)')
axs[4,0].set_title('T change, Ocean-only FAFMIP')
axs[4,1].set_title('U change, Ocean-only FAFMIP')
#plt.savefig('SISAZ_figures/OGCM_ARCSAFm_12-16.eps', format='eps')
